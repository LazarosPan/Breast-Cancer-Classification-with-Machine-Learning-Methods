# %% [markdown]
# <!-- # Διπλωματική Εργασία
# ## Ταξινόμηση του καρκίνου του μαστού με μεθόδους μηχανικής μάθησης
# ### Εξαγωγή χαρακτηριστικών με PCA
#
# > Λάζαρος Πανιτσίδης<br />
# > Τμήμα Μηχανικών Παραγωγής και Διοίκησης <br />
# > Διεθνές Πανεπιστήμιο της Ελλάδος <br />
# > lazarospanitsidis@outlook.com -->

# %% [markdown]
# # Diploma thesis
# ## Breast cancer classification using machine learning methods
# ### Feature extraction with PCA
#
# > Lazaros Panitsidis<br />
# > Department of Industrial Engineering and Management <br />
# > International Hellenic University <br />
# > lazarospanitsidis@outlook.com

# %% [markdown]
# ## Contents
# 1. [Useful Python Libraries](#1)
# 1. [Data Processing](#2)
# 1. [Gaussian Naive Bayes](#3)
# 1. [Linear Discriminant Analysis](#4)
# 1. [Quadratic Discriminant Analysis](#5)
# 1. [Ridge Classifier](#6)
# 1. [Decision Tree Classifier](#7)
# 1. [Random Forest Classifier](#8)
# 1. [ADA Boost Classifier (Adaptive Boosting)](#9)
# 1. [C-Support Vector Classification](#10)
# 1. [Stochastic Gradient Descent Classifier](#11)
# 1. [eXtreme Gradient Boosting](#12)
# 1. [Light Gradient Boosting Machine](#13)
# 1. [K-Nearest Neighbors Classifier](#14)
# 1. [Multi-layer Perceptron Classifier](#15)
# 1. [Summary](#16)

# %% [markdown]
# <a id='1'></a>
# ## 1) Useful Python Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library  
import scipy.stats as stats
import matplotlib.pyplot as plt
import time
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None  # default='warn'
#import warnings library
import warnings
# ignore all warnings
warnings.filterwarnings('ignore')
# Any results you write to the current directory are saved as output.

# some of them are not used in this file
from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.feature_selection import SelectKBest, f_classif, chi2, RFE, RFECV , mutual_info_classif
from sklearn.model_selection import train_test_split, cross_val_score , GridSearchCV , LeaveOneOut,KFold,RandomizedSearchCV,StratifiedKFold, HalvingGridSearchCV
from skopt import BayesSearchCV # https://scikit-optimize.github.io/stable/modules/generated/skopt.BayesSearchCV.html#skopt.BayesSearchCV , https://scikit-optimize.github.io/stable/auto_examples/bayesian-optimization.html
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score , make_scorer , classification_report
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline , Pipeline # https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html
from sklearn.preprocessing import StandardScaler , LabelEncoder , MinMaxScaler
from xgboost import XGBClassifier , plot_importance
from sklearn.utils import resample
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier , RidgeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis , QuadraticDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier , AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
import lightgbm as lgbm
from sklearn.neural_network import MLPClassifier
import pygad

# %% [markdown]
# <a id='2'></a>
# ## 2) Data Processing

# %%
dataWISC = pd.read_csv('dataWisc.csv')
dataWISC.drop(["id", "Unnamed: 32"], axis = 1, inplace = True)

# Undersampling function
def make_undersample(_df, column):
  dfs_r = {}
  dfs_c = {}
  smaller = 1e1000
  ignore = ""
  for c in _df[column].unique():
    dfs_c[c] = _df[_df[column] == c]
    if dfs_c[c].shape[0] < smaller:
      smaller = dfs_c[c].shape[0]
      ignore = c

  for c in dfs_c:
    if c == ignore:
      continue
    dfs_r[c] = resample(dfs_c[c], 
                        replace=False, # sample without replacement
                        n_samples=smaller,
                        random_state=0)
  return pd.concat([dfs_r[c] for c in dfs_r] + [dfs_c[ignore]])

dataWISC = make_undersample(dataWISC,'diagnosis')

#Description of the dataset

#how many cases are included in the dataset
length = len(dataWISC)
#how many features are in the dataset
features = dataWISC.shape[1]-1 # - diagnosis

# Number of malignant cases
malignant = len(dataWISC[dataWISC['diagnosis']=='M'])

#Number of benign cases
benign = len(dataWISC[dataWISC['diagnosis']=='B'])

#Rate of malignant tumors over all cases
rate = (float(malignant)/(length))*100

print ("There are "+ str(len(dataWISC))+" cases in this dataset")
print ("There are {}".format(features)+" features in this dataset")
print ("There are {}".format(malignant)+" cases diagnosed as malignant tumor")
print ("There are {}".format(benign)+" cases diagnosed as benign tumor")
print ("The percentage of malignant cases is: {:.2f}%".format(rate))
# Out:
# There are 424 cases in this dataset
# There are 30 features in this dataset
# There are 212 cases diagnosed as malignant tumor
# There are 212 cases diagnosed as benign tumor
# The percentage of malignant cases is: 50.00%

# %%
y = dataWISC.diagnosis                          # M or B 
x = dataWISC.drop('diagnosis',axis = 1 )
target_names=['Benign','Malignant']
le= LabelEncoder()
le.fit(y)
y_le = le.transform(y)

# %%
x_new = x
x_new.head(3)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 49         13.49         22.30           86.91      561.0          0.08752
# 285        12.58         18.40           79.83      489.0          0.08393
# 495        14.87         20.21           96.12      680.9          0.09587
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 49            0.07698         0.04751             0.033840         0.1809
# 285           0.04216         0.00186             0.002924         0.1697
# 495           0.08345         0.06824             0.049510         0.1487
#
#      fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  \
# 49                  0.05718     0.2338       1.353         1.735    20.20
# 285                 0.05855     0.2719       1.350         1.721    22.45
# 495                 0.05748     0.2323       1.636         1.596    21.84
#
#      smoothness_se  compactness_se  concavity_se  concave points_se  \
# 49        0.004455        0.013820       0.02095           0.011840
# 285       0.006383        0.008008       0.00186           0.002924
# 495       0.005415        0.013710       0.02153           0.011830
#
#      symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# 49       0.01641              0.001956         15.15          31.82
# 285      0.02571              0.002015         13.50          23.08
# 495      0.01959              0.001812         16.01          28.48
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 49             99.00       698.8            0.1162            0.17110
# 285            85.56       564.1            0.1038            0.06624
# 495           103.90       783.6            0.1216            0.13880
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 49          0.228200              0.128200          0.2871
# 285         0.005579              0.008772          0.2505
# 495         0.170000              0.101700          0.2369
#
#      fractal_dimension_worst
# 49                   0.06917
# 285                  0.06431
# 495                  0.06599

# %%
# https://machinelearningmastery.com/loocv-for-evaluating-machine-learning-algorithms/#:~:text=Given%20the%20improved%20estimate%20of,biased%20estimates%20of%20model%20performance.
# cv = LeaveOneOut()
rng = np.random.RandomState(13) # random number generator , use it in every random state if shuffle=True for different results.Usefull to test a specific algorithm multiple times within a for loop.

# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html
cv=StratifiedKFold(n_splits=10, shuffle=False, random_state=None)
search_cv = StratifiedKFold(n_splits=5, shuffle=False, random_state=None)

originalclass = []
predictedclass = []

def classification_report_with_accuracy_score(y_true, y_pred):
  originalclass.extend(y_true)
  predictedclass.extend(y_pred)
  #print(classification_report(y_true, y_pred, target_names=target_names)) 
  return accuracy_score(y_true, y_pred)

def print_best_params(search):
    print("")
    print("Best hyperparameters : ", search.best_params_)
    print("")
    print("Best estimator : ", search.best_estimator_)
    print("")

# %%
# this method didn't work so it will not be used (nested cross validation which returns the best parameters and their scores)

# Following kf is the outer loop
outer_kf = StratifiedKFold(n_splits=10,shuffle=True,random_state=13)
inner_kf = StratifiedKFold(n_splits=5,shuffle=True,random_state=13)
# model = SVC()
# params = {'kernel':['rbf','linear'],'C':[1,10]}
def nested_cv_with_gscv(model,params,x,y):
    outer_loop_accuracy_scores = []
    inner_loop_won_params = []
    inner_loop_accuracy_scores = []

    # Looping through the outer loop, feeding each training set into a GSCV as the inner loop
    for train_index,test_index in outer_kf.split(x,y):
        
        GSCV = GridSearchCV(estimator=model,param_grid=params,cv=inner_kf)
        
        # GSCV is looping through the training data to find the best parameters. This is the inner loop
        GSCV.fit(x[train_index],y[train_index])
        
        # The best hyper parameters from GSCV is now being tested on the unseen outer loop test data.
        pred = GSCV.predict(x[test_index])
        
        # Appending the "winning" hyper parameters and their associated accuracy score
        inner_loop_won_params.append(GSCV.best_params_)
        outer_loop_accuracy_scores.append(accuracy_score(y[test_index],pred))
        inner_loop_accuracy_scores.append(GSCV.best_score_)

    for i in zip(inner_loop_won_params,outer_loop_accuracy_scores,inner_loop_accuracy_scores):
        print (i)

    print('Mean of outer loop accuracy score:',np.mean(outer_loop_accuracy_scores))

# https://github.com/rosscleung/Projects/blob/b9abc20db545d9f483e90a9b046ea50c74f25718/Tutorial%20notebooks/Nested%20Cross%20Validation%20Example.ipynb

# %% [markdown]
# * The process by which the best model will be selected is as follows:
# 1. Evaluation of the default algorithm with 10-fold cross validation
# 2. Evaluation of the tuned hyperparameter algorithm with nested cross-validation (5-fold Grid Search/Randomized Search inside a 10-fold cross validation)
# 3. Choosing the best model (from steps 1 and 2) and finding the best hyperparameters

# %% [markdown]
# <a id='3'></a>
# ## 3) [Gaussian Naive Bayes](<https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html#sklearn.naive_bayes.GaussianNB>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_gnb = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('gnb', GaussianNB())])
score = cross_val_score(clf_gnb, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.918     0.953     0.935       212
#    Malignant      0.951     0.915     0.933       212
#
#     accuracy                          0.934       424
#    macro avg      0.935     0.934     0.934       424
# weighted avg      0.935     0.934     0.934       424
#
# --- Time of execution : 0.11070418357849121 seconds ---

# %% [markdown]
# * Νested Cross Validation with Grid Search for hyper-parameter tuning

# %%
start = time.time()
param_grid = { 'gnb__var_smoothing': np.logspace(0,-10, num=100) }

search = GridSearchCV(clf_gnb, param_grid=param_grid, n_jobs=-1,cv=search_cv,verbose=0,scoring='f1_macro')

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(search, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.919     0.958     0.938       212
#    Malignant      0.956     0.915     0.935       212
#
#     accuracy                          0.936       424
#    macro avg      0.937     0.936     0.936       424
# weighted avg      0.937     0.936     0.936       424
#
# --- Time of execution : 9.095436811447144 seconds ---

# %% [markdown]
# <a id='4'></a>
# ## 4) [Linear Discriminant Analysis](<https://scikit-learn.org/stable/modules/generated/sklearn.discriminant_analysis.LinearDiscriminantAnalysis.html>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_lda = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('lda', LinearDiscriminantAnalysis())])

score = cross_val_score(clf_lda, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.938     0.991     0.963       212
#    Malignant      0.990     0.934     0.961       212
#
#     accuracy                          0.962       424
#    macro avg      0.964     0.962     0.962       424
# weighted avg      0.964     0.962     0.962       424
#
# --- Time of execution : 0.08859038352966309 seconds ---

# %% [markdown]
# * Νested Cross Validation with Grid Search for Model Evaluation

# %%
start = time.time()
param_grid = [
    {
        'lda__solver' : ['lsqr','eigen'],
        'lda__shrinkage':[None,'auto']
    },
    {
        'lda__solver' : ['svd'],
        'lda__tol': np.linspace(0, 0.01, num=100)
    }
]

search = RandomizedSearchCV(clf_lda, param_distributions=param_grid, n_jobs=-1,cv=search_cv,verbose=0,scoring='f1_macro',n_iter=500)

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(search, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.938     0.991     0.963       212
#    Malignant      0.990     0.934     0.961       212
#
#     accuracy                          0.962       424
#    macro avg      0.964     0.962     0.962       424
# weighted avg      0.964     0.962     0.962       424
#
# --- Time of execution : 6.808892011642456 seconds ---

# %% [markdown]
# <a id='5'></a>
# ## 5) [Quadratic Discriminant Analysis](<https://scikit-learn.org/stable/modules/generated/sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis.html>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_qda = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('qda', QuadraticDiscriminantAnalysis())])

score = cross_val_score(clf_qda, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.967     0.953     0.960       212
#    Malignant      0.953     0.967     0.960       212
#
#     accuracy                          0.960       424
#    macro avg      0.960     0.960     0.960       424
# weighted avg      0.960     0.960     0.960       424
#
# --- Time of execution : 0.08455038070678711 seconds ---

# %% [markdown]
# * Νested Cross Validation with Randomized Search for hyper-parameter tuning

# %%
start = time.time()
param_grid = {
    'qda__reg_param': np.linspace(0, 1, num=100),
    'qda__tol': np.linspace(0, 0.01, num=100)
}

search = RandomizedSearchCV(clf_qda, param_distributions=param_grid, n_jobs=-1,cv=search_cv,verbose=0,scoring='f1_macro',n_iter=500)

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(search, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.959     0.986     0.972       212
#    Malignant      0.985     0.958     0.971       212
#
#     accuracy                          0.972       424
#    macro avg      0.972     0.972     0.972       424
# weighted avg      0.972     0.972     0.972       424
#
# --- Time of execution : 27.98405933380127 seconds ---

# %% [markdown]
# <a id='6'></a>
# ## 6) [Ridge Classifier](<https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.RidgeClassifier.html#sklearn.linear_model.RidgeClassifier>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_rc = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('rg', RidgeClassifier())])

score = cross_val_score(clf_rc, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.938     0.991     0.963       212
#    Malignant      0.990     0.934     0.961       212
#
#     accuracy                          0.962       424
#    macro avg      0.964     0.962     0.962       424
# weighted avg      0.964     0.962     0.962       424
#
# --- Time of execution : 0.09992051124572754 seconds ---

# %% [markdown]
# * Νested Cross Validation with Randomized Search for hyper-parameter tuning

# %%
start = time.time()
param_grid = {
    'rg__alpha' : np.linspace(0, 1, num=10),
    'rg__fit_intercept' : [True,False],
    'rg__copy_X' : [True,False],
    'rg__max_iter' : [None],
    'rg__tol' : [0.001],
    'rg__class_weight' : [None,'balanced'],
    'rg__solver' : ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs'],
    'rg__positive' : [False]
}

search = RandomizedSearchCV(clf_rc, param_distributions=param_grid, n_jobs=-1,cv=search_cv,verbose=0,scoring='f1_macro',n_iter=500)

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(search, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.938     0.991     0.963       212
#    Malignant      0.990     0.934     0.961       212
#
#     accuracy                          0.962       424
#    macro avg      0.964     0.962     0.962       424
# weighted avg      0.964     0.962     0.962       424
#
# --- Time of execution : 32.04672145843506 seconds ---

# %% [markdown]
# <a id='7'></a>
# ## 7) [Decision Tree Classifier](<https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_tree = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('tree', DecisionTreeClassifier(random_state=13))])

score = cross_val_score(clf_tree, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.934     0.934     0.934       212
#    Malignant      0.934     0.934     0.934       212
#
#     accuracy                          0.934       424
#    macro avg      0.934     0.934     0.934       424
# weighted avg      0.934     0.934     0.934       424
#
# --- Time of execution : 0.09537887573242188 seconds ---

# %% [markdown]
# * Νested Cross Validation with Randomized Search for hyper-parameter tuning

# %%
start = time.time()
param_grid = {
    'tree__criterion' :['gini','entropy'],
    'tree__splitter' : ['best','random'],
    'tree__max_depth': [list(range(2, 20)),None],
    'tree__min_samples_split': list(range(2, 6)),
    'tree__min_samples_leaf': list(range(1, 8)),
    'tree__min_weight_fraction_leaf' : [0.0],
    'tree__max_features': [None, 'sqrt', 'log2'],
    'tree__max_leaf_nodes' : [None],
    'tree__min_impurity_decrease' : [0.0],
    'tree__class_weight' : [None,'balanced'],
    'tree__ccp_alpha' : [0.0],
    'tree__random_state' : [13]
}

search = RandomizedSearchCV(clf_tree, param_distributions=param_grid, n_jobs=-1,cv=search_cv,verbose=0,scoring='f1_macro',n_iter=1000)

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(search, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.914     0.948     0.931       212
#    Malignant      0.946     0.910     0.928       212
#
#     accuracy                          0.929       424
#    macro avg      0.930     0.929     0.929       424
# weighted avg      0.930     0.929     0.929       424
#
# --- Time of execution : 51.517773389816284 seconds ---

# %% [markdown]
# * Finding the best hyper-parameters

# %%
search.fit(x_new, y) # we need this for adaboost

print_best_params(search)
search_results = pd.DataFrame(search.cv_results_)
search_results.sort_values(by='mean_test_score',ascending=False).head(3)
# Out:
# Best hyperparameters :  {'tree__splitter': 'best', 'tree__random_state': 13, 'tree__min_weight_fraction_leaf': 0.0, 'tree__min_samples_split': 5, 'tree__min_samples_leaf': 1, 'tree__min_impurity_decrease': 0.0, 'tree__max_leaf_nodes': None, 'tree__max_features': None, 'tree__max_depth': None, 'tree__criterion': 'entropy', 'tree__class_weight': None, 'tree__ccp_alpha': 0.0}
#
# Best estimator :  Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=10)),
#                 ('tree',
#                  DecisionTreeClassifier(criterion='entropy',
#                                         min_samples_split=5,
#                                         random_state=13))])
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 41        0.003124      0.006248         0.001902    3.803444e-03
# 206       0.005784      0.000399         0.001995    3.162980e-07
# 414       0.007978      0.005984         0.001995    2.611745e-07
#
#     param_tree__splitter param_tree__random_state  \
# 41                  best                       13
# 206                 best                       13
# 414                 best                       13
#
#     param_tree__min_weight_fraction_leaf param_tree__min_samples_split  \
# 41                                   0.0                             5
# 206                                  0.0                             5
# 414                                  0.0                             4
#
#     param_tree__min_samples_leaf param_tree__min_impurity_decrease  \
# 41                             1                               0.0
# 206                            1                               0.0
# 414                            1                               0.0
#
#     param_tree__max_leaf_nodes param_tree__max_features param_tree__max_depth  \
# 41                        None                     None                  None
# 206                       None                     None                  None
# 414                       None                     None                  None
#
#     param_tree__criterion param_tree__class_weight param_tree__ccp_alpha  \
# 41                entropy                     None                   0.0
# 206               entropy                 balanced                   0.0
# 414               entropy                     None                   0.0
#
#                                                 params  split0_test_score  \
# 41   {'tree__splitter': 'best', 'tree__random_state...           0.964706
# 206  {'tree__splitter': 'best', 'tree__random_state...           0.964706
# 414  {'tree__splitter': 'best', 'tree__random_state...           0.964706
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 41            0.905765                1.0           0.917464
# 206           0.894118                1.0           0.917464
# 414           0.905765                1.0           0.917464
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 41            0.952354         0.948058        0.033818                1
# 206           0.952354         0.945728        0.036911                2
# 414           0.940468         0.945681        0.033850                3

# %% [markdown]
# <a id='8'></a>
# ## 8) [Random Forest Classifier](<https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_rf = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('rf', RandomForestClassifier(random_state=13))])
                       
score = cross_val_score(clf_rf, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.949     0.962     0.956       212
#    Malignant      0.962     0.948     0.955       212
#
#     accuracy                          0.955       424
#    macro avg      0.955     0.955     0.955       424
# weighted avg      0.955     0.955     0.955       424
#
# --- Time of execution : 1.2531466484069824 seconds ---

# %% [markdown]
# * Νested Cross Validation with Randomized Search for hyper-parameter tuning

# %%
start = time.time()
param_grid = {
    'rf__bootstrap': [True,False],
    'rf__max_depth': [list(range(5,15)), None],
    'rf__n_estimators' :[100],
    'rf__max_features': [None, 'sqrt', 'log2'],
    'rf__max_leaf_nodes' : [None,list(range(5,15))],
    'rf__min_samples_leaf': list(range(1,10)),
    'rf__min_samples_split': list(range(2, 6)),
    'rf__criterion' :['entropy','gini'],
    'rf__random_state' : [13]
}

search = RandomizedSearchCV(clf_rf, param_distributions=param_grid, n_jobs=-1,cv=search_cv,verbose=1,scoring='f1_macro',n_iter=300)

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(search, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits

# %%
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.953     0.962     0.958       212
#    Malignant      0.962     0.953     0.957       212
#
#     accuracy                          0.958       424
#    macro avg      0.958     0.958     0.958       424
# weighted avg      0.958     0.958     0.958       424
#
# --- Time of execution : 148.47292494773865 seconds ---

# %% [markdown]
# <a id='9'></a>
# ## 9) [ADA Boost Classifier (Adaptive Boosting)](<https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html#:~:text=An%20AdaBoost%20%5B1%5D%20classifier%20is,focus%20more%20on%20difficult%20cases.>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_adaboost = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('adab', AdaBoostClassifier(random_state=13))])

score = cross_val_score(clf_adaboost, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.958     0.962     0.960       212
#    Malignant      0.962     0.958     0.960       212
#
#     accuracy                          0.960       424
#    macro avg      0.960     0.960     0.960       424
# weighted avg      0.960     0.960     0.960       424
#
# --- Time of execution : 0.802978515625 seconds ---

# %% [markdown]
# * Νested Cross Validation with Randomized Search for hyper-parameter tuning

# %%
start = time.time()
param_grid = {
    'adab__base_estimator' : [DecisionTreeClassifier(criterion='entropy',min_samples_split=5, random_state=13)],
    'adab__n_estimators' : np.arange(100,210,10),
    'adab__learning_rate' : np.power(10, np.arange(-3, 1, dtype=float)),
    'adab__algorithm' : ['SAMME', 'SAMME.R'],
    'adab__random_state' : [13],
}

search = RandomizedSearchCV(clf_adaboost, param_distributions=param_grid, n_jobs=-1,cv=search_cv,verbose=0,scoring='f1_macro',n_iter=300)

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(search, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.949     0.958     0.953       212
#    Malignant      0.957     0.948     0.953       212
#
#     accuracy                          0.953       424
#    macro avg      0.953     0.953     0.953       424
# weighted avg      0.953     0.953     0.953       424
#
# --- Time of execution : 41.33515763282776 seconds ---

# %% [markdown]
# <a id='10'></a>
# ## 10) [C-Support Vector Classification](<https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_svc = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('svc', SVC())])

score = cross_val_score(clf_svc, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.972     0.991     0.981       212
#    Malignant      0.990     0.972     0.981       212
#
#     accuracy                          0.981       424
#    macro avg      0.981     0.981     0.981       424
# weighted avg      0.981     0.981     0.981       424
#
# --- Time of execution : 0.09321236610412598 seconds ---

# %% [markdown]
# * Νested Cross Validation with Grid Search for hyper-parameter tuning

# %%
start = time.time()
param_grid = [
    {
        'svc__kernel': ['rbf'], 
        'svc__gamma': [1,1e-1,1e-2, 1e-3, 1e-4,'auto','scale'], 
        'svc__C': [1, 10, 100, 1000],
        'svc__decision_function_shape': ['ovo', 'ovr'],
        'svc__random_state' : [13]
    },
    {
        'svc__kernel': ['linear'], 
        'svc__C': [1, 10, 100, 1000],
        'svc__decision_function_shape': ['ovo', 'ovr'],
        'svc__random_state' : [13]
    },
]

search = GridSearchCV(clf_svc, param_grid=param_grid, n_jobs=-1,cv=search_cv,verbose=0,scoring='f1_macro')

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(search, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.977     0.986     0.981       212
#    Malignant      0.986     0.976     0.981       212
#
#     accuracy                          0.981       424
#    macro avg      0.981     0.981     0.981       424
# weighted avg      0.981     0.981     0.981       424
#
# --- Time of execution : 9.945495843887329 seconds ---

# %% [markdown]
# <a id='11'></a>
# ## 11) [Stochastic Gradient Descent Classifier](<https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_sgd = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('sgd', SGDClassifier(random_state=13))])

score = cross_val_score(clf_sgd, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.967     0.953     0.960       212
#    Malignant      0.953     0.967     0.960       212
#
#     accuracy                          0.960       424
#    macro avg      0.960     0.960     0.960       424
# weighted avg      0.960     0.960     0.960       424
#
# --- Time of execution : 0.08829951286315918 seconds ---

# %% [markdown]
# * Νested Cross Validation with Grid Search for hyper-parameter tuning

# %%
start = time.time()
param_grid = {
    'sgd__average': [True, False],
    'sgd__l1_ratio': np.linspace(0, 1, num=10),
    'sgd__alpha': np.power(10, np.arange(-2, 1, dtype=float)),
    'sgd__random_state' : [13]
}

grid_search = GridSearchCV(clf_sgd, param_grid=param_grid, n_jobs=-1,cv=search_cv,verbose=0,scoring='f1_macro')

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(grid_search, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.963     0.986     0.974       212
#    Malignant      0.986     0.962     0.974       212
#
#     accuracy                          0.974       424
#    macro avg      0.974     0.974     0.974       424
# weighted avg      0.974     0.974     0.974       424
#
# --- Time of execution : 4.022985219955444 seconds ---

# %% [markdown]
# <a id='12'></a>
# ## 12) [eXtreme Gradient Boosting](<https://xgboost.readthedocs.io/en/latest/parameter.html#learning-task-parameters>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_xgb = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('xgb', XGBClassifier(random_state=13))])

score = cross_val_score(clf_xgb, x_new, y_le, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.962     0.962     0.962       212
#    Malignant      0.962     0.962     0.962       212
#
#     accuracy                          0.962       424
#    macro avg      0.962     0.962     0.962       424
# weighted avg      0.962     0.962     0.962       424
#
# --- Time of execution : 0.5850555896759033 seconds ---

# %% [markdown]
# * Νested Cross Validation with Randomized Search for hyper-parameter tuning

# %%
# https://www.kaggle.com/code/prashant111/a-guide-on-xgboost-hyperparameters-tuning/notebook
# https://www.cs.cornell.edu/courses/cs4780/2018sp/lectures/lecturenote19.html
# https://medium.com/data-design/xgboost-hi-im-gamma-what-can-i-do-for-you-and-the-tuning-of-regularization-a42ea17e6ab6

start = time.time()
param_grid = {
        'xgb__booster' : ['gbtree'],
        'xgb__validate_parameters' : [True],
        'xgb__learning_rate' : np.arange(0.01,1.1,0.05),
        'xgb__gamma' : np.arange(0,1.05,0.05),
        'xgb__max_depth' : np.arange(2,11,1),
        'xgb__min_child_weight' : np.arange(1,6,1),
        'xgb__max_delta_step' : np.arange(0,5,1),
        'xgb__subsample' : [0.5],
        'xgb__colsample_bylevel' : [1],
        'xgb__colsample_bynode' : [1],
        'xgb__colsample_bytree' : [1],
        'xgb__reg_lambda' : [0,1],
        'xgb__reg_alpha' : [0],
        'xgb__tree_method' : ['exact'],
        'xgb__scale_pos_weight' : [1],
        'xgb__objective' : ['binary:logistic'], # 'multi:softmax' -> same scores as 'binary:logistic' with grid search
        #'num_class' : [2],
        'xgb__n_estimators' : np.arange(100,210,10),
        'xgb__random_state' : [13]
    }

grid_search = RandomizedSearchCV(clf_xgb, param_distributions=param_grid, n_jobs=-1,cv=search_cv,verbose=1,scoring='f1_macro',n_iter=300)

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(grid_search, x_new, y_le, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits

# %%
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.959     0.981     0.970       212
#    Malignant      0.981     0.958     0.969       212
#
#     accuracy                          0.969       424
#    macro avg      0.970     0.969     0.969       424
# weighted avg      0.970     0.969     0.969       424
#
# --- Time of execution : 217.93663454055786 seconds ---

# %% [markdown]
# <a id='13'></a>
# ## 13) [Light Gradient Boosting Machine](<https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_lgbm = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('lgbm', lgbm.LGBMClassifier(random_state=13))])

score = cross_val_score(clf_lgbm, x_new, y_le, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.967     0.981     0.974       212
#    Malignant      0.981     0.967     0.974       212
#
#     accuracy                          0.974       424
#    macro avg      0.974     0.974     0.974       424
# weighted avg      0.974     0.974     0.974       424
#
# --- Time of execution : 0.2835416793823242 seconds ---

# %% [markdown]
# * Νested Cross Validation with Randomized Search for hyper-parameter tuning

# %%
# https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html
# https://neptune.ai/blog/lightgbm-parameters-guide
# https://www.youtube.com/watch?v=5CWwwtEM2TA&ab_channel=PyData & https://github.com/MSusik/newgradientboosting/blob/master/pydata.pdf

start = time.time()
param_grid = {
        'lgbm__boosting_type' : ['gbdt','dart'],
        'lgbm__num_leaves' : np.arange(5,55,1),
        'lgbm__max_depth' : np.arange(2,11,1),
        'lgbm__learning_rate' : np.arange(0.01,1.1,0.05),
        'lgbm__n_estimators' : np.arange(100,210,10),
        'lgbm__objective' : ['binary'],
        'lgbm__min_child_samples' : np.arange(10,35,5),
        'lgbm__subsample' : [0.5],
        'lgbm__reg_lambda' : [0,1],
        'lgbm__reg_alpha' : [0],
        'lgbm__subsample' : [0.5],
        'lgbm__colsample_bytree' : [1],
        'lgbm__scale_pos_weight' : [1],
        'lgbm__random_state' : [13]
    }

grid_search = RandomizedSearchCV(clf_lgbm, param_distributions=param_grid, n_jobs=-1,cv=search_cv,verbose=1,scoring='f1_macro',n_iter=300)

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(grid_search, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits

# %%
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.963     0.976     0.970       212
#    Malignant      0.976     0.962     0.969       212
#
#     accuracy                          0.969       424
#    macro avg      0.969     0.969     0.969       424
# weighted avg      0.969     0.969     0.969       424
#
# --- Time of execution : 90.93715715408325 seconds ---

# %% [markdown]
# <a id='14'></a>
# ## 14) [K-Nearest Neighbors Classifier](<https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_knn = Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('knn', KNeighborsClassifier())])

score = cross_val_score(clf_knn, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.946     0.986     0.965       212
#    Malignant      0.985     0.943     0.964       212
#
#     accuracy                          0.965       424
#    macro avg      0.965     0.965     0.965       424
# weighted avg      0.965     0.965     0.965       424
#
# --- Time of execution : 0.1001896858215332 seconds ---

# %% [markdown]
# * Νested Cross Validation with Grid Search for hyper-parameter tuning

# %%
start = time.time()
param_grid = {
    'knn__n_neighbors': list(range(3,10)),
    'knn__weights': ['uniform','distance'],
    'knn__algorithm' : ['ball_tree', 'kd_tree', 'brute'],
    'knn__leaf_size': [10,20,30,40,50],
    'knn__p': [1,2],
    'knn__metric': ['minkowski','manhattan','chebyshev']
}

grid_search = GridSearchCV(clf_knn, param_grid=param_grid, n_jobs=-1,cv=search_cv,verbose=0,scoring='f1_macro')

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(grid_search, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.972     0.986     0.979       212
#    Malignant      0.986     0.972     0.979       212
#
#     accuracy                          0.979       424
#    macro avg      0.979     0.979     0.979       424
# weighted avg      0.979     0.979     0.979       424
#
# --- Time of execution : 87.84296345710754 seconds ---

# %% [markdown]
# <a id='15'></a>
# ## 15) [Multi-layer Perceptron Classifier](<https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html>)

# %% [markdown]
# * Default hyperparameters

# %%
start = time.time()
originalclass = []
predictedclass = []
  
# Cross validate
clf_mlp =  Pipeline([('scaler', StandardScaler()),('pca',PCA(n_components=10)), ('scaler2', StandardScaler()),('mlp', MLPClassifier(shuffle=True,random_state=13))])
# scaling after pca showed better results
score = cross_val_score(clf_mlp, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
print("--- Time of execution : %s seconds ---" % (time.time() - start))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.972     0.991     0.981       212
#    Malignant      0.990     0.972     0.981       212
#
#     accuracy                          0.981       424
#    macro avg      0.981     0.981     0.981       424
# weighted avg      0.981     0.981     0.981       424
#
# --- Time of execution : 3.700441360473633 seconds ---

# %% [markdown]
# * Νested Cross Validation with Randomized Search for hyper-parameter tuning

# %% [markdown]
# * Tried a wider range of hyperparameters in nested cross validation at first , but over testing, worst attempts were removed (those in comments). Finally, when few hyperparameters remained, they were tested separately with a 10-fold cross-validation.

# %% [markdown]
# 1. Solver : ADAM

# %%
# http://yann.lecun.com/exdb/publis/pdf/lecun-98b.pdf
# https://www.cs.cornell.edu/courses/cs4780/2018fa/lectures/lecturenote20.pdf
# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw
# https://datascience.stackexchange.com/questions/36049/how-to-adjust-the-hyperparameters-of-mlp-classifier-to-get-more-perfect-performa
# https://scikit-learn.org/stable/auto_examples/neural_networks/plot_mlp_alpha.html
param_grid = {
    'mlp__hidden_layer_sizes' : [(20,)] , #[(20,),(100,),(20,4),(10,10,)] 
    'mlp__activation' : ['relu'], #['logistic','tanh','relu']
    'mlp__solver' : ['adam'],
    'mlp__alpha' : [0.1], #10.0 ** -np.arange(1, 7) , np.linspace(0.1,3,20) , 1 ,*0.1
    'mlp__batch_size' : [99], # ~297 samples for train at inner cv -> 3 equal size batches , #[16,32,64,128,'auto']
    'mlp__learning_rate' : ['constant'],
    'mlp__learning_rate_init' : [0.01,0.001],
    'mlp__max_iter' : [1000],
    'mlp__verbose' : [1]
}

search_adam = GridSearchCV(clf_mlp, param_grid=param_grid, n_jobs=-1,cv=search_cv,verbose=1,scoring='f1_macro')

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(search_adam, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Iteration 1, loss = 0.60904345
# Iteration 2, loss = 0.51329005
# Iteration 3, loss = 0.43427708
# Iteration 4, loss = 0.37003938
# Iteration 5, loss = 0.31461902
# Iteration 6, loss = 0.26791543
# Iteration 7, loss = 0.22981482
# Iteration 8, loss = 0.19866344
# Iteration 9, loss = 0.17438068
# Iteration 10, loss = 0.15387658
# Iteration 11, loss = 0.13839645
# Iteration 12, loss = 0.12554637
# Iteration 13, loss = 0.11533133
# Iteration 14, loss = 0.10708479
# Iteration 15, loss = 0.09933705
# Iteration 16, loss = 0.09376646
# Iteration 17, loss = 0.08873488
# Iteration 18, loss = 0.08502769
# Iteration 19, loss = 0.08117158
# Iteration 20, loss = 0.07786950
# Iteration 21, loss = 0.07522183
# Iteration 22, loss = 0.07285588
# Iteration 23, loss = 0.07105131
# Iteration 24, loss = 0.06917150
# Iteration 25, loss = 0.06729218
# Iteration 26, loss = 0.06573170
# Iteration 27, loss = 0.06471634
# Iteration 28, loss = 0.06329278
# Iteration 29, loss = 0.06245844
# Iteration 30, loss = 0.06111605
# Iteration 31, loss = 0.06022675
# Iteration 32, loss = 0.05925491
# Iteration 33, loss = 0.05851494
# Iteration 34, loss = 0.05774995
# Iteration 35, loss = 0.05693353
# Iteration 36, loss = 0.05631301
# Iteration 37, loss = 0.05576568
# Iteration 38, loss = 0.05516579
# Iteration 39, loss = 0.05473239
# Iteration 40, loss = 0.05424452
# Iteration 41, loss = 0.05390277
# Iteration 42, loss = 0.05316595
# Iteration 43, loss = 0.05269091
# Iteration 44, loss = 0.05243986
# Iteration 45, loss = 0.05199026
# Iteration 46, loss = 0.05142047
# Iteration 47, loss = 0.05115951
# Iteration 48, loss = 0.05075111
# Iteration 49, loss = 0.05041078
# Iteration 50, loss = 0.04988865
# Iteration 51, loss = 0.04959027
# Iteration 52, loss = 0.05001414
# Iteration 53, loss = 0.04943479
# Iteration 54, loss = 0.04872728
# Iteration 55, loss = 0.04894037
# Iteration 56, loss = 0.04828692
# Iteration 57, loss = 0.04777571
# Iteration 58, loss = 0.04769628
# Iteration 59, loss = 0.04772523
# Iteration 60, loss = 0.04725735
# Iteration 61, loss = 0.04725797
# Iteration 62, loss = 0.04680309
# Iteration 63, loss = 0.04679282
# Iteration 64, loss = 0.04660107
# Iteration 65, loss = 0.04632302
# Iteration 66, loss = 0.04614977
# Iteration 67, loss = 0.04613162
# Iteration 68, loss = 0.04599038
# Iteration 69, loss = 0.04568855
# Iteration 70, loss = 0.04545683
# Iteration 71, loss = 0.04536558
# Iteration 72, loss = 0.04534970
# Iteration 73, loss = 0.04519032
# Iteration 74, loss = 0.04514177
# Iteration 75, loss = 0.04513389
# Iteration 76, loss = 0.04473961
# Iteration 77, loss = 0.04470729
# Iteration 78, loss = 0.04461542
# Iteration 79, loss = 0.04447082
# Iteration 80, loss = 0.04444831
# Iteration 81, loss = 0.04446872
# Iteration 82, loss = 0.04419590
# Iteration 83, loss = 0.04422226
# Iteration 84, loss = 0.04408402
# Iteration 85, loss = 0.04397264
# Iteration 86, loss = 0.04408826
# Iteration 87, loss = 0.04392956
# Iteration 88, loss = 0.04369360
# Iteration 89, loss = 0.04394913
# Iteration 90, loss = 0.04378960
# Iteration 91, loss = 0.04370830
# Iteration 92, loss = 0.04353589
# Iteration 93, loss = 0.04348357
# Iteration 94, loss = 0.04337666
# Iteration 95, loss = 0.04338895
# Iteration 96, loss = 0.04333167
# Iteration 97, loss = 0.04314768
# Iteration 98, loss = 0.04317810
# Iteration 99, loss = 0.04334090
# Iteration 100, loss = 0.04327717
# Iteration 101, loss = 0.04282942
# Iteration 102, loss = 0.04292008
# Iteration 103, loss = 0.04278500
# Iteration 104, loss = 0.04275804
# Iteration 105, loss = 0.04255446
# Iteration 106, loss = 0.04247274
# Iteration 107, loss = 0.04259139
# Iteration 108, loss = 0.04269677
# Iteration 109, loss = 0.04243366
# Iteration 110, loss = 0.04230634
# Iteration 111, loss = 0.04233076
# Iteration 112, loss = 0.04230373
# Iteration 113, loss = 0.04229989
# Iteration 114, loss = 0.04217904
# Iteration 115, loss = 0.04215221
# Iteration 116, loss = 0.04208393
# Iteration 117, loss = 0.04193638
# Iteration 118, loss = 0.04200270
# Iteration 119, loss = 0.04205873
# Iteration 120, loss = 0.04193078
# Iteration 121, loss = 0.04183410
# Iteration 122, loss = 0.04194415
# Iteration 123, loss = 0.04187761
# Iteration 124, loss = 0.04176438
# Iteration 125, loss = 0.04179088
# Iteration 126, loss = 0.04179228
# Iteration 127, loss = 0.04186160
# Iteration 128, loss = 0.04162135
# Iteration 129, loss = 0.04163330
# Iteration 130, loss = 0.04168451
# Iteration 131, loss = 0.04165074
# Iteration 132, loss = 0.04160398
# Iteration 133, loss = 0.04170404
# Iteration 134, loss = 0.04165018
# Iteration 135, loss = 0.04156261
# Iteration 136, loss = 0.04158777
# Iteration 137, loss = 0.04138238
# Iteration 138, loss = 0.04143064
# Iteration 139, loss = 0.04140778
# Iteration 140, loss = 0.04145174
# Iteration 141, loss = 0.04125140
# Iteration 142, loss = 0.04135049
# Iteration 143, loss = 0.04138119
# Iteration 144, loss = 0.04128890
# Iteration 145, loss = 0.04132908
# Iteration 146, loss = 0.04120298
# Iteration 147, loss = 0.04145031
# Iteration 148, loss = 0.04128896
# Iteration 149, loss = 0.04120746
# Iteration 150, loss = 0.04105088
# Iteration 151, loss = 0.04111851
# Iteration 152, loss = 0.04107764
# Iteration 153, loss = 0.04106529
# Iteration 154, loss = 0.04105960
# Iteration 155, loss = 0.04115271
# Iteration 156, loss = 0.04117495
# Iteration 157, loss = 0.04118011
# Iteration 158, loss = 0.04111618
# Iteration 159, loss = 0.04087822
# Iteration 160, loss = 0.04122656
# Iteration 161, loss = 0.04116446
# Iteration 162, loss = 0.04103036
# Iteration 163, loss = 0.04089348
# Iteration 164, loss = 0.04104783
# Iteration 165, loss = 0.04092491
# Iteration 166, loss = 0.04091190
# Iteration 167, loss = 0.04121631
# Iteration 168, loss = 0.04089619
# Iteration 169, loss = 0.04074186
# Iteration 170, loss = 0.04068442
# Iteration 171, loss = 0.04080570
# Iteration 172, loss = 0.04070537
# Iteration 173, loss = 0.04074491
# Iteration 174, loss = 0.04072245
# Iteration 175, loss = 0.04070205
# Iteration 176, loss = 0.04077922
# Iteration 177, loss = 0.04067773
# Iteration 178, loss = 0.04108512
# Iteration 179, loss = 0.04096554
# Iteration 180, loss = 0.04089900
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Iteration 1, loss = 0.62076034
# Iteration 2, loss = 0.61037390
# Iteration 3, loss = 0.60020464
# Iteration 4, loss = 0.59072309
# Iteration 5, loss = 0.58109764
# Iteration 6, loss = 0.57197988
# Iteration 7, loss = 0.56312311
# Iteration 8, loss = 0.55430454
# Iteration 9, loss = 0.54557005
# Iteration 10, loss = 0.53709731
# Iteration 11, loss = 0.52854437
# Iteration 12, loss = 0.52052792
# Iteration 13, loss = 0.51220667
# Iteration 14, loss = 0.50402599
# Iteration 15, loss = 0.49627563
# Iteration 16, loss = 0.48830816
# Iteration 17, loss = 0.48067848
# Iteration 18, loss = 0.47280555
# Iteration 19, loss = 0.46511440
# Iteration 20, loss = 0.45760272
# Iteration 21, loss = 0.45017379
# Iteration 22, loss = 0.44265645
# Iteration 23, loss = 0.43547579
# Iteration 24, loss = 0.42821198
# Iteration 25, loss = 0.42110042
# Iteration 26, loss = 0.41421995
# Iteration 27, loss = 0.40732089
# Iteration 28, loss = 0.40062088
# Iteration 29, loss = 0.39383931
# Iteration 30, loss = 0.38724817
# Iteration 31, loss = 0.38069066
# Iteration 32, loss = 0.37445329
# Iteration 33, loss = 0.36829682
# Iteration 34, loss = 0.36202275
# Iteration 35, loss = 0.35606824
# Iteration 36, loss = 0.35012638
# Iteration 37, loss = 0.34430724
# Iteration 38, loss = 0.33865183
# Iteration 39, loss = 0.33309502
# Iteration 40, loss = 0.32771361
# Iteration 41, loss = 0.32228187
# Iteration 42, loss = 0.31706709
# Iteration 43, loss = 0.31200553
# Iteration 44, loss = 0.30695220
# Iteration 45, loss = 0.30202725
# Iteration 46, loss = 0.29712275
# Iteration 47, loss = 0.29242389
# Iteration 48, loss = 0.28786803
# Iteration 49, loss = 0.28334798
# Iteration 50, loss = 0.27897078
# Iteration 51, loss = 0.27466082
# Iteration 52, loss = 0.27039736
# Iteration 53, loss = 0.26625183
# Iteration 54, loss = 0.26214093
# Iteration 55, loss = 0.25816999
# Iteration 56, loss = 0.25438251
# Iteration 57, loss = 0.25045227
# Iteration 58, loss = 0.24670054
# Iteration 59, loss = 0.24321911
# Iteration 60, loss = 0.23957282
# Iteration 61, loss = 0.23606959
# Iteration 62, loss = 0.23266222
# Iteration 63, loss = 0.22939934
# Iteration 64, loss = 0.22617636
# Iteration 65, loss = 0.22296560
# Iteration 66, loss = 0.21988735
# Iteration 67, loss = 0.21678384
# Iteration 68, loss = 0.21386362
# Iteration 69, loss = 0.21093622
# Iteration 70, loss = 0.20805077
# Iteration 71, loss = 0.20521815
# Iteration 72, loss = 0.20250710
# Iteration 73, loss = 0.19983403
# Iteration 74, loss = 0.19716331
# Iteration 75, loss = 0.19461668
# Iteration 76, loss = 0.19210429
# Iteration 77, loss = 0.18965007
# Iteration 78, loss = 0.18727655
# Iteration 79, loss = 0.18496185
# Iteration 80, loss = 0.18265722
# Iteration 81, loss = 0.18041183
# Iteration 82, loss = 0.17820873
# Iteration 83, loss = 0.17607895
# Iteration 84, loss = 0.17400200
# Iteration 85, loss = 0.17197578
# Iteration 86, loss = 0.16996390
# Iteration 87, loss = 0.16800035
# Iteration 88, loss = 0.16610771
# Iteration 89, loss = 0.16422209
# Iteration 90, loss = 0.16243675
# Iteration 91, loss = 0.16066300
# Iteration 92, loss = 0.15892472
# Iteration 93, loss = 0.15724774
# Iteration 94, loss = 0.15558823
# Iteration 95, loss = 0.15396319
# Iteration 96, loss = 0.15236284
# Iteration 97, loss = 0.15083732
# Iteration 98, loss = 0.14925884
# Iteration 99, loss = 0.14772234
# Iteration 100, loss = 0.14625439
# Iteration 101, loss = 0.14482320
# Iteration 102, loss = 0.14334080
# Iteration 103, loss = 0.14199548
# Iteration 104, loss = 0.14064881
# Iteration 105, loss = 0.13926651
# Iteration 106, loss = 0.13795431
# Iteration 107, loss = 0.13666660
# Iteration 108, loss = 0.13539073
# Iteration 109, loss = 0.13416512
# Iteration 110, loss = 0.13296468
# Iteration 111, loss = 0.13179003
# Iteration 112, loss = 0.13064055
# Iteration 113, loss = 0.12949543
# Iteration 114, loss = 0.12839163
# Iteration 115, loss = 0.12733171
# Iteration 116, loss = 0.12622162
# Iteration 117, loss = 0.12520162
# Iteration 118, loss = 0.12421201
# Iteration 119, loss = 0.12321387
# Iteration 120, loss = 0.12223077
# Iteration 121, loss = 0.12123063
# Iteration 122, loss = 0.12033298
# Iteration 123, loss = 0.11941922
# Iteration 124, loss = 0.11849295
# Iteration 125, loss = 0.11758715
# Iteration 126, loss = 0.11676271
# Iteration 127, loss = 0.11590444
# Iteration 128, loss = 0.11503056
# Iteration 129, loss = 0.11419469
# Iteration 130, loss = 0.11339619
# Iteration 131, loss = 0.11261097
# Iteration 132, loss = 0.11181453
# Iteration 133, loss = 0.11106430
# Iteration 134, loss = 0.11030556
# Iteration 135, loss = 0.10953160
# Iteration 136, loss = 0.10881371
# Iteration 137, loss = 0.10809382
# Iteration 138, loss = 0.10743856
# Iteration 139, loss = 0.10673078
# Iteration 140, loss = 0.10608453
# Iteration 141, loss = 0.10539682
# Iteration 142, loss = 0.10474859
# Iteration 143, loss = 0.10412447
# Iteration 144, loss = 0.10346533
# Iteration 145, loss = 0.10285925
# Iteration 146, loss = 0.10224677
# Iteration 147, loss = 0.10165129
# Iteration 148, loss = 0.10105311
# Iteration 149, loss = 0.10048916
# Iteration 150, loss = 0.09991011
# Iteration 151, loss = 0.09934005
# Iteration 152, loss = 0.09879528
# Iteration 153, loss = 0.09823322
# Iteration 154, loss = 0.09770430
# Iteration 155, loss = 0.09714858
# Iteration 156, loss = 0.09660816
# Iteration 157, loss = 0.09609908
# Iteration 158, loss = 0.09559389
# Iteration 159, loss = 0.09506918
# Iteration 160, loss = 0.09458855
# Iteration 161, loss = 0.09408656
# Iteration 162, loss = 0.09360845
# Iteration 163, loss = 0.09310720
# Iteration 164, loss = 0.09266987
# Iteration 165, loss = 0.09217308
# Iteration 166, loss = 0.09171525
# Iteration 167, loss = 0.09128612
# Iteration 168, loss = 0.09079949
# Iteration 169, loss = 0.09037771
# Iteration 170, loss = 0.08992379
# Iteration 171, loss = 0.08947802
# Iteration 172, loss = 0.08906606
# Iteration 173, loss = 0.08865478
# Iteration 174, loss = 0.08822638
# Iteration 175, loss = 0.08783499
# Iteration 176, loss = 0.08739259
# Iteration 177, loss = 0.08700378
# Iteration 178, loss = 0.08662613
# Iteration 179, loss = 0.08625482
# Iteration 180, loss = 0.08583771
# Iteration 181, loss = 0.08547333
# Iteration 182, loss = 0.08510558
# Iteration 183, loss = 0.08474416
# Iteration 184, loss = 0.08437571
# Iteration 185, loss = 0.08404706
# Iteration 186, loss = 0.08365018
# Iteration 187, loss = 0.08331768
# Iteration 188, loss = 0.08298299
# Iteration 189, loss = 0.08259970
# Iteration 190, loss = 0.08227144
# Iteration 191, loss = 0.08193353
# Iteration 192, loss = 0.08158149
# Iteration 193, loss = 0.08126684
# Iteration 194, loss = 0.08096884
# Iteration 195, loss = 0.08063336
# Iteration 196, loss = 0.08031068
# Iteration 197, loss = 0.07998108
# Iteration 198, loss = 0.07966879
# Iteration 199, loss = 0.07937534
# Iteration 200, loss = 0.07906011
# Iteration 201, loss = 0.07872257
# Iteration 202, loss = 0.07844066
# Iteration 203, loss = 0.07813289
# Iteration 204, loss = 0.07784069
# Iteration 205, loss = 0.07756156
# Iteration 206, loss = 0.07727628
# Iteration 207, loss = 0.07697313
# Iteration 208, loss = 0.07670015
# Iteration 209, loss = 0.07644639
# Iteration 210, loss = 0.07615753
# Iteration 211, loss = 0.07587767
# Iteration 212, loss = 0.07561131
# Iteration 213, loss = 0.07531800
# Iteration 214, loss = 0.07506585
# Iteration 215, loss = 0.07479831
# Iteration 216, loss = 0.07457093
# Iteration 217, loss = 0.07429530
# Iteration 218, loss = 0.07403076
# Iteration 219, loss = 0.07376524
# Iteration 220, loss = 0.07351425
# Iteration 221, loss = 0.07326692
# Iteration 222, loss = 0.07304345
# Iteration 223, loss = 0.07284444
# Iteration 224, loss = 0.07259958
# Iteration 225, loss = 0.07233230
# Iteration 226, loss = 0.07210279
# Iteration 227, loss = 0.07184615
# Iteration 228, loss = 0.07163607
# Iteration 229, loss = 0.07139442
# Iteration 230, loss = 0.07119027
# Iteration 231, loss = 0.07097292
# Iteration 232, loss = 0.07071574
# Iteration 233, loss = 0.07053322
# Iteration 234, loss = 0.07030354
# Iteration 235, loss = 0.07007518
# Iteration 236, loss = 0.06989520
# Iteration 237, loss = 0.06965865
# Iteration 238, loss = 0.06949538
# Iteration 239, loss = 0.06924447
# Iteration 240, loss = 0.06905279
# Iteration 241, loss = 0.06885639
# Iteration 242, loss = 0.06867675
# Iteration 243, loss = 0.06848358
# Iteration 244, loss = 0.06825683
# Iteration 245, loss = 0.06810236
# Iteration 246, loss = 0.06788244
# Iteration 247, loss = 0.06769657
# Iteration 248, loss = 0.06750055
# Iteration 249, loss = 0.06733334
# Iteration 250, loss = 0.06717270
# Iteration 251, loss = 0.06696461
# Iteration 252, loss = 0.06678612
# Iteration 253, loss = 0.06660271
# Iteration 254, loss = 0.06640824
# Iteration 255, loss = 0.06627031
# Iteration 256, loss = 0.06607559
# Iteration 257, loss = 0.06589626
# Iteration 258, loss = 0.06573764
# Iteration 259, loss = 0.06556864
# Iteration 260, loss = 0.06540874
# Iteration 261, loss = 0.06524634
# Iteration 262, loss = 0.06509291
# Iteration 263, loss = 0.06494358
# Iteration 264, loss = 0.06476833
# Iteration 265, loss = 0.06462489
# Iteration 266, loss = 0.06448462
# Iteration 267, loss = 0.06429759
# Iteration 268, loss = 0.06414309
# Iteration 269, loss = 0.06400159
# Iteration 270, loss = 0.06391007
# Iteration 271, loss = 0.06370132
# Iteration 272, loss = 0.06354926
# Iteration 273, loss = 0.06341326
# Iteration 274, loss = 0.06327672
# Iteration 275, loss = 0.06312566
# Iteration 276, loss = 0.06300055
# Iteration 277, loss = 0.06287994
# Iteration 278, loss = 0.06271409
# Iteration 279, loss = 0.06256398
# Iteration 280, loss = 0.06244674
# Iteration 281, loss = 0.06232463
# Iteration 282, loss = 0.06217713
# Iteration 283, loss = 0.06204225
# Iteration 284, loss = 0.06192262
# Iteration 285, loss = 0.06180152
# Iteration 286, loss = 0.06165830
# Iteration 287, loss = 0.06155022
# Iteration 288, loss = 0.06141560
# Iteration 289, loss = 0.06128567
# Iteration 290, loss = 0.06115171
# Iteration 291, loss = 0.06102665
# Iteration 292, loss = 0.06089465
# Iteration 293, loss = 0.06078877
# Iteration 294, loss = 0.06067503
# Iteration 295, loss = 0.06054645
# Iteration 296, loss = 0.06043653
# Iteration 297, loss = 0.06034887
# Iteration 298, loss = 0.06021654
# Iteration 299, loss = 0.06008279
# Iteration 300, loss = 0.05995910
# Iteration 301, loss = 0.05984962
# Iteration 302, loss = 0.05973308
# Iteration 303, loss = 0.05962308
# Iteration 304, loss = 0.05951223
# Iteration 305, loss = 0.05941223
# Iteration 306, loss = 0.05928511
# Iteration 307, loss = 0.05917186
# Iteration 308, loss = 0.05907953
# Iteration 309, loss = 0.05899343
# Iteration 310, loss = 0.05887806
# Iteration 311, loss = 0.05877716
# Iteration 312, loss = 0.05866197
# Iteration 313, loss = 0.05854964
# Iteration 314, loss = 0.05843853
# Iteration 315, loss = 0.05834905
# Iteration 316, loss = 0.05824327
# Iteration 317, loss = 0.05813992
# Iteration 318, loss = 0.05804471
# Iteration 319, loss = 0.05793177
# Iteration 320, loss = 0.05784457
# Iteration 321, loss = 0.05774254
# Iteration 322, loss = 0.05765270
# Iteration 323, loss = 0.05758510
# Iteration 324, loss = 0.05744549
# Iteration 325, loss = 0.05735150
# Iteration 326, loss = 0.05726738
# Iteration 327, loss = 0.05716458
# Iteration 328, loss = 0.05706943
# Iteration 329, loss = 0.05696671
# Iteration 330, loss = 0.05689003
# Iteration 331, loss = 0.05677377
# Iteration 332, loss = 0.05669187
# Iteration 333, loss = 0.05660846
# Iteration 334, loss = 0.05650132
# Iteration 335, loss = 0.05641573
# Iteration 336, loss = 0.05634432
# Iteration 337, loss = 0.05623976
# Iteration 338, loss = 0.05617593
# Iteration 339, loss = 0.05611827
# Iteration 340, loss = 0.05600197
# Iteration 341, loss = 0.05590331
# Iteration 342, loss = 0.05581069
# Iteration 343, loss = 0.05575878
# Iteration 344, loss = 0.05563664
# Iteration 345, loss = 0.05558068
# Iteration 346, loss = 0.05548879
# Iteration 347, loss = 0.05542762
# Iteration 348, loss = 0.05531898
# Iteration 349, loss = 0.05526597
# Iteration 350, loss = 0.05516912
# Iteration 351, loss = 0.05511896
# Iteration 352, loss = 0.05500443
# Iteration 353, loss = 0.05493987
# Iteration 354, loss = 0.05487664
# Iteration 355, loss = 0.05479844
# Iteration 356, loss = 0.05472073
# Iteration 357, loss = 0.05464708
# Iteration 358, loss = 0.05455442
# Iteration 359, loss = 0.05446158
# Iteration 360, loss = 0.05440063
# Iteration 361, loss = 0.05430932
# Iteration 362, loss = 0.05424809
# Iteration 363, loss = 0.05419061
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Iteration 1, loss = 0.64509312
# Iteration 2, loss = 0.63392343
# Iteration 3, loss = 0.62311019
# Iteration 4, loss = 0.61294454
# Iteration 5, loss = 0.60270292
# Iteration 6, loss = 0.59281531
# Iteration 7, loss = 0.58334918
# Iteration 8, loss = 0.57395016
# Iteration 9, loss = 0.56490011
# Iteration 10, loss = 0.55597333
# Iteration 11, loss = 0.54702924
# Iteration 12, loss = 0.53853663
# Iteration 13, loss = 0.53002164
# Iteration 14, loss = 0.52158308
# Iteration 15, loss = 0.51377173
# Iteration 16, loss = 0.50542508
# Iteration 17, loss = 0.49766426
# Iteration 18, loss = 0.48982567
# Iteration 19, loss = 0.48197618
# Iteration 20, loss = 0.47436179
# Iteration 21, loss = 0.46676488
# Iteration 22, loss = 0.45920342
# Iteration 23, loss = 0.45175519
# Iteration 24, loss = 0.44455008
# Iteration 25, loss = 0.43722556
# Iteration 26, loss = 0.43005189
# Iteration 27, loss = 0.42308740
# Iteration 28, loss = 0.41619216
# Iteration 29, loss = 0.40933713
# Iteration 30, loss = 0.40251192
# Iteration 31, loss = 0.39577877
# Iteration 32, loss = 0.38938328
# Iteration 33, loss = 0.38293083
# Iteration 34, loss = 0.37643371
# Iteration 35, loss = 0.37032755
# Iteration 36, loss = 0.36416662
# Iteration 37, loss = 0.35807051
# Iteration 38, loss = 0.35222646
# Iteration 39, loss = 0.34632001
# Iteration 40, loss = 0.34075188
# Iteration 41, loss = 0.33519948
# Iteration 42, loss = 0.32975870
# Iteration 43, loss = 0.32436550
# Iteration 44, loss = 0.31916927
# Iteration 45, loss = 0.31402280
# Iteration 46, loss = 0.30894694
# Iteration 47, loss = 0.30398605
# Iteration 48, loss = 0.29920968
# Iteration 49, loss = 0.29448823
# Iteration 50, loss = 0.28984253
# Iteration 51, loss = 0.28535189
# Iteration 52, loss = 0.28087639
# Iteration 53, loss = 0.27653216
# Iteration 54, loss = 0.27225683
# Iteration 55, loss = 0.26806384
# Iteration 56, loss = 0.26409060
# Iteration 57, loss = 0.26005118
# Iteration 58, loss = 0.25612578
# Iteration 59, loss = 0.25244098
# Iteration 60, loss = 0.24863271
# Iteration 61, loss = 0.24493696
# Iteration 62, loss = 0.24138956
# Iteration 63, loss = 0.23796119
# Iteration 64, loss = 0.23455625
# Iteration 65, loss = 0.23123988
# Iteration 66, loss = 0.22803561
# Iteration 67, loss = 0.22484400
# Iteration 68, loss = 0.22172120
# Iteration 69, loss = 0.21874568
# Iteration 70, loss = 0.21579423
# Iteration 71, loss = 0.21288636
# Iteration 72, loss = 0.21014738
# Iteration 73, loss = 0.20740612
# Iteration 74, loss = 0.20471322
# Iteration 75, loss = 0.20208509
# Iteration 76, loss = 0.19950260
# Iteration 77, loss = 0.19697080
# Iteration 78, loss = 0.19454760
# Iteration 79, loss = 0.19213929
# Iteration 80, loss = 0.18983813
# Iteration 81, loss = 0.18748211
# Iteration 82, loss = 0.18529671
# Iteration 83, loss = 0.18309901
# Iteration 84, loss = 0.18097999
# Iteration 85, loss = 0.17889291
# Iteration 86, loss = 0.17674501
# Iteration 87, loss = 0.17477554
# Iteration 88, loss = 0.17279574
# Iteration 89, loss = 0.17082134
# Iteration 90, loss = 0.16893028
# Iteration 91, loss = 0.16703882
# Iteration 92, loss = 0.16513993
# Iteration 93, loss = 0.16340107
# Iteration 94, loss = 0.16156332
# Iteration 95, loss = 0.15981659
# Iteration 96, loss = 0.15811637
# Iteration 97, loss = 0.15646492
# Iteration 98, loss = 0.15483930
# Iteration 99, loss = 0.15315641
# Iteration 100, loss = 0.15171805
# Iteration 101, loss = 0.15007298
# Iteration 102, loss = 0.14853172
# Iteration 103, loss = 0.14714115
# Iteration 104, loss = 0.14564304
# Iteration 105, loss = 0.14425419
# Iteration 106, loss = 0.14282311
# Iteration 107, loss = 0.14150470
# Iteration 108, loss = 0.14017585
# Iteration 109, loss = 0.13888535
# Iteration 110, loss = 0.13759893
# Iteration 111, loss = 0.13638114
# Iteration 112, loss = 0.13510236
# Iteration 113, loss = 0.13387284
# Iteration 114, loss = 0.13272715
# Iteration 115, loss = 0.13159372
# Iteration 116, loss = 0.13040760
# Iteration 117, loss = 0.12928218
# Iteration 118, loss = 0.12818159
# Iteration 119, loss = 0.12713674
# Iteration 120, loss = 0.12604336
# Iteration 121, loss = 0.12500860
# Iteration 122, loss = 0.12400493
# Iteration 123, loss = 0.12300033
# Iteration 124, loss = 0.12195703
# Iteration 125, loss = 0.12096628
# Iteration 126, loss = 0.12007960
# Iteration 127, loss = 0.11907690
# Iteration 128, loss = 0.11815276
# Iteration 129, loss = 0.11724340
# Iteration 130, loss = 0.11638223
# Iteration 131, loss = 0.11550354
# Iteration 132, loss = 0.11468143
# Iteration 133, loss = 0.11383502
# Iteration 134, loss = 0.11302533
# Iteration 135, loss = 0.11222424
# Iteration 136, loss = 0.11140118
# Iteration 137, loss = 0.11063435
# Iteration 138, loss = 0.10990475
# Iteration 139, loss = 0.10913331
# Iteration 140, loss = 0.10841362
# Iteration 141, loss = 0.10770698
# Iteration 142, loss = 0.10699183
# Iteration 143, loss = 0.10626942
# Iteration 144, loss = 0.10559322
# Iteration 145, loss = 0.10487014
# Iteration 146, loss = 0.10426329
# Iteration 147, loss = 0.10361459
# Iteration 148, loss = 0.10291645
# Iteration 149, loss = 0.10231099
# Iteration 150, loss = 0.10169636
# Iteration 151, loss = 0.10109135
# Iteration 152, loss = 0.10048026
# Iteration 153, loss = 0.09989530
# Iteration 154, loss = 0.09930235
# Iteration 155, loss = 0.09871749
# Iteration 156, loss = 0.09814622
# Iteration 157, loss = 0.09760792
# Iteration 158, loss = 0.09703343
# Iteration 159, loss = 0.09651329
# Iteration 160, loss = 0.09598728
# Iteration 161, loss = 0.09545424
# Iteration 162, loss = 0.09495625
# Iteration 163, loss = 0.09440859
# Iteration 164, loss = 0.09396006
# Iteration 165, loss = 0.09341716
# Iteration 166, loss = 0.09296263
# Iteration 167, loss = 0.09246391
# Iteration 168, loss = 0.09198549
# Iteration 169, loss = 0.09150485
# Iteration 170, loss = 0.09104630
# Iteration 171, loss = 0.09055741
# Iteration 172, loss = 0.09011320
# Iteration 173, loss = 0.08968964
# Iteration 174, loss = 0.08925383
# Iteration 175, loss = 0.08883577
# Iteration 176, loss = 0.08837545
# Iteration 177, loss = 0.08797462
# Iteration 178, loss = 0.08755828
# Iteration 179, loss = 0.08717510
# Iteration 180, loss = 0.08674057
# Iteration 181, loss = 0.08635082
# Iteration 182, loss = 0.08595840
# Iteration 183, loss = 0.08557596
# Iteration 184, loss = 0.08520789
# Iteration 185, loss = 0.08487068
# Iteration 186, loss = 0.08446837
# Iteration 187, loss = 0.08411454
# Iteration 188, loss = 0.08375826
# Iteration 189, loss = 0.08340919
# Iteration 190, loss = 0.08306142
# Iteration 191, loss = 0.08272270
# Iteration 192, loss = 0.08237575
# Iteration 193, loss = 0.08205559
# Iteration 194, loss = 0.08173793
# Iteration 195, loss = 0.08142086
# Iteration 196, loss = 0.08109320
# Iteration 197, loss = 0.08075329
# Iteration 198, loss = 0.08046849
# Iteration 199, loss = 0.08014803
# Iteration 200, loss = 0.07984426
# Iteration 201, loss = 0.07954931
# Iteration 202, loss = 0.07926870
# Iteration 203, loss = 0.07896396
# Iteration 204, loss = 0.07867322
# Iteration 205, loss = 0.07841604
# Iteration 206, loss = 0.07811308
# Iteration 207, loss = 0.07782156
# Iteration 208, loss = 0.07756635
# Iteration 209, loss = 0.07732061
# Iteration 210, loss = 0.07701219
# Iteration 211, loss = 0.07675927
# Iteration 212, loss = 0.07649967
# Iteration 213, loss = 0.07623132
# Iteration 214, loss = 0.07595628
# Iteration 215, loss = 0.07569168
# Iteration 216, loss = 0.07545235
# Iteration 217, loss = 0.07521347
# Iteration 218, loss = 0.07493843
# Iteration 219, loss = 0.07470112
# Iteration 220, loss = 0.07444343
# Iteration 221, loss = 0.07419915
# Iteration 222, loss = 0.07399803
# Iteration 223, loss = 0.07373539
# Iteration 224, loss = 0.07355004
# Iteration 225, loss = 0.07328186
# Iteration 226, loss = 0.07303917
# Iteration 227, loss = 0.07281109
# Iteration 228, loss = 0.07257821
# Iteration 229, loss = 0.07235870
# Iteration 230, loss = 0.07217078
# Iteration 231, loss = 0.07193803
# Iteration 232, loss = 0.07170845
# Iteration 233, loss = 0.07148445
# Iteration 234, loss = 0.07126313
# Iteration 235, loss = 0.07107355
# Iteration 236, loss = 0.07091751
# Iteration 237, loss = 0.07065468
# Iteration 238, loss = 0.07045575
# Iteration 239, loss = 0.07022868
# Iteration 240, loss = 0.07003735
# Iteration 241, loss = 0.06985402
# Iteration 242, loss = 0.06966446
# Iteration 243, loss = 0.06946130
# Iteration 244, loss = 0.06924108
# Iteration 245, loss = 0.06907942
# Iteration 246, loss = 0.06886370
# Iteration 247, loss = 0.06869271
# Iteration 248, loss = 0.06849978
# Iteration 249, loss = 0.06834487
# Iteration 250, loss = 0.06813621
# Iteration 251, loss = 0.06795258
# Iteration 252, loss = 0.06780640
# Iteration 253, loss = 0.06760833
# Iteration 254, loss = 0.06742684
# Iteration 255, loss = 0.06726445
# Iteration 256, loss = 0.06708127
# Iteration 257, loss = 0.06691840
# Iteration 258, loss = 0.06674171
# Iteration 259, loss = 0.06657062
# Iteration 260, loss = 0.06643286
# Iteration 261, loss = 0.06624816
# Iteration 262, loss = 0.06606536
# Iteration 263, loss = 0.06594222
# Iteration 264, loss = 0.06575092
# Iteration 265, loss = 0.06557505
# Iteration 266, loss = 0.06543267
# Iteration 267, loss = 0.06526064
# Iteration 268, loss = 0.06512158
# Iteration 269, loss = 0.06496264
# Iteration 270, loss = 0.06487969
# Iteration 271, loss = 0.06466607
# Iteration 272, loss = 0.06452768
# Iteration 273, loss = 0.06438371
# Iteration 274, loss = 0.06425636
# Iteration 275, loss = 0.06411586
# Iteration 276, loss = 0.06397547
# Iteration 277, loss = 0.06389417
# Iteration 278, loss = 0.06371371
# Iteration 279, loss = 0.06360649
# Iteration 280, loss = 0.06344375
# Iteration 281, loss = 0.06329576
# Iteration 282, loss = 0.06321055
# Iteration 283, loss = 0.06303197
# Iteration 284, loss = 0.06293303
# Iteration 285, loss = 0.06278430
# Iteration 286, loss = 0.06265070
# Iteration 287, loss = 0.06254606
# Iteration 288, loss = 0.06242399
# Iteration 289, loss = 0.06229287
# Iteration 290, loss = 0.06218004
# Iteration 291, loss = 0.06204188
# Iteration 292, loss = 0.06191840
# Iteration 293, loss = 0.06180469
# Iteration 294, loss = 0.06168756
# Iteration 295, loss = 0.06156526
# Iteration 296, loss = 0.06145198
# Iteration 297, loss = 0.06135997
# Iteration 298, loss = 0.06122979
# Iteration 299, loss = 0.06110654
# Iteration 300, loss = 0.06099439
# Iteration 301, loss = 0.06088827
# Iteration 302, loss = 0.06077727
# Iteration 303, loss = 0.06066903
# Iteration 304, loss = 0.06054737
# Iteration 305, loss = 0.06044811
# Iteration 306, loss = 0.06032882
# Iteration 307, loss = 0.06023645
# Iteration 308, loss = 0.06014332
# Iteration 309, loss = 0.06003319
# Iteration 310, loss = 0.05994547
# Iteration 311, loss = 0.05981772
# Iteration 312, loss = 0.05971080
# Iteration 313, loss = 0.05960691
# Iteration 314, loss = 0.05952948
# Iteration 315, loss = 0.05941137
# Iteration 316, loss = 0.05930081
# Iteration 317, loss = 0.05921216
# Iteration 318, loss = 0.05912595
# Iteration 319, loss = 0.05901463
# Iteration 320, loss = 0.05891529
# Iteration 321, loss = 0.05883349
# Iteration 322, loss = 0.05873818
# Iteration 323, loss = 0.05867016
# Iteration 324, loss = 0.05854206
# Iteration 325, loss = 0.05844390
# Iteration 326, loss = 0.05837922
# Iteration 327, loss = 0.05827432
# Iteration 328, loss = 0.05819509
# Iteration 329, loss = 0.05808777
# Iteration 330, loss = 0.05803843
# Iteration 331, loss = 0.05790779
# Iteration 332, loss = 0.05783235
# Iteration 333, loss = 0.05776450
# Iteration 334, loss = 0.05765601
# Iteration 335, loss = 0.05756244
# Iteration 336, loss = 0.05748792
# Iteration 337, loss = 0.05739353
# Iteration 338, loss = 0.05732594
# Iteration 339, loss = 0.05727028
# Iteration 340, loss = 0.05713355
# Iteration 341, loss = 0.05705418
# Iteration 342, loss = 0.05698505
# Iteration 343, loss = 0.05691039
# Iteration 344, loss = 0.05682217
# Iteration 345, loss = 0.05674064
# Iteration 346, loss = 0.05667929
# Iteration 347, loss = 0.05656277
# Iteration 348, loss = 0.05648869
# Iteration 349, loss = 0.05640000
# Iteration 350, loss = 0.05635503
# Iteration 351, loss = 0.05624790
# Iteration 352, loss = 0.05616558
# Iteration 353, loss = 0.05609201
# Iteration 354, loss = 0.05602035
# Iteration 355, loss = 0.05596091
# Iteration 356, loss = 0.05586099
# Iteration 357, loss = 0.05579428
# Iteration 358, loss = 0.05570104
# Iteration 359, loss = 0.05563661
# Iteration 360, loss = 0.05556752
# Iteration 361, loss = 0.05549824
# Iteration 362, loss = 0.05541957
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Iteration 1, loss = 0.63079801
# Iteration 2, loss = 0.61966589
# Iteration 3, loss = 0.60918079
# Iteration 4, loss = 0.59909234
# Iteration 5, loss = 0.58919044
# Iteration 6, loss = 0.57936453
# Iteration 7, loss = 0.56994333
# Iteration 8, loss = 0.56087887
# Iteration 9, loss = 0.55190311
# Iteration 10, loss = 0.54299975
# Iteration 11, loss = 0.53418145
# Iteration 12, loss = 0.52588953
# Iteration 13, loss = 0.51729730
# Iteration 14, loss = 0.50882783
# Iteration 15, loss = 0.50098206
# Iteration 16, loss = 0.49255945
# Iteration 17, loss = 0.48461673
# Iteration 18, loss = 0.47671637
# Iteration 19, loss = 0.46874897
# Iteration 20, loss = 0.46109872
# Iteration 21, loss = 0.45340163
# Iteration 22, loss = 0.44595893
# Iteration 23, loss = 0.43843849
# Iteration 24, loss = 0.43126986
# Iteration 25, loss = 0.42389203
# Iteration 26, loss = 0.41689770
# Iteration 27, loss = 0.40992398
# Iteration 28, loss = 0.40319812
# Iteration 29, loss = 0.39648317
# Iteration 30, loss = 0.38984756
# Iteration 31, loss = 0.38319970
# Iteration 32, loss = 0.37685123
# Iteration 33, loss = 0.37066118
# Iteration 34, loss = 0.36437209
# Iteration 35, loss = 0.35833270
# Iteration 36, loss = 0.35230238
# Iteration 37, loss = 0.34646160
# Iteration 38, loss = 0.34069525
# Iteration 39, loss = 0.33494093
# Iteration 40, loss = 0.32947068
# Iteration 41, loss = 0.32391087
# Iteration 42, loss = 0.31863498
# Iteration 43, loss = 0.31324333
# Iteration 44, loss = 0.30810185
# Iteration 45, loss = 0.30302509
# Iteration 46, loss = 0.29805003
# Iteration 47, loss = 0.29316419
# Iteration 48, loss = 0.28842213
# Iteration 49, loss = 0.28381412
# Iteration 50, loss = 0.27919817
# Iteration 51, loss = 0.27480197
# Iteration 52, loss = 0.27033758
# Iteration 53, loss = 0.26609483
# Iteration 54, loss = 0.26187578
# Iteration 55, loss = 0.25778325
# Iteration 56, loss = 0.25377898
# Iteration 57, loss = 0.24985297
# Iteration 58, loss = 0.24599420
# Iteration 59, loss = 0.24238113
# Iteration 60, loss = 0.23866126
# Iteration 61, loss = 0.23510623
# Iteration 62, loss = 0.23160702
# Iteration 63, loss = 0.22824282
# Iteration 64, loss = 0.22493859
# Iteration 65, loss = 0.22168649
# Iteration 66, loss = 0.21852533
# Iteration 67, loss = 0.21541260
# Iteration 68, loss = 0.21236833
# Iteration 69, loss = 0.20946721
# Iteration 70, loss = 0.20654622
# Iteration 71, loss = 0.20372202
# Iteration 72, loss = 0.20101864
# Iteration 73, loss = 0.19834578
# Iteration 74, loss = 0.19569941
# Iteration 75, loss = 0.19314936
# Iteration 76, loss = 0.19064837
# Iteration 77, loss = 0.18819231
# Iteration 78, loss = 0.18584307
# Iteration 79, loss = 0.18348735
# Iteration 80, loss = 0.18124227
# Iteration 81, loss = 0.17902342
# Iteration 82, loss = 0.17685069
# Iteration 83, loss = 0.17474904
# Iteration 84, loss = 0.17272689
# Iteration 85, loss = 0.17071637
# Iteration 86, loss = 0.16868944
# Iteration 87, loss = 0.16682652
# Iteration 88, loss = 0.16495218
# Iteration 89, loss = 0.16304053
# Iteration 90, loss = 0.16124241
# Iteration 91, loss = 0.15948906
# Iteration 92, loss = 0.15769324
# Iteration 93, loss = 0.15604000
# Iteration 94, loss = 0.15432201
# Iteration 95, loss = 0.15269267
# Iteration 96, loss = 0.15108502
# Iteration 97, loss = 0.14953115
# Iteration 98, loss = 0.14802105
# Iteration 99, loss = 0.14648460
# Iteration 100, loss = 0.14510133
# Iteration 101, loss = 0.14357262
# Iteration 102, loss = 0.14214981
# Iteration 103, loss = 0.14080966
# Iteration 104, loss = 0.13942062
# Iteration 105, loss = 0.13814487
# Iteration 106, loss = 0.13676469
# Iteration 107, loss = 0.13551249
# Iteration 108, loss = 0.13425837
# Iteration 109, loss = 0.13301049
# Iteration 110, loss = 0.13177091
# Iteration 111, loss = 0.13058499
# Iteration 112, loss = 0.12937584
# Iteration 113, loss = 0.12819156
# Iteration 114, loss = 0.12710095
# Iteration 115, loss = 0.12601745
# Iteration 116, loss = 0.12487764
# Iteration 117, loss = 0.12378936
# Iteration 118, loss = 0.12272904
# Iteration 119, loss = 0.12177348
# Iteration 120, loss = 0.12074262
# Iteration 121, loss = 0.11976118
# Iteration 122, loss = 0.11880348
# Iteration 123, loss = 0.11786922
# Iteration 124, loss = 0.11693152
# Iteration 125, loss = 0.11600010
# Iteration 126, loss = 0.11518643
# Iteration 127, loss = 0.11426058
# Iteration 128, loss = 0.11340128
# Iteration 129, loss = 0.11255228
# Iteration 130, loss = 0.11172888
# Iteration 131, loss = 0.11091396
# Iteration 132, loss = 0.11011711
# Iteration 133, loss = 0.10929858
# Iteration 134, loss = 0.10852073
# Iteration 135, loss = 0.10777369
# Iteration 136, loss = 0.10696984
# Iteration 137, loss = 0.10622312
# Iteration 138, loss = 0.10550792
# Iteration 139, loss = 0.10475129
# Iteration 140, loss = 0.10405102
# Iteration 141, loss = 0.10335337
# Iteration 142, loss = 0.10264645
# Iteration 143, loss = 0.10196428
# Iteration 144, loss = 0.10132127
# Iteration 145, loss = 0.10064545
# Iteration 146, loss = 0.10001442
# Iteration 147, loss = 0.09941847
# Iteration 148, loss = 0.09875586
# Iteration 149, loss = 0.09817106
# Iteration 150, loss = 0.09759113
# Iteration 151, loss = 0.09700609
# Iteration 152, loss = 0.09642461
# Iteration 153, loss = 0.09583339
# Iteration 154, loss = 0.09529494
# Iteration 155, loss = 0.09472456
# Iteration 156, loss = 0.09417898
# Iteration 157, loss = 0.09365669
# Iteration 158, loss = 0.09310842
# Iteration 159, loss = 0.09261191
# Iteration 160, loss = 0.09210108
# Iteration 161, loss = 0.09158350
# Iteration 162, loss = 0.09112052
# Iteration 163, loss = 0.09058744
# Iteration 164, loss = 0.09015675
# Iteration 165, loss = 0.08963490
# Iteration 166, loss = 0.08922056
# Iteration 167, loss = 0.08875431
# Iteration 168, loss = 0.08831648
# Iteration 169, loss = 0.08785348
# Iteration 170, loss = 0.08741835
# Iteration 171, loss = 0.08697079
# Iteration 172, loss = 0.08655348
# Iteration 173, loss = 0.08616189
# Iteration 174, loss = 0.08577565
# Iteration 175, loss = 0.08537643
# Iteration 176, loss = 0.08493963
# Iteration 177, loss = 0.08457062
# Iteration 178, loss = 0.08417520
# Iteration 179, loss = 0.08382365
# Iteration 180, loss = 0.08342475
# Iteration 181, loss = 0.08304709
# Iteration 182, loss = 0.08268442
# Iteration 183, loss = 0.08235188
# Iteration 184, loss = 0.08198456
# Iteration 185, loss = 0.08165567
# Iteration 186, loss = 0.08129296
# Iteration 187, loss = 0.08096070
# Iteration 188, loss = 0.08063831
# Iteration 189, loss = 0.08029271
# Iteration 190, loss = 0.07996306
# Iteration 191, loss = 0.07964421
# Iteration 192, loss = 0.07930330
# Iteration 193, loss = 0.07898014
# Iteration 194, loss = 0.07869692
# Iteration 195, loss = 0.07839131
# Iteration 196, loss = 0.07808921
# Iteration 197, loss = 0.07776162
# Iteration 198, loss = 0.07746850
# Iteration 199, loss = 0.07717205
# Iteration 200, loss = 0.07687071
# Iteration 201, loss = 0.07658594
# Iteration 202, loss = 0.07629726
# Iteration 203, loss = 0.07600086
# Iteration 204, loss = 0.07572413
# Iteration 205, loss = 0.07547788
# Iteration 206, loss = 0.07518769
# Iteration 207, loss = 0.07489792
# Iteration 208, loss = 0.07466512
# Iteration 209, loss = 0.07437998
# Iteration 210, loss = 0.07410169
# Iteration 211, loss = 0.07383006
# Iteration 212, loss = 0.07360548
# Iteration 213, loss = 0.07333096
# Iteration 214, loss = 0.07305674
# Iteration 215, loss = 0.07280759
# Iteration 216, loss = 0.07257224
# Iteration 217, loss = 0.07233249
# Iteration 218, loss = 0.07206659
# Iteration 219, loss = 0.07181864
# Iteration 220, loss = 0.07157594
# Iteration 221, loss = 0.07133361
# Iteration 222, loss = 0.07113911
# Iteration 223, loss = 0.07085288
# Iteration 224, loss = 0.07066701
# Iteration 225, loss = 0.07041370
# Iteration 226, loss = 0.07015873
# Iteration 227, loss = 0.06992595
# Iteration 228, loss = 0.06968638
# Iteration 229, loss = 0.06946360
# Iteration 230, loss = 0.06928503
# Iteration 231, loss = 0.06905731
# Iteration 232, loss = 0.06883027
# Iteration 233, loss = 0.06862172
# Iteration 234, loss = 0.06839588
# Iteration 235, loss = 0.06819713
# Iteration 236, loss = 0.06803452
# Iteration 237, loss = 0.06776605
# Iteration 238, loss = 0.06757698
# Iteration 239, loss = 0.06737577
# Iteration 240, loss = 0.06717087
# Iteration 241, loss = 0.06697803
# Iteration 242, loss = 0.06680914
# Iteration 243, loss = 0.06662946
# Iteration 244, loss = 0.06640500
# Iteration 245, loss = 0.06623797
# Iteration 246, loss = 0.06603774
# Iteration 247, loss = 0.06586488
# Iteration 248, loss = 0.06567300
# Iteration 249, loss = 0.06550579
# Iteration 250, loss = 0.06531999
# Iteration 251, loss = 0.06514715
# Iteration 252, loss = 0.06498836
# Iteration 253, loss = 0.06480398
# Iteration 254, loss = 0.06462482
# Iteration 255, loss = 0.06445529
# Iteration 256, loss = 0.06428348
# Iteration 257, loss = 0.06415119
# Iteration 258, loss = 0.06396143
# Iteration 259, loss = 0.06376239
# Iteration 260, loss = 0.06362490
# Iteration 261, loss = 0.06345134
# Iteration 262, loss = 0.06327628
# Iteration 263, loss = 0.06313102
# Iteration 264, loss = 0.06295731
# Iteration 265, loss = 0.06277157
# Iteration 266, loss = 0.06263055
# Iteration 267, loss = 0.06245455
# Iteration 268, loss = 0.06230721
# Iteration 269, loss = 0.06214657
# Iteration 270, loss = 0.06202052
# Iteration 271, loss = 0.06183473
# Iteration 272, loss = 0.06168051
# Iteration 273, loss = 0.06154294
# Iteration 274, loss = 0.06138686
# Iteration 275, loss = 0.06125635
# Iteration 276, loss = 0.06109695
# Iteration 277, loss = 0.06102444
# Iteration 278, loss = 0.06082790
# Iteration 279, loss = 0.06068657
# Iteration 280, loss = 0.06057041
# Iteration 281, loss = 0.06038867
# Iteration 282, loss = 0.06030313
# Iteration 283, loss = 0.06011998
# Iteration 284, loss = 0.05999163
# Iteration 285, loss = 0.05983820
# Iteration 286, loss = 0.05971562
# Iteration 287, loss = 0.05959559
# Iteration 288, loss = 0.05945929
# Iteration 289, loss = 0.05932981
# Iteration 290, loss = 0.05921862
# Iteration 291, loss = 0.05907318
# Iteration 292, loss = 0.05894196
# Iteration 293, loss = 0.05881997
# Iteration 294, loss = 0.05869099
# Iteration 295, loss = 0.05856208
# Iteration 296, loss = 0.05844546
# Iteration 297, loss = 0.05836354
# Iteration 298, loss = 0.05821208
# Iteration 299, loss = 0.05809021
# Iteration 300, loss = 0.05796409
# Iteration 301, loss = 0.05786466
# Iteration 302, loss = 0.05773683
# Iteration 303, loss = 0.05761096
# Iteration 304, loss = 0.05748520
# Iteration 305, loss = 0.05739066
# Iteration 306, loss = 0.05727559
# Iteration 307, loss = 0.05715267
# Iteration 308, loss = 0.05704718
# Iteration 309, loss = 0.05694095
# Iteration 310, loss = 0.05683644
# Iteration 311, loss = 0.05670579
# Iteration 312, loss = 0.05659253
# Iteration 313, loss = 0.05648963
# Iteration 314, loss = 0.05638979
# Iteration 315, loss = 0.05627424
# Iteration 316, loss = 0.05615681
# Iteration 317, loss = 0.05608908
# Iteration 318, loss = 0.05596172
# Iteration 319, loss = 0.05585453
# Iteration 320, loss = 0.05575072
# Iteration 321, loss = 0.05566329
# Iteration 322, loss = 0.05555431
# Iteration 323, loss = 0.05547059
# Iteration 324, loss = 0.05534890
# Iteration 325, loss = 0.05526985
# Iteration 326, loss = 0.05518181
# Iteration 327, loss = 0.05506420
# Iteration 328, loss = 0.05497389
# Iteration 329, loss = 0.05488469
# Iteration 330, loss = 0.05480845
# Iteration 331, loss = 0.05468174
# Iteration 332, loss = 0.05461069
# Iteration 333, loss = 0.05455830
# Iteration 334, loss = 0.05441865
# Iteration 335, loss = 0.05432557
# Iteration 336, loss = 0.05423491
# Iteration 337, loss = 0.05415123
# Iteration 338, loss = 0.05406811
# Iteration 339, loss = 0.05399511
# Iteration 340, loss = 0.05388975
# Iteration 341, loss = 0.05378902
# Iteration 342, loss = 0.05372802
# Iteration 343, loss = 0.05364411
# Iteration 344, loss = 0.05355823
# Iteration 345, loss = 0.05346171
# Iteration 346, loss = 0.05339416
# Iteration 347, loss = 0.05329781
# Iteration 348, loss = 0.05320878
# Iteration 349, loss = 0.05312127
# Iteration 350, loss = 0.05303947
# Iteration 351, loss = 0.05298366
# Iteration 352, loss = 0.05288209
# Iteration 353, loss = 0.05279999
# Iteration 354, loss = 0.05273567
# Iteration 355, loss = 0.05264539
# Iteration 356, loss = 0.05256484
# Iteration 357, loss = 0.05249358
# Iteration 358, loss = 0.05240635
# Iteration 359, loss = 0.05233037
# Iteration 360, loss = 0.05225463
# Iteration 361, loss = 0.05218523
# Iteration 362, loss = 0.05211148
# Iteration 363, loss = 0.05204701
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Iteration 1, loss = 0.64459075
# Iteration 2, loss = 0.63279189
# Iteration 3, loss = 0.62212762
# Iteration 4, loss = 0.61138220
# Iteration 5, loss = 0.60101577
# Iteration 6, loss = 0.59089468
# Iteration 7, loss = 0.58099183
# Iteration 8, loss = 0.57175522
# Iteration 9, loss = 0.56241815
# Iteration 10, loss = 0.55355492
# Iteration 11, loss = 0.54445553
# Iteration 12, loss = 0.53586270
# Iteration 13, loss = 0.52705255
# Iteration 14, loss = 0.51869063
# Iteration 15, loss = 0.51036096
# Iteration 16, loss = 0.50195710
# Iteration 17, loss = 0.49387471
# Iteration 18, loss = 0.48593857
# Iteration 19, loss = 0.47786883
# Iteration 20, loss = 0.46990788
# Iteration 21, loss = 0.46217769
# Iteration 22, loss = 0.45447710
# Iteration 23, loss = 0.44694182
# Iteration 24, loss = 0.43936796
# Iteration 25, loss = 0.43200367
# Iteration 26, loss = 0.42477831
# Iteration 27, loss = 0.41747709
# Iteration 28, loss = 0.41048846
# Iteration 29, loss = 0.40332815
# Iteration 30, loss = 0.39659435
# Iteration 31, loss = 0.38987605
# Iteration 32, loss = 0.38313334
# Iteration 33, loss = 0.37670048
# Iteration 34, loss = 0.37018855
# Iteration 35, loss = 0.36382609
# Iteration 36, loss = 0.35760738
# Iteration 37, loss = 0.35141546
# Iteration 38, loss = 0.34541071
# Iteration 39, loss = 0.33961721
# Iteration 40, loss = 0.33389783
# Iteration 41, loss = 0.32815846
# Iteration 42, loss = 0.32265909
# Iteration 43, loss = 0.31717622
# Iteration 44, loss = 0.31193226
# Iteration 45, loss = 0.30673889
# Iteration 46, loss = 0.30165135
# Iteration 47, loss = 0.29674582
# Iteration 48, loss = 0.29189709
# Iteration 49, loss = 0.28714542
# Iteration 50, loss = 0.28245049
# Iteration 51, loss = 0.27802874
# Iteration 52, loss = 0.27354532
# Iteration 53, loss = 0.26927305
# Iteration 54, loss = 0.26504690
# Iteration 55, loss = 0.26094457
# Iteration 56, loss = 0.25689247
# Iteration 57, loss = 0.25305491
# Iteration 58, loss = 0.24917847
# Iteration 59, loss = 0.24548365
# Iteration 60, loss = 0.24187898
# Iteration 61, loss = 0.23828512
# Iteration 62, loss = 0.23492046
# Iteration 63, loss = 0.23156915
# Iteration 64, loss = 0.22818110
# Iteration 65, loss = 0.22501910
# Iteration 66, loss = 0.22184255
# Iteration 67, loss = 0.21876768
# Iteration 68, loss = 0.21581568
# Iteration 69, loss = 0.21278563
# Iteration 70, loss = 0.20992732
# Iteration 71, loss = 0.20707347
# Iteration 72, loss = 0.20431814
# Iteration 73, loss = 0.20161078
# Iteration 74, loss = 0.19896191
# Iteration 75, loss = 0.19641202
# Iteration 76, loss = 0.19384870
# Iteration 77, loss = 0.19137623
# Iteration 78, loss = 0.18897418
# Iteration 79, loss = 0.18662012
# Iteration 80, loss = 0.18428517
# Iteration 81, loss = 0.18208272
# Iteration 82, loss = 0.17989451
# Iteration 83, loss = 0.17780786
# Iteration 84, loss = 0.17570105
# Iteration 85, loss = 0.17370686
# Iteration 86, loss = 0.17176135
# Iteration 87, loss = 0.16978604
# Iteration 88, loss = 0.16790489
# Iteration 89, loss = 0.16611349
# Iteration 90, loss = 0.16428257
# Iteration 91, loss = 0.16251430
# Iteration 92, loss = 0.16078835
# Iteration 93, loss = 0.15910714
# Iteration 94, loss = 0.15742153
# Iteration 95, loss = 0.15581548
# Iteration 96, loss = 0.15418845
# Iteration 97, loss = 0.15265511
# Iteration 98, loss = 0.15108188
# Iteration 99, loss = 0.14957507
# Iteration 100, loss = 0.14816763
# Iteration 101, loss = 0.14663651
# Iteration 102, loss = 0.14522084
# Iteration 103, loss = 0.14382076
# Iteration 104, loss = 0.14248978
# Iteration 105, loss = 0.14118268
# Iteration 106, loss = 0.13987216
# Iteration 107, loss = 0.13858333
# Iteration 108, loss = 0.13736052
# Iteration 109, loss = 0.13615684
# Iteration 110, loss = 0.13490793
# Iteration 111, loss = 0.13375170
# Iteration 112, loss = 0.13258021
# Iteration 113, loss = 0.13153976
# Iteration 114, loss = 0.13036541
# Iteration 115, loss = 0.12928037
# Iteration 116, loss = 0.12818885
# Iteration 117, loss = 0.12714094
# Iteration 118, loss = 0.12609990
# Iteration 119, loss = 0.12510488
# Iteration 120, loss = 0.12410744
# Iteration 121, loss = 0.12312983
# Iteration 122, loss = 0.12218325
# Iteration 123, loss = 0.12127374
# Iteration 124, loss = 0.12029862
# Iteration 125, loss = 0.11937497
# Iteration 126, loss = 0.11852960
# Iteration 127, loss = 0.11764197
# Iteration 128, loss = 0.11678938
# Iteration 129, loss = 0.11600310
# Iteration 130, loss = 0.11513795
# Iteration 131, loss = 0.11432691
# Iteration 132, loss = 0.11355850
# Iteration 133, loss = 0.11276587
# Iteration 134, loss = 0.11200325
# Iteration 135, loss = 0.11123467
# Iteration 136, loss = 0.11049981
# Iteration 137, loss = 0.10977779
# Iteration 138, loss = 0.10906076
# Iteration 139, loss = 0.10836901
# Iteration 140, loss = 0.10769347
# Iteration 141, loss = 0.10697965
# Iteration 142, loss = 0.10631299
# Iteration 143, loss = 0.10567630
# Iteration 144, loss = 0.10500997
# Iteration 145, loss = 0.10440202
# Iteration 146, loss = 0.10376444
# Iteration 147, loss = 0.10318571
# Iteration 148, loss = 0.10258633
# Iteration 149, loss = 0.10197738
# Iteration 150, loss = 0.10142031
# Iteration 151, loss = 0.10081999
# Iteration 152, loss = 0.10027888
# Iteration 153, loss = 0.09972686
# Iteration 154, loss = 0.09915747
# Iteration 155, loss = 0.09863160
# Iteration 156, loss = 0.09809151
# Iteration 157, loss = 0.09759234
# Iteration 158, loss = 0.09704653
# Iteration 159, loss = 0.09654045
# Iteration 160, loss = 0.09604393
# Iteration 161, loss = 0.09560468
# Iteration 162, loss = 0.09509837
# Iteration 163, loss = 0.09457891
# Iteration 164, loss = 0.09412126
# Iteration 165, loss = 0.09369486
# Iteration 166, loss = 0.09320264
# Iteration 167, loss = 0.09273864
# Iteration 168, loss = 0.09227986
# Iteration 169, loss = 0.09184906
# Iteration 170, loss = 0.09142681
# Iteration 171, loss = 0.09100319
# Iteration 172, loss = 0.09057091
# Iteration 173, loss = 0.09014973
# Iteration 174, loss = 0.08974175
# Iteration 175, loss = 0.08934855
# Iteration 176, loss = 0.08893204
# Iteration 177, loss = 0.08852948
# Iteration 178, loss = 0.08817666
# Iteration 179, loss = 0.08774871
# Iteration 180, loss = 0.08740750
# Iteration 181, loss = 0.08703462
# Iteration 182, loss = 0.08664646
# ...
# Iteration 224, loss = 0.07115870
# Iteration 225, loss = 0.07096060
# Iteration 226, loss = 0.07075998
# Iteration 227, loss = 0.07048833
# Iteration 228, loss = 0.07026547
# Iteration 229, loss = 0.07007734
# Iteration 230, loss = 0.06988039
# Iteration 231, loss = 0.06965293
# Iteration 232, loss = 0.06942448
# Iteration 233, loss = 0.06926269
# Iteration 234, loss = 0.06899940
# Iteration 235, loss = 0.06881148
# Iteration 236, loss = 0.06859825
# Iteration 237, loss = 0.06843068
# Iteration 238, loss = 0.06820874
# Iteration 239, loss = 0.06801363
# Iteration 240, loss = 0.06781645
# Iteration 241, loss = 0.06762941
# Iteration 242, loss = 0.06741278
# Iteration 243, loss = 0.06727642
# Iteration 244, loss = 0.06706159
# Iteration 245, loss = 0.06686943
# Iteration 246, loss = 0.06667399
# Iteration 247, loss = 0.06649507
# Iteration 248, loss = 0.06631730
# Iteration 249, loss = 0.06614661
# Iteration 250, loss = 0.06595944
# Iteration 251, loss = 0.06577390
# Iteration 252, loss = 0.06558836
# Iteration 253, loss = 0.06545543
# Iteration 254, loss = 0.06524611
# Iteration 255, loss = 0.06507034
# Iteration 256, loss = 0.06490263
# Iteration 257, loss = 0.06474056
# Iteration 258, loss = 0.06455848
# Iteration 259, loss = 0.06441061
# Iteration 260, loss = 0.06423390
# Iteration 261, loss = 0.06407103
# Iteration 262, loss = 0.06390793
# Iteration 263, loss = 0.06375187
# Iteration 264, loss = 0.06359295
# Iteration 265, loss = 0.06345752
# Iteration 266, loss = 0.06327939
# Iteration 267, loss = 0.06314017
# Iteration 268, loss = 0.06304308
# Iteration 269, loss = 0.06283419
# Iteration 270, loss = 0.06269723
# Iteration 271, loss = 0.06252720
# Iteration 272, loss = 0.06239835
# Iteration 273, loss = 0.06222244
# Iteration 274, loss = 0.06209839
# Iteration 275, loss = 0.06194690
# Iteration 276, loss = 0.06182088
# Iteration 277, loss = 0.06167451
# Iteration 278, loss = 0.06154581
# Iteration 279, loss = 0.06140099
# Iteration 280, loss = 0.06125737
# Iteration 281, loss = 0.06114843
# Iteration 282, loss = 0.06100004
# Iteration 283, loss = 0.06086297
# Iteration 284, loss = 0.06074147
# Iteration 285, loss = 0.06060474
# Iteration 286, loss = 0.06047873
# Iteration 287, loss = 0.06035472
# Iteration 288, loss = 0.06024058
# Iteration 289, loss = 0.06011538
# Iteration 290, loss = 0.06000522
# Iteration 291, loss = 0.05985907
# Iteration 292, loss = 0.05977826
# Iteration 293, loss = 0.05964568
# Iteration 294, loss = 0.05951019
# Iteration 295, loss = 0.05939988
# Iteration 296, loss = 0.05927163
# Iteration 297, loss = 0.05914881
# Iteration 298, loss = 0.05906567
# Iteration 299, loss = 0.05892796
# Iteration 300, loss = 0.05889220
# Iteration 301, loss = 0.05872789
# Iteration 302, loss = 0.05860586
# Iteration 303, loss = 0.05849728
# Iteration 304, loss = 0.05841259
# Iteration 305, loss = 0.05827757
# Iteration 306, loss = 0.05815323
# Iteration 307, loss = 0.05804037
# Iteration 308, loss = 0.05793854
# Iteration 309, loss = 0.05782556
# Iteration 310, loss = 0.05772349
# Iteration 311, loss = 0.05762073
# Iteration 312, loss = 0.05753205
# Iteration 313, loss = 0.05741455
# Iteration 314, loss = 0.05730848
# Iteration 315, loss = 0.05721408
# Iteration 316, loss = 0.05710356
# Iteration 317, loss = 0.05702128
# Iteration 318, loss = 0.05690527
# Iteration 319, loss = 0.05679921
# Iteration 320, loss = 0.05671954
# Iteration 321, loss = 0.05662340
# Iteration 322, loss = 0.05650816
# Iteration 323, loss = 0.05640896
# Iteration 324, loss = 0.05631897
# Iteration 325, loss = 0.05623016
# Iteration 326, loss = 0.05614778
# Iteration 327, loss = 0.05603283
# Iteration 328, loss = 0.05596697
# Iteration 329, loss = 0.05584822
# Iteration 330, loss = 0.05578771
# Iteration 331, loss = 0.05567009
# Iteration 332, loss = 0.05559244
# Iteration 333, loss = 0.05547778
# Iteration 334, loss = 0.05539709
# Iteration 335, loss = 0.05530701
# Iteration 336, loss = 0.05522678
# Iteration 337, loss = 0.05513658
# Iteration 338, loss = 0.05506506
# Iteration 339, loss = 0.05495398
# Iteration 340, loss = 0.05488697
# Iteration 341, loss = 0.05479592
# Iteration 342, loss = 0.05471219
# Iteration 343, loss = 0.05461226
# Iteration 344, loss = 0.05454277
# Iteration 345, loss = 0.05445690
# Iteration 346, loss = 0.05438289
# Iteration 347, loss = 0.05429231
# Iteration 348, loss = 0.05421719
# Iteration 349, loss = 0.05415237
# Iteration 350, loss = 0.05406458
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Iteration 1, loss = 0.63327985
# Iteration 2, loss = 0.62178072
# Iteration 3, loss = 0.61105445
# Iteration 4, loss = 0.60054176
# Iteration 5, loss = 0.59018370
# Iteration 6, loss = 0.57996427
# Iteration 7, loss = 0.57025459
# Iteration 8, loss = 0.56073646
# Iteration 9, loss = 0.55115201
# Iteration 10, loss = 0.54214359
# Iteration 11, loss = 0.53286502
# Iteration 12, loss = 0.52396605
# Iteration 13, loss = 0.51502314
# Iteration 14, loss = 0.50661928
# Iteration 15, loss = 0.49789681
# Iteration 16, loss = 0.48952991
# Iteration 17, loss = 0.48127251
# Iteration 18, loss = 0.47336156
# Iteration 19, loss = 0.46533986
# Iteration 20, loss = 0.45742718
# Iteration 21, loss = 0.44961776
# Iteration 22, loss = 0.44198387
# Iteration 23, loss = 0.43458327
# Iteration 24, loss = 0.42723951
# Iteration 25, loss = 0.41996386
# Iteration 26, loss = 0.41297195
# Iteration 27, loss = 0.40594495
# Iteration 28, loss = 0.39906751
# Iteration 29, loss = 0.39234954
# Iteration 30, loss = 0.38591433
# Iteration 31, loss = 0.37947162
# Iteration 32, loss = 0.37310555
# Iteration 33, loss = 0.36696652
# Iteration 34, loss = 0.36088874
# Iteration 35, loss = 0.35493129
# Iteration 36, loss = 0.34913992
# Iteration 37, loss = 0.34327287
# Iteration 38, loss = 0.33758617
# Iteration 39, loss = 0.33198918
# Iteration 40, loss = 0.32656006
# Iteration 41, loss = 0.32111762
# Iteration 42, loss = 0.31585058
# Iteration 43, loss = 0.31078262
# Iteration 44, loss = 0.30572032
# Iteration 45, loss = 0.30074837
# Iteration 46, loss = 0.29594418
# Iteration 47, loss = 0.29109984
# Iteration 48, loss = 0.28649283
# Iteration 49, loss = 0.28197523
# Iteration 50, loss = 0.27750360
# Iteration 51, loss = 0.27321281
# Iteration 52, loss = 0.26905383
# Iteration 53, loss = 0.26488598
# Iteration 54, loss = 0.26078126
# Iteration 55, loss = 0.25689800
# Iteration 56, loss = 0.25306609
# Iteration 57, loss = 0.24923920
# Iteration 58, loss = 0.24557453
# Iteration 59, loss = 0.24197977
# Iteration 60, loss = 0.23846234
# Iteration 61, loss = 0.23501040
# Iteration 62, loss = 0.23158882
# Iteration 63, loss = 0.22835022
# Iteration 64, loss = 0.22506173
# Iteration 65, loss = 0.22192883
# Iteration 66, loss = 0.21881609
# Iteration 67, loss = 0.21574817
# Iteration 68, loss = 0.21283334
# Iteration 69, loss = 0.20993110
# Iteration 70, loss = 0.20707336
# Iteration 71, loss = 0.20435483
# Iteration 72, loss = 0.20163470
# Iteration 73, loss = 0.19904450
# Iteration 74, loss = 0.19646312
# Iteration 75, loss = 0.19393500
# Iteration 76, loss = 0.19148835
# Iteration 77, loss = 0.18905367
# Iteration 78, loss = 0.18677544
# Iteration 79, loss = 0.18445850
# Iteration 80, loss = 0.18221397
# Iteration 81, loss = 0.18001588
# Iteration 82, loss = 0.17786616
# Iteration 83, loss = 0.17578705
# Iteration 84, loss = 0.17371293
# Iteration 85, loss = 0.17173891
# Iteration 86, loss = 0.16972784
# Iteration 87, loss = 0.16774082
# Iteration 88, loss = 0.16585140
# Iteration 89, loss = 0.16397460
# Iteration 90, loss = 0.16213295
# Iteration 91, loss = 0.16033489
# Iteration 92, loss = 0.15854745
# Iteration 93, loss = 0.15685768
# Iteration 94, loss = 0.15519401
# Iteration 95, loss = 0.15354261
# Iteration 96, loss = 0.15192319
# Iteration 97, loss = 0.15033527
# Iteration 98, loss = 0.14876609
# Iteration 99, loss = 0.14723286
# Iteration 100, loss = 0.14574661
# Iteration 101, loss = 0.14424704
# Iteration 102, loss = 0.14281601
# Iteration 103, loss = 0.14138574
# Iteration 104, loss = 0.13999416
# Iteration 105, loss = 0.13866097
# Iteration 106, loss = 0.13731211
# Iteration 107, loss = 0.13601263
# Iteration 108, loss = 0.13475644
# Iteration 109, loss = 0.13355608
# Iteration 110, loss = 0.13229070
# Iteration 111, loss = 0.13115426
# Iteration 112, loss = 0.12998541
# Iteration 113, loss = 0.12886370
# Iteration 114, loss = 0.12774173
# Iteration 115, loss = 0.12666673
# Iteration 116, loss = 0.12553826
# Iteration 117, loss = 0.12454294
# Iteration 118, loss = 0.12348043
# Iteration 119, loss = 0.12247955
# Iteration 120, loss = 0.12148230
# Iteration 121, loss = 0.12052523
# Iteration 122, loss = 0.11955356
# Iteration 123, loss = 0.11856816
# Iteration 124, loss = 0.11765541
# Iteration 125, loss = 0.11670645
# Iteration 126, loss = 0.11582168
# Iteration 127, loss = 0.11492761
# Iteration 128, loss = 0.11404360
# Iteration 129, loss = 0.11316571
# Iteration 130, loss = 0.11231569
# Iteration 131, loss = 0.11144019
# Iteration 132, loss = 0.11066249
# Iteration 133, loss = 0.10982318
# Iteration 134, loss = 0.10904810
# Iteration 135, loss = 0.10826448
# Iteration 136, loss = 0.10753508
# Iteration 137, loss = 0.10681186
# Iteration 138, loss = 0.10606256
# Iteration 139, loss = 0.10533952
# Iteration 140, loss = 0.10463757
# Iteration 141, loss = 0.10397046
# Iteration 142, loss = 0.10330201
# Iteration 143, loss = 0.10264320
# Iteration 144, loss = 0.10197039
# Iteration 145, loss = 0.10134966
# Iteration 146, loss = 0.10070740
# Iteration 147, loss = 0.10011440
# Iteration 148, loss = 0.09948039
# Iteration 149, loss = 0.09889131
# Iteration 150, loss = 0.09828899
# Iteration 151, loss = 0.09768465
# Iteration 152, loss = 0.09713126
# Iteration 153, loss = 0.09659440
# Iteration 154, loss = 0.09603601
# Iteration 155, loss = 0.09551277
# Iteration 156, loss = 0.09499690
# Iteration 157, loss = 0.09449622
# Iteration 158, loss = 0.09396583
# Iteration 159, loss = 0.09344431
# Iteration 160, loss = 0.09296961
# Iteration 161, loss = 0.09249607
# Iteration 162, loss = 0.09202480
# Iteration 163, loss = 0.09151966
# Iteration 164, loss = 0.09111181
# Iteration 165, loss = 0.09060921
# Iteration 166, loss = 0.09017678
# Iteration 167, loss = 0.08975534
# Iteration 168, loss = 0.08931221
# Iteration 169, loss = 0.08886611
# Iteration 170, loss = 0.08844878
# Iteration 171, loss = 0.08803164
# Iteration 172, loss = 0.08761384
# Iteration 173, loss = 0.08723914
# Iteration 174, loss = 0.08679956
# Iteration 175, loss = 0.08643592
# Iteration 176, loss = 0.08602865
# Iteration 177, loss = 0.08563890
# Iteration 178, loss = 0.08524266
# Iteration 179, loss = 0.08487627
# Iteration 180, loss = 0.08454416
# Iteration 181, loss = 0.08421506
# Iteration 182, loss = 0.08382053
# Iteration 183, loss = 0.08347614
# Iteration 184, loss = 0.08315097
# Iteration 185, loss = 0.08278781
# Iteration 186, loss = 0.08246435
# Iteration 187, loss = 0.08213024
# Iteration 188, loss = 0.08184463
# Iteration 189, loss = 0.08145789
# Iteration 190, loss = 0.08114622
# Iteration 191, loss = 0.08081711
# Iteration 192, loss = 0.08052058
# Iteration 193, loss = 0.08019900
# Iteration 194, loss = 0.07991907
# Iteration 195, loss = 0.07958940
# Iteration 196, loss = 0.07929579
# Iteration 197, loss = 0.07900659
# Iteration 198, loss = 0.07872481
# Iteration 199, loss = 0.07842621
# Iteration 200, loss = 0.07814420
# Iteration 201, loss = 0.07787041
# Iteration 202, loss = 0.07756261
# Iteration 203, loss = 0.07731103
# Iteration 204, loss = 0.07705117
# Iteration 205, loss = 0.07676418
# Iteration 206, loss = 0.07650185
# Iteration 207, loss = 0.07623881
# Iteration 208, loss = 0.07599630
# Iteration 209, loss = 0.07572633
# Iteration 210, loss = 0.07553299
# Iteration 211, loss = 0.07522331
# Iteration 212, loss = 0.07498598
# Iteration 213, loss = 0.07474207
# Iteration 214, loss = 0.07453095
# Iteration 215, loss = 0.07426966
# Iteration 216, loss = 0.07404781
# Iteration 217, loss = 0.07381589
# Iteration 218, loss = 0.07360895
# Iteration 219, loss = 0.07336789
# Iteration 220, loss = 0.07316030
# Iteration 221, loss = 0.07291617
# Iteration 222, loss = 0.07269762
# Iteration 223, loss = 0.07248901
# Iteration 224, loss = 0.07224882
# Iteration 225, loss = 0.07205962
# Iteration 226, loss = 0.07189326
# Iteration 227, loss = 0.07162467
# Iteration 228, loss = 0.07142122
# Iteration 229, loss = 0.07125214
# Iteration 230, loss = 0.07106401
# Iteration 231, loss = 0.07083635
# Iteration 232, loss = 0.07062610
# Iteration 233, loss = 0.07048361
# Iteration 234, loss = 0.07024130
# Iteration 235, loss = 0.07005388
# Iteration 236, loss = 0.06985267
# Iteration 237, loss = 0.06968748
# Iteration 238, loss = 0.06948326
# Iteration 239, loss = 0.06930470
# Iteration 240, loss = 0.06913543
# Iteration 241, loss = 0.06895743
# Iteration 242, loss = 0.06874989
# Iteration 243, loss = 0.06862228
# Iteration 244, loss = 0.06841085
# Iteration 245, loss = 0.06822758
# Iteration 246, loss = 0.06805726
# Iteration 247, loss = 0.06787877
# Iteration 248, loss = 0.06770672
# Iteration 249, loss = 0.06755506
# Iteration 250, loss = 0.06738819
# Iteration 251, loss = 0.06721182
# Iteration 252, loss = 0.06704694
# Iteration 253, loss = 0.06690368
# Iteration 254, loss = 0.06671684
# Iteration 255, loss = 0.06654959
# Iteration 256, loss = 0.06639009
# Iteration 257, loss = 0.06622859
# Iteration 258, loss = 0.06607306
# Iteration 259, loss = 0.06592389
# Iteration 260, loss = 0.06575790
# Iteration 261, loss = 0.06560511
# Iteration 262, loss = 0.06545356
# Iteration 263, loss = 0.06530645
# Iteration 264, loss = 0.06515030
# Iteration 265, loss = 0.06502532
# Iteration 266, loss = 0.06485445
# Iteration 267, loss = 0.06471929
# Iteration 268, loss = 0.06461562
# Iteration 269, loss = 0.06443798
# Iteration 270, loss = 0.06430167
# Iteration 271, loss = 0.06415164
# Iteration 272, loss = 0.06401861
# Iteration 273, loss = 0.06385073
# Iteration 274, loss = 0.06373853
# Iteration 275, loss = 0.06360151
# Iteration 276, loss = 0.06349913
# Iteration 277, loss = 0.06333066
# Iteration 278, loss = 0.06321113
# Iteration 279, loss = 0.06306589
# Iteration 280, loss = 0.06293849
# Iteration 281, loss = 0.06281103
# Iteration 282, loss = 0.06268760
# Iteration 283, loss = 0.06256361
# Iteration 284, loss = 0.06242515
# Iteration 285, loss = 0.06230091
# Iteration 286, loss = 0.06217965
# Iteration 287, loss = 0.06205536
# Iteration 288, loss = 0.06194731
# Iteration 289, loss = 0.06181765
# Iteration 290, loss = 0.06171200
# Iteration 291, loss = 0.06158970
# Iteration 292, loss = 0.06149905
# Iteration 293, loss = 0.06135502
# Iteration 294, loss = 0.06124000
# Iteration 295, loss = 0.06112892
# Iteration 296, loss = 0.06100428
# Iteration 297, loss = 0.06089464
# Iteration 298, loss = 0.06080261
# Iteration 299, loss = 0.06066932
# Iteration 300, loss = 0.06064055
# Iteration 301, loss = 0.06047131
# Iteration 302, loss = 0.06035828
# Iteration 303, loss = 0.06025953
# Iteration 304, loss = 0.06016918
# Iteration 305, loss = 0.06003025
# Iteration 306, loss = 0.05992105
# Iteration 307, loss = 0.05980819
# Iteration 308, loss = 0.05971240
# Iteration 309, loss = 0.05959255
# Iteration 310, loss = 0.05949729
# Iteration 311, loss = 0.05940651
# Iteration 312, loss = 0.05930593
# Iteration 313, loss = 0.05918483
# Iteration 314, loss = 0.05909290
# Iteration 315, loss = 0.05899700
# Iteration 316, loss = 0.05888650
# Iteration 317, loss = 0.05880027
# Iteration 318, loss = 0.05867863
# Iteration 319, loss = 0.05857370
# Iteration 320, loss = 0.05848571
# Iteration 321, loss = 0.05843371
# Iteration 322, loss = 0.05829060
# Iteration 323, loss = 0.05818427
# Iteration 324, loss = 0.05809467
# Iteration 325, loss = 0.05801402
# Iteration 326, loss = 0.05793455
# Iteration 327, loss = 0.05780649
# Iteration 328, loss = 0.05775429
# Iteration 329, loss = 0.05763027
# Iteration 330, loss = 0.05757294
# Iteration 331, loss = 0.05744057
# Iteration 332, loss = 0.05737265
# Iteration 333, loss = 0.05726610
# Iteration 334, loss = 0.05717930
# Iteration 335, loss = 0.05708390
# Iteration 336, loss = 0.05700190
# Iteration 337, loss = 0.05692007
# Iteration 338, loss = 0.05681139
# Iteration 339, loss = 0.05671909
# Iteration 340, loss = 0.05665680
# Iteration 341, loss = 0.05655609
# Iteration 342, loss = 0.05644999
# Iteration 343, loss = 0.05636832
# Iteration 344, loss = 0.05629310
# Iteration 345, loss = 0.05620686
# Iteration 346, loss = 0.05612100
# Iteration 347, loss = 0.05603354
# Iteration 348, loss = 0.05594527
# Iteration 349, loss = 0.05587481
# Iteration 350, loss = 0.05578548
# Iteration 351, loss = 0.05569931
# Iteration 352, loss = 0.05562525
# Iteration 353, loss = 0.05554891
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.981     0.991     0.986       212
#    Malignant      0.990     0.981     0.986       212
#
#     accuracy                          0.986       424
#    macro avg      0.986     0.986     0.986       424
# weighted avg      0.986     0.986     0.986       424

# %%
originalclass = []
predictedclass = []
  
# Cross validate
clf_mlp_adam =  Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=10)),
                ('scaler2', StandardScaler()),
                ('mlp',MLPClassifier(alpha=0.1, batch_size=99,
                               hidden_layer_sizes=(20,),
                               learning_rate_init=0.01, max_iter=1000,
                               random_state=13, verbose=0))])

score = cross_val_score(clf_mlp_adam, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.981     0.986     0.984       212
#    Malignant      0.986     0.981     0.983       212
#
#     accuracy                          0.983       424
#    macro avg      0.984     0.983     0.983       424
# weighted avg      0.984     0.983     0.983       424

# %% [markdown]
# 2. Solver : SGD

# %%
# http://yann.lecun.com/exdb/publis/pdf/lecun-98b.pdf
# https://www.cs.cornell.edu/courses/cs4780/2018fa/lectures/lecturenote20.html
# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw
# https://datascience.stackexchange.com/questions/36049/how-to-adjust-the-hyperparameters-of-mlp-classifier-to-get-more-perfect-performa
param_grid = {
    'mlp__hidden_layer_sizes' : [(20,)], # [(20,),(100,),(20,4),(10,10,)]
    'mlp__activation' : ['relu'], #['logistic','tanh','relu'] 
    'mlp__solver' : ['sgd'],
    'mlp__alpha' : [0.1], #10.0 ** -np.arange(1, 7) , np.linspace(0.1,3,20) , 1 ,*0.1
    'mlp__batch_size' : [99], # ~297 samples for train at inner cv -> 3 equal size batches , #[16,32,64,128,'auto']
    'mlp__learning_rate' : ['constant','adaptive'], # [*'constant','invscaling','adaptive']
    'mlp__learning_rate_init' : [0.01],
    'mlp__power_t' : [0.5],
    'mlp__momentum' : [0.2], # np.arange(0.1,1,0.1), *0.2
    'mlp__max_iter' : [1000],
    'mlp__verbose' : [1]
}

search_sgd = RandomizedSearchCV(clf_mlp, param_distributions=param_grid, n_jobs=-1,cv=search_cv,verbose=1,scoring='f1_macro',n_iter=100)

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(search_sgd, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Iteration 1, loss = 0.64557034
# Iteration 2, loss = 0.63982398
# Iteration 3, loss = 0.63416835
# Iteration 4, loss = 0.62863543
# Iteration 5, loss = 0.62320076
# Iteration 6, loss = 0.61778218
# Iteration 7, loss = 0.61248881
# Iteration 8, loss = 0.60722685
# Iteration 9, loss = 0.60209668
# Iteration 10, loss = 0.59696720
# Iteration 11, loss = 0.59199538
# Iteration 12, loss = 0.58708415
# Iteration 13, loss = 0.58222086
# Iteration 14, loss = 0.57735901
# Iteration 15, loss = 0.57266623
# Iteration 16, loss = 0.56787383
# Iteration 17, loss = 0.56320912
# Iteration 18, loss = 0.55862619
# Iteration 19, loss = 0.55405714
# Iteration 20, loss = 0.54954477
# Iteration 21, loss = 0.54513753
# Iteration 22, loss = 0.54088514
# Iteration 23, loss = 0.53639636
# Iteration 24, loss = 0.53213378
# Iteration 25, loss = 0.52786982
# Iteration 26, loss = 0.52361705
# Iteration 27, loss = 0.51945330
# Iteration 28, loss = 0.51539597
# Iteration 29, loss = 0.51132100
# Iteration 30, loss = 0.50711647
# Iteration 31, loss = 0.50305490
# Iteration 32, loss = 0.49914483
# Iteration 33, loss = 0.49510325
# Iteration 34, loss = 0.49114077
# Iteration 35, loss = 0.48724487
# Iteration 36, loss = 0.48342323
# Iteration 37, loss = 0.47959813
# Iteration 38, loss = 0.47573775
# Iteration 39, loss = 0.47198335
# Iteration 40, loss = 0.46821026
# Iteration 41, loss = 0.46448000
# Iteration 42, loss = 0.46080434
# Iteration 43, loss = 0.45720918
# Iteration 44, loss = 0.45347377
# Iteration 45, loss = 0.44983289
# Iteration 46, loss = 0.44630696
# Iteration 47, loss = 0.44279077
# Iteration 48, loss = 0.43932993
# Iteration 49, loss = 0.43582900
# Iteration 50, loss = 0.43248493
# Iteration 51, loss = 0.42906094
# Iteration 52, loss = 0.42573146
# Iteration 53, loss = 0.42238411
# Iteration 54, loss = 0.41906488
# Iteration 55, loss = 0.41574867
# Iteration 56, loss = 0.41251745
# Iteration 57, loss = 0.40930098
# Iteration 58, loss = 0.40618408
# Iteration 59, loss = 0.40297998
# Iteration 60, loss = 0.39984935
# Iteration 61, loss = 0.39667926
# Iteration 62, loss = 0.39361209
# Iteration 63, loss = 0.39057992
# Iteration 64, loss = 0.38757876
# Iteration 65, loss = 0.38463069
# Iteration 66, loss = 0.38168219
# Iteration 67, loss = 0.37873355
# Iteration 68, loss = 0.37581429
# Iteration 69, loss = 0.37295119
# Iteration 70, loss = 0.37009117
# Iteration 71, loss = 0.36727129
# Iteration 72, loss = 0.36450890
# Iteration 73, loss = 0.36176998
# Iteration 74, loss = 0.35903454
# Iteration 75, loss = 0.35631095
# Iteration 76, loss = 0.35365905
# Iteration 77, loss = 0.35101173
# Iteration 78, loss = 0.34838121
# Iteration 79, loss = 0.34577520
# Iteration 80, loss = 0.34321804
# Iteration 81, loss = 0.34068548
# Iteration 82, loss = 0.33821135
# Iteration 83, loss = 0.33567118
# Iteration 84, loss = 0.33321264
# Iteration 85, loss = 0.33084030
# Iteration 86, loss = 0.32841278
# Iteration 87, loss = 0.32607410
# Iteration 88, loss = 0.32371241
# Iteration 89, loss = 0.32140594
# Iteration 90, loss = 0.31909371
# Iteration 91, loss = 0.31685769
# Iteration 92, loss = 0.31458578
# Iteration 93, loss = 0.31239096
# Iteration 94, loss = 0.31022837
# Iteration 95, loss = 0.30803513
# Iteration 96, loss = 0.30591715
# Iteration 97, loss = 0.30384849
# Iteration 98, loss = 0.30177703
# Iteration 99, loss = 0.29969582
# Iteration 100, loss = 0.29771391
# Iteration 101, loss = 0.29563264
# Iteration 102, loss = 0.29366359
# Iteration 103, loss = 0.29173365
# Iteration 104, loss = 0.28979384
# Iteration 105, loss = 0.28787169
# Iteration 106, loss = 0.28602126
# Iteration 107, loss = 0.28414407
# Iteration 108, loss = 0.28229502
# Iteration 109, loss = 0.28050972
# Iteration 110, loss = 0.27871925
# Iteration 111, loss = 0.27696457
# Iteration 112, loss = 0.27519767
# Iteration 113, loss = 0.27348476
# Iteration 114, loss = 0.27177252
# Iteration 115, loss = 0.27012969
# Iteration 116, loss = 0.26843700
# Iteration 117, loss = 0.26681502
# Iteration 118, loss = 0.26518363
# Iteration 119, loss = 0.26358286
# Iteration 120, loss = 0.26197568
# Iteration 121, loss = 0.26043955
# Iteration 122, loss = 0.25889822
# Iteration 123, loss = 0.25730797
# Iteration 124, loss = 0.25578743
# Iteration 125, loss = 0.25428609
# Iteration 126, loss = 0.25280793
# Iteration 127, loss = 0.25134010
# Iteration 128, loss = 0.24988447
# Iteration 129, loss = 0.24844391
# Iteration 130, loss = 0.24702446
# Iteration 131, loss = 0.24562568
# Iteration 132, loss = 0.24424628
# Iteration 133, loss = 0.24290097
# Iteration 134, loss = 0.24152370
# Iteration 135, loss = 0.24024372
# Iteration 136, loss = 0.23887207
# Iteration 137, loss = 0.23761011
# Iteration 138, loss = 0.23631706
# Iteration 139, loss = 0.23501823
# Iteration 140, loss = 0.23376196
# Iteration 141, loss = 0.23250393
# Iteration 142, loss = 0.23127802
# Iteration 143, loss = 0.23005405
# Iteration 144, loss = 0.22886692
# Iteration 145, loss = 0.22767568
# Iteration 146, loss = 0.22651140
# Iteration 147, loss = 0.22534353
# Iteration 148, loss = 0.22417393
# Iteration 149, loss = 0.22306351
# Iteration 150, loss = 0.22192496
# Iteration 151, loss = 0.22081089
# Iteration 152, loss = 0.21973409
# Iteration 153, loss = 0.21863146
# Iteration 154, loss = 0.21755820
# Iteration 155, loss = 0.21650414
# Iteration 156, loss = 0.21548525
# Iteration 157, loss = 0.21443237
# Iteration 158, loss = 0.21338014
# Iteration 159, loss = 0.21235249
# Iteration 160, loss = 0.21136399
# Iteration 161, loss = 0.21038465
# Iteration 162, loss = 0.20939039
# Iteration 163, loss = 0.20842437
# Iteration 164, loss = 0.20746046
# Iteration 165, loss = 0.20651846
# Iteration 166, loss = 0.20557590
# Iteration 167, loss = 0.20465493
# Iteration 168, loss = 0.20372775
# Iteration 169, loss = 0.20280183
# Iteration 170, loss = 0.20191943
# Iteration 171, loss = 0.20103791
# Iteration 172, loss = 0.20011477
# Iteration 173, loss = 0.19928915
# Iteration 174, loss = 0.19841156
# Iteration 175, loss = 0.19753914
# Iteration 176, loss = 0.19670511
# Iteration 177, loss = 0.19588419
# Iteration 178, loss = 0.19506479
# Iteration 179, loss = 0.19424767
# Iteration 180, loss = 0.19342256
# Iteration 181, loss = 0.19263660
# Iteration 182, loss = 0.19183291
# Iteration 183, loss = 0.19106538
# Iteration 184, loss = 0.19027893
# Iteration 185, loss = 0.18952358
# Iteration 186, loss = 0.18878133
# Iteration 187, loss = 0.18802119
# Iteration 188, loss = 0.18730954
# Iteration 189, loss = 0.18655501
# Iteration 190, loss = 0.18581802
# Iteration 191, loss = 0.18507033
# Iteration 192, loss = 0.18437157
# Iteration 193, loss = 0.18366220
# Iteration 194, loss = 0.18298243
# Iteration 195, loss = 0.18229058
# Iteration 196, loss = 0.18154865
# Iteration 197, loss = 0.18088500
# Iteration 198, loss = 0.18019501
# Iteration 199, loss = 0.17953115
# Iteration 200, loss = 0.17884961
# Iteration 201, loss = 0.17817889
# Iteration 202, loss = 0.17754567
# Iteration 203, loss = 0.17689211
# Iteration 204, loss = 0.17625383
# Iteration 205, loss = 0.17561613
# Iteration 206, loss = 0.17498731
# Iteration 207, loss = 0.17436513
# Iteration 208, loss = 0.17373206
# Iteration 209, loss = 0.17313051
# Iteration 210, loss = 0.17251737
# Iteration 211, loss = 0.17191881
# Iteration 212, loss = 0.17132641
# Iteration 213, loss = 0.17075609
# Iteration 214, loss = 0.17017630
# Iteration 215, loss = 0.16956816
# Iteration 216, loss = 0.16900322
# Iteration 217, loss = 0.16843004
# Iteration 218, loss = 0.16786639
# Iteration 219, loss = 0.16729653
# Iteration 220, loss = 0.16675347
# Iteration 221, loss = 0.16619868
# Iteration 222, loss = 0.16564137
# Iteration 223, loss = 0.16509906
# Iteration 224, loss = 0.16452900
# Iteration 225, loss = 0.16397582
# Iteration 226, loss = 0.16342299
# Iteration 227, loss = 0.16288064
# Iteration 228, loss = 0.16236244
# Iteration 229, loss = 0.16182962
# Iteration 230, loss = 0.16129665
# Iteration 231, loss = 0.16075865
# Iteration 232, loss = 0.16025113
# Iteration 233, loss = 0.15973888
# Iteration 234, loss = 0.15922914
# Iteration 235, loss = 0.15873304
# Iteration 236, loss = 0.15826385
# Iteration 237, loss = 0.15775884
# Iteration 238, loss = 0.15731360
# Iteration 239, loss = 0.15676611
# Iteration 240, loss = 0.15629356
# Iteration 241, loss = 0.15581618
# Iteration 242, loss = 0.15536745
# Iteration 243, loss = 0.15488248
# Iteration 244, loss = 0.15440593
# Iteration 245, loss = 0.15394985
# Iteration 246, loss = 0.15350416
# Iteration 247, loss = 0.15306779
# Iteration 248, loss = 0.15260355
# Iteration 249, loss = 0.15214953
# Iteration 250, loss = 0.15172705
# Iteration 251, loss = 0.15129664
# Iteration 252, loss = 0.15086358
# Iteration 253, loss = 0.15045393
# Iteration 254, loss = 0.15001728
# Iteration 255, loss = 0.14957778
# Iteration 256, loss = 0.14914924
# Iteration 257, loss = 0.14872637
# Iteration 258, loss = 0.14835096
# Iteration 259, loss = 0.14791257
# Iteration 260, loss = 0.14750772
# Iteration 261, loss = 0.14710610
# Iteration 262, loss = 0.14672478
# Iteration 263, loss = 0.14631423
# Iteration 264, loss = 0.14593197
# Iteration 265, loss = 0.14555972
# Iteration 266, loss = 0.14517211
# Iteration 267, loss = 0.14477110
# Iteration 268, loss = 0.14438063
# Iteration 269, loss = 0.14401525
# Iteration 270, loss = 0.14363973
# Iteration 271, loss = 0.14327255
# Iteration 272, loss = 0.14289258
# Iteration 273, loss = 0.14253281
# Iteration 274, loss = 0.14216638
# Iteration 275, loss = 0.14178569
# Iteration 276, loss = 0.14146007
# Iteration 277, loss = 0.14108359
# Iteration 278, loss = 0.14071045
# Iteration 279, loss = 0.14035501
# Iteration 280, loss = 0.14000406
# Iteration 281, loss = 0.13968906
# Iteration 282, loss = 0.13933668
# Iteration 283, loss = 0.13900765
# Iteration 284, loss = 0.13864519
# Iteration 285, loss = 0.13831115
# Iteration 286, loss = 0.13799225
# Iteration 287, loss = 0.13764189
# Iteration 288, loss = 0.13732784
# Iteration 289, loss = 0.13699623
# Iteration 290, loss = 0.13664624
# Iteration 291, loss = 0.13632144
# Iteration 292, loss = 0.13599461
# Iteration 293, loss = 0.13569031
# Iteration 294, loss = 0.13536469
# Iteration 295, loss = 0.13505811
# Iteration 296, loss = 0.13473494
# Iteration 297, loss = 0.13443559
# Iteration 298, loss = 0.13410781
# Iteration 299, loss = 0.13380502
# Iteration 300, loss = 0.13348193
# Iteration 301, loss = 0.13321415
# Iteration 302, loss = 0.13287801
# Iteration 303, loss = 0.13258021
# Iteration 304, loss = 0.13228720
# Iteration 305, loss = 0.13200717
# Iteration 306, loss = 0.13172154
# Iteration 307, loss = 0.13144429
# Iteration 308, loss = 0.13112275
# Iteration 309, loss = 0.13084751
# Iteration 310, loss = 0.13056321
# Iteration 311, loss = 0.13027641
# Iteration 312, loss = 0.12999108
# Iteration 313, loss = 0.12970765
# Iteration 314, loss = 0.12943402
# Iteration 315, loss = 0.12915670
# Iteration 316, loss = 0.12888189
# Iteration 317, loss = 0.12862233
# Iteration 318, loss = 0.12833316
# Iteration 319, loss = 0.12807465
# Iteration 320, loss = 0.12780696
# Iteration 321, loss = 0.12754713
# Iteration 322, loss = 0.12728229
# Iteration 323, loss = 0.12702647
# Iteration 324, loss = 0.12676461
# Iteration 325, loss = 0.12651928
# Iteration 326, loss = 0.12624805
# Iteration 327, loss = 0.12600236
# Iteration 328, loss = 0.12574074
# Iteration 329, loss = 0.12550328
# Iteration 330, loss = 0.12526064
# Iteration 331, loss = 0.12502524
# Iteration 332, loss = 0.12477824
# Iteration 333, loss = 0.12451967
# Iteration 334, loss = 0.12428265
# Iteration 335, loss = 0.12403712
# Iteration 336, loss = 0.12381466
# Iteration 337, loss = 0.12357323
# Iteration 338, loss = 0.12335711
# Iteration 339, loss = 0.12311875
# Iteration 340, loss = 0.12287680
# Iteration 341, loss = 0.12265910
# Iteration 342, loss = 0.12241285
# Iteration 343, loss = 0.12218881
# Iteration 344, loss = 0.12194257
# Iteration 345, loss = 0.12173558
# Iteration 346, loss = 0.12151220
# Iteration 347, loss = 0.12127595
# Iteration 348, loss = 0.12105826
# Iteration 349, loss = 0.12084772
# Iteration 350, loss = 0.12064324
# Iteration 351, loss = 0.12041564
# Iteration 352, loss = 0.12019950
# Iteration 353, loss = 0.11999847
# Iteration 354, loss = 0.11977524
# Iteration 355, loss = 0.11957393
# Iteration 356, loss = 0.11937775
# Iteration 357, loss = 0.11916455
# Iteration 358, loss = 0.11892646
# Iteration 359, loss = 0.11872528
# Iteration 360, loss = 0.11852200
# Iteration 361, loss = 0.11833087
# Iteration 362, loss = 0.11813325
# Iteration 363, loss = 0.11792713
# Iteration 364, loss = 0.11771924
# Iteration 365, loss = 0.11753272
# Iteration 366, loss = 0.11733355
# Iteration 367, loss = 0.11713027
# Iteration 368, loss = 0.11692645
# Iteration 369, loss = 0.11673490
# Iteration 370, loss = 0.11654258
# Iteration 371, loss = 0.11635772
# Iteration 372, loss = 0.11615739
# Iteration 373, loss = 0.11597625
# Iteration 374, loss = 0.11579035
# Iteration 375, loss = 0.11561082
# Iteration 376, loss = 0.11541349
# Iteration 377, loss = 0.11522827
# Iteration 378, loss = 0.11504384
# Iteration 379, loss = 0.11484680
# Iteration 380, loss = 0.11468009
# Iteration 381, loss = 0.11448629
# Iteration 382, loss = 0.11430597
# Iteration 383, loss = 0.11412954
# Iteration 384, loss = 0.11395618
# Iteration 385, loss = 0.11377780
# Iteration 386, loss = 0.11361985
# Iteration 387, loss = 0.11341375
# Iteration 388, loss = 0.11323308
# Iteration 389, loss = 0.11307907
# Iteration 390, loss = 0.11291074
# Iteration 391, loss = 0.11272505
# Iteration 392, loss = 0.11256585
# Iteration 393, loss = 0.11238207
# Iteration 394, loss = 0.11222821
# Iteration 395, loss = 0.11205052
# Iteration 396, loss = 0.11188069
# Iteration 397, loss = 0.11171687
# Iteration 398, loss = 0.11154607
# Iteration 399, loss = 0.11138325
# Iteration 400, loss = 0.11121700
# Iteration 401, loss = 0.11106175
# Iteration 402, loss = 0.11090891
# Iteration 403, loss = 0.11076215
# Iteration 404, loss = 0.11058929
# Iteration 405, loss = 0.11042466
# Iteration 406, loss = 0.11027576
# Iteration 407, loss = 0.11011383
# Iteration 408, loss = 0.10996595
# Iteration 409, loss = 0.10981430
# Iteration 410, loss = 0.10965887
# Iteration 411, loss = 0.10951228
# Iteration 412, loss = 0.10934856
# Iteration 413, loss = 0.10919102
# Iteration 414, loss = 0.10904071
# Iteration 415, loss = 0.10892540
# Iteration 416, loss = 0.10875537
# Iteration 417, loss = 0.10859871
# Iteration 418, loss = 0.10844983
# Iteration 419, loss = 0.10830873
# Iteration 420, loss = 0.10817234
# Iteration 421, loss = 0.10802090
# Iteration 422, loss = 0.10787810
# Iteration 423, loss = 0.10772397
# Iteration 424, loss = 0.10757954
# Iteration 425, loss = 0.10742735
# Iteration 426, loss = 0.10731552
# Iteration 427, loss = 0.10717115
# Iteration 428, loss = 0.10700888
# Iteration 429, loss = 0.10686820
# Iteration 430, loss = 0.10673393
# Iteration 431, loss = 0.10661068
# Iteration 432, loss = 0.10646046
# Iteration 433, loss = 0.10632135
# Iteration 434, loss = 0.10618545
# Iteration 435, loss = 0.10603897
# Iteration 436, loss = 0.10592045
# Iteration 437, loss = 0.10577441
# Iteration 438, loss = 0.10564171
# Iteration 439, loss = 0.10550617
# Iteration 440, loss = 0.10537282
# Iteration 441, loss = 0.10523776
# Iteration 442, loss = 0.10511831
# Iteration 443, loss = 0.10497530
# Iteration 444, loss = 0.10483990
# Iteration 445, loss = 0.10471304
# Iteration 446, loss = 0.10459770
# Iteration 447, loss = 0.10444754
# Iteration 448, loss = 0.10435015
# Iteration 449, loss = 0.10421086
# Iteration 450, loss = 0.10407901
# Iteration 451, loss = 0.10396003
# Iteration 452, loss = 0.10382247
# Iteration 453, loss = 0.10368685
# Iteration 454, loss = 0.10359643
# Iteration 455, loss = 0.10344965
# Iteration 456, loss = 0.10332515
# Iteration 457, loss = 0.10323227
# Iteration 458, loss = 0.10310455
# Iteration 459, loss = 0.10297184
# Iteration 460, loss = 0.10283407
# Iteration 461, loss = 0.10271913
# Iteration 462, loss = 0.10260742
# Iteration 463, loss = 0.10247918
# Iteration 464, loss = 0.10236211
# Iteration 465, loss = 0.10223635
# Iteration 466, loss = 0.10214840
# Iteration 467, loss = 0.10200654
# Iteration 468, loss = 0.10188107
# Iteration 469, loss = 0.10175560
# Iteration 470, loss = 0.10166414
# Iteration 471, loss = 0.10153122
# Iteration 472, loss = 0.10143556
# Iteration 473, loss = 0.10131759
# Iteration 474, loss = 0.10121912
# Iteration 475, loss = 0.10109295
# Iteration 476, loss = 0.10098679
# Iteration 477, loss = 0.10086823
# Iteration 478, loss = 0.10075388
# Iteration 479, loss = 0.10065667
# Iteration 480, loss = 0.10054957
# Iteration 481, loss = 0.10042595
# Iteration 482, loss = 0.10033811
# Iteration 483, loss = 0.10021681
# Iteration 484, loss = 0.10010603
# Iteration 485, loss = 0.09999718
# Iteration 486, loss = 0.09988593
# Iteration 487, loss = 0.09977242
# Iteration 488, loss = 0.09967907
# Iteration 489, loss = 0.09956913
# Iteration 490, loss = 0.09947747
# Iteration 491, loss = 0.09936835
# Iteration 492, loss = 0.09925714
# Iteration 493, loss = 0.09914973
# Iteration 494, loss = 0.09907103
# Iteration 495, loss = 0.09897717
# Iteration 496, loss = 0.09885529
# Iteration 497, loss = 0.09873772
# Iteration 498, loss = 0.09864826
# Iteration 499, loss = 0.09855105
# Iteration 500, loss = 0.09846167
# Iteration 501, loss = 0.09835776
# Iteration 502, loss = 0.09825451
# Iteration 503, loss = 0.09814041
# Iteration 504, loss = 0.09805323
# Iteration 505, loss = 0.09794586
# Iteration 506, loss = 0.09785911
# Iteration 507, loss = 0.09776791
# Iteration 508, loss = 0.09768887
# Iteration 509, loss = 0.09757720
# Iteration 510, loss = 0.09746513
# Iteration 511, loss = 0.09737696
# Iteration 512, loss = 0.09728880
# Iteration 513, loss = 0.09718439
# Iteration 514, loss = 0.09709246
# Iteration 515, loss = 0.09700188
# Iteration 516, loss = 0.09691949
# Iteration 517, loss = 0.09680343
# Iteration 518, loss = 0.09672855
# Iteration 519, loss = 0.09661947
# Iteration 520, loss = 0.09654319
# Iteration 521, loss = 0.09645163
# Iteration 522, loss = 0.09634458
# Iteration 523, loss = 0.09626752
# Iteration 524, loss = 0.09617887
# Iteration 525, loss = 0.09609112
# Iteration 526, loss = 0.09598557
# Iteration 527, loss = 0.09591330
# Iteration 528, loss = 0.09581607
# Iteration 529, loss = 0.09572042
# Iteration 530, loss = 0.09563365
# Iteration 531, loss = 0.09554331
# Iteration 532, loss = 0.09545815
# Iteration 533, loss = 0.09536761
# Iteration 534, loss = 0.09528247
# Iteration 535, loss = 0.09520128
# Iteration 536, loss = 0.09513246
# Iteration 537, loss = 0.09501750
# Iteration 538, loss = 0.09492910
# Iteration 539, loss = 0.09486843
# Iteration 540, loss = 0.09476632
# Iteration 541, loss = 0.09468006
# Iteration 542, loss = 0.09462513
# Iteration 543, loss = 0.09450658
# Iteration 544, loss = 0.09442536
# Iteration 545, loss = 0.09433990
# Iteration 546, loss = 0.09426306
# Iteration 547, loss = 0.09417206
# Iteration 548, loss = 0.09410114
# Iteration 549, loss = 0.09402018
# Iteration 550, loss = 0.09395345
# Iteration 551, loss = 0.09386945
# Iteration 552, loss = 0.09376484
# Iteration 553, loss = 0.09369586
# Iteration 554, loss = 0.09359604
# Iteration 555, loss = 0.09352489
# Iteration 556, loss = 0.09346294
# Iteration 557, loss = 0.09335964
# Iteration 558, loss = 0.09329086
# Iteration 559, loss = 0.09319533
# Iteration 560, loss = 0.09312365
# Iteration 561, loss = 0.09303293
# Iteration 562, loss = 0.09295534
# Iteration 563, loss = 0.09287570
# Iteration 564, loss = 0.09282266
# Iteration 565, loss = 0.09271902
# Iteration 566, loss = 0.09265008
# Iteration 567, loss = 0.09258130
# Iteration 568, loss = 0.09251034
# Iteration 569, loss = 0.09242049
# Iteration 570, loss = 0.09234101
# Iteration 571, loss = 0.09225824
# Iteration 572, loss = 0.09218804
# Iteration 573, loss = 0.09212413
# Iteration 574, loss = 0.09203208
# Iteration 575, loss = 0.09197612
# Iteration 576, loss = 0.09187435
# Iteration 577, loss = 0.09180079
# Iteration 578, loss = 0.09173846
# Iteration 579, loss = 0.09164242
# Iteration 580, loss = 0.09158842
# Iteration 581, loss = 0.09150477
# Iteration 582, loss = 0.09143563
# Iteration 583, loss = 0.09136966
# Iteration 584, loss = 0.09128360
# Iteration 585, loss = 0.09121479
# Iteration 586, loss = 0.09115562
# Iteration 587, loss = 0.09106803
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Iteration 1, loss = 0.62281330
# Iteration 2, loss = 0.61803522
# Iteration 3, loss = 0.61318104
# Iteration 4, loss = 0.60850465
# Iteration 5, loss = 0.60385786
# Iteration 6, loss = 0.59928912
# Iteration 7, loss = 0.59470183
# Iteration 8, loss = 0.59022024
# Iteration 9, loss = 0.58587428
# Iteration 10, loss = 0.58148477
# Iteration 11, loss = 0.57716748
# Iteration 12, loss = 0.57293474
# Iteration 13, loss = 0.56879145
# Iteration 14, loss = 0.56470715
# Iteration 15, loss = 0.56060022
# Iteration 16, loss = 0.55645890
# Iteration 17, loss = 0.55248459
# Iteration 18, loss = 0.54852255
# Iteration 19, loss = 0.54461901
# Iteration 20, loss = 0.54071265
# Iteration 21, loss = 0.53691130
# Iteration 22, loss = 0.53320760
# Iteration 23, loss = 0.52930488
# Iteration 24, loss = 0.52556618
# Iteration 25, loss = 0.52182310
# Iteration 26, loss = 0.51815028
# Iteration 27, loss = 0.51447147
# Iteration 28, loss = 0.51090199
# Iteration 29, loss = 0.50724646
# Iteration 30, loss = 0.50357515
# Iteration 31, loss = 0.49996367
# Iteration 32, loss = 0.49648809
# Iteration 33, loss = 0.49288156
# Iteration 34, loss = 0.48938388
# Iteration 35, loss = 0.48593481
# Iteration 36, loss = 0.48252160
# Iteration 37, loss = 0.47908904
# Iteration 38, loss = 0.47566358
# Iteration 39, loss = 0.47227883
# Iteration 40, loss = 0.46889234
# Iteration 41, loss = 0.46559211
# Iteration 42, loss = 0.46225921
# Iteration 43, loss = 0.45905891
# Iteration 44, loss = 0.45571728
# Iteration 45, loss = 0.45242765
# Iteration 46, loss = 0.44922831
# Iteration 47, loss = 0.44604261
# Iteration 48, loss = 0.44288168
# Iteration 49, loss = 0.43965534
# Iteration 50, loss = 0.43654626
# Iteration 51, loss = 0.43343332
# Iteration 52, loss = 0.43036620
# Iteration 53, loss = 0.42723563
# Iteration 54, loss = 0.42416048
# Iteration 55, loss = 0.42108535
# Iteration 56, loss = 0.41805930
# Iteration 57, loss = 0.41508428
# Iteration 58, loss = 0.41210712
# Iteration 59, loss = 0.40920110
# Iteration 60, loss = 0.40623324
# Iteration 61, loss = 0.40325228
# Iteration 62, loss = 0.40038680
# Iteration 63, loss = 0.39750177
# Iteration 64, loss = 0.39467831
# Iteration 65, loss = 0.39185681
# Iteration 66, loss = 0.38910691
# Iteration 67, loss = 0.38627359
# Iteration 68, loss = 0.38353981
# Iteration 69, loss = 0.38085696
# Iteration 70, loss = 0.37817906
# Iteration 71, loss = 0.37546073
# Iteration 72, loss = 0.37282466
# Iteration 73, loss = 0.37018903
# Iteration 74, loss = 0.36755776
# Iteration 75, loss = 0.36498406
# Iteration 76, loss = 0.36243442
# Iteration 77, loss = 0.35982841
# Iteration 78, loss = 0.35728819
# Iteration 79, loss = 0.35474592
# Iteration 80, loss = 0.35220635
# Iteration 81, loss = 0.34974052
# Iteration 82, loss = 0.34728680
# Iteration 83, loss = 0.34478844
# Iteration 84, loss = 0.34236171
# Iteration 85, loss = 0.33997868
# Iteration 86, loss = 0.33757403
# Iteration 87, loss = 0.33520654
# Iteration 88, loss = 0.33287342
# Iteration 89, loss = 0.33051162
# Iteration 90, loss = 0.32822652
# Iteration 91, loss = 0.32596037
# Iteration 92, loss = 0.32369358
# Iteration 93, loss = 0.32144131
# Iteration 94, loss = 0.31926458
# Iteration 95, loss = 0.31702503
# Iteration 96, loss = 0.31485761
# Iteration 97, loss = 0.31272077
# Iteration 98, loss = 0.31059970
# Iteration 99, loss = 0.30850157
# Iteration 100, loss = 0.30647000
# Iteration 101, loss = 0.30434622
# Iteration 102, loss = 0.30231529
# Iteration 103, loss = 0.30031931
# Iteration 104, loss = 0.29832361
# Iteration 105, loss = 0.29636425
# Iteration 106, loss = 0.29447287
# Iteration 107, loss = 0.29245946
# Iteration 108, loss = 0.29054918
# Iteration 109, loss = 0.28866034
# Iteration 110, loss = 0.28676609
# Iteration 111, loss = 0.28492482
# Iteration 112, loss = 0.28305530
# Iteration 113, loss = 0.28125573
# Iteration 114, loss = 0.27943746
# Iteration 115, loss = 0.27772214
# Iteration 116, loss = 0.27590548
# Iteration 117, loss = 0.27414678
# Iteration 118, loss = 0.27242767
# Iteration 119, loss = 0.27072404
# Iteration 120, loss = 0.26899980
# Iteration 121, loss = 0.26733335
# Iteration 122, loss = 0.26569008
# Iteration 123, loss = 0.26404292
# Iteration 124, loss = 0.26239941
# Iteration 125, loss = 0.26082830
# Iteration 126, loss = 0.25927804
# Iteration 127, loss = 0.25766739
# Iteration 128, loss = 0.25610834
# Iteration 129, loss = 0.25457451
# Iteration 130, loss = 0.25304495
# Iteration 131, loss = 0.25156833
# Iteration 132, loss = 0.25006795
# Iteration 133, loss = 0.24862282
# Iteration 134, loss = 0.24716461
# Iteration 135, loss = 0.24574097
# Iteration 136, loss = 0.24428863
# Iteration 137, loss = 0.24290328
# Iteration 138, loss = 0.24152716
# Iteration 139, loss = 0.24013578
# Iteration 140, loss = 0.23881117
# Iteration 141, loss = 0.23745950
# Iteration 142, loss = 0.23613262
# Iteration 143, loss = 0.23481323
# Iteration 144, loss = 0.23351391
# Iteration 145, loss = 0.23224578
# Iteration 146, loss = 0.23100453
# Iteration 147, loss = 0.22973941
# Iteration 148, loss = 0.22848294
# Iteration 149, loss = 0.22731121
# Iteration 150, loss = 0.22606225
# Iteration 151, loss = 0.22485578
# Iteration 152, loss = 0.22371160
# Iteration 153, loss = 0.22251802
# Iteration 154, loss = 0.22138763
# Iteration 155, loss = 0.22025599
# Iteration 156, loss = 0.21914318
# Iteration 157, loss = 0.21800582
# Iteration 158, loss = 0.21692344
# Iteration 159, loss = 0.21579174
# Iteration 160, loss = 0.21472221
# Iteration 161, loss = 0.21368691
# Iteration 162, loss = 0.21258668
# Iteration 163, loss = 0.21154470
# Iteration 164, loss = 0.21050844
# Iteration 165, loss = 0.20948046
# Iteration 166, loss = 0.20849064
# Iteration 167, loss = 0.20749380
# Iteration 168, loss = 0.20647350
# Iteration 169, loss = 0.20549011
# Iteration 170, loss = 0.20453368
# Iteration 171, loss = 0.20357652
# Iteration 172, loss = 0.20261315
# Iteration 173, loss = 0.20170706
# Iteration 174, loss = 0.20073765
# Iteration 175, loss = 0.19981768
# Iteration 176, loss = 0.19890579
# Iteration 177, loss = 0.19801842
# Iteration 178, loss = 0.19713364
# Iteration 179, loss = 0.19628305
# Iteration 180, loss = 0.19538113
# Iteration 181, loss = 0.19452449
# Iteration 182, loss = 0.19366883
# Iteration 183, loss = 0.19285594
# Iteration 184, loss = 0.19201424
# Iteration 185, loss = 0.19120974
# Iteration 186, loss = 0.19039615
# Iteration 187, loss = 0.18960826
# Iteration 188, loss = 0.18882774
# Iteration 189, loss = 0.18803041
# Iteration 190, loss = 0.18724586
# Iteration 191, loss = 0.18647875
# Iteration 192, loss = 0.18572616
# Iteration 193, loss = 0.18498392
# Iteration 194, loss = 0.18426245
# Iteration 195, loss = 0.18353802
# Iteration 196, loss = 0.18277340
# Iteration 197, loss = 0.18205040
# Iteration 198, loss = 0.18132579
# Iteration 199, loss = 0.18062616
# Iteration 200, loss = 0.17991752
# Iteration 201, loss = 0.17919497
# Iteration 202, loss = 0.17852915
# Iteration 203, loss = 0.17783991
# Iteration 204, loss = 0.17716832
# Iteration 205, loss = 0.17651946
# Iteration 206, loss = 0.17585721
# Iteration 207, loss = 0.17521233
# Iteration 208, loss = 0.17457096
# Iteration 209, loss = 0.17394289
# Iteration 210, loss = 0.17332321
# Iteration 211, loss = 0.17269386
# Iteration 212, loss = 0.17208120
# Iteration 213, loss = 0.17147851
# Iteration 214, loss = 0.17088021
# Iteration 215, loss = 0.17027723
# Iteration 216, loss = 0.16970321
# Iteration 217, loss = 0.16909913
# Iteration 218, loss = 0.16853687
# Iteration 219, loss = 0.16795244
# Iteration 220, loss = 0.16737967
# Iteration 221, loss = 0.16683755
# Iteration 222, loss = 0.16628415
# Iteration 223, loss = 0.16572540
# Iteration 224, loss = 0.16519169
# Iteration 225, loss = 0.16464431
# Iteration 226, loss = 0.16409646
# Iteration 227, loss = 0.16355971
# Iteration 228, loss = 0.16304858
# Iteration 229, loss = 0.16254310
# Iteration 230, loss = 0.16201037
# Iteration 231, loss = 0.16148546
# Iteration 232, loss = 0.16098799
# Iteration 233, loss = 0.16048342
# Iteration 234, loss = 0.15998232
# Iteration 235, loss = 0.15948268
# Iteration 236, loss = 0.15902066
# Iteration 237, loss = 0.15849940
# Iteration 238, loss = 0.15809932
# Iteration 239, loss = 0.15754206
# Iteration 240, loss = 0.15707542
# Iteration 241, loss = 0.15660926
# Iteration 242, loss = 0.15613819
# Iteration 243, loss = 0.15568154
# Iteration 244, loss = 0.15520705
# Iteration 245, loss = 0.15476625
# Iteration 246, loss = 0.15430818
# Iteration 247, loss = 0.15386297
# Iteration 248, loss = 0.15341944
# Iteration 249, loss = 0.15297606
# Iteration 250, loss = 0.15253592
# Iteration 251, loss = 0.15210970
# Iteration 252, loss = 0.15169794
# Iteration 253, loss = 0.15127450
# Iteration 254, loss = 0.15083067
# Iteration 255, loss = 0.15041640
# Iteration 256, loss = 0.14998036
# Iteration 257, loss = 0.14955404
# Iteration 258, loss = 0.14919408
# Iteration 259, loss = 0.14874356
# Iteration 260, loss = 0.14833062
# Iteration 261, loss = 0.14792865
# Iteration 262, loss = 0.14752545
# Iteration 263, loss = 0.14714227
# Iteration 264, loss = 0.14674433
# Iteration 265, loss = 0.14635748
# Iteration 266, loss = 0.14600526
# Iteration 267, loss = 0.14559530
# Iteration 268, loss = 0.14520657
# Iteration 269, loss = 0.14484349
# Iteration 270, loss = 0.14447389
# Iteration 271, loss = 0.14411565
# Iteration 272, loss = 0.14372612
# Iteration 273, loss = 0.14336050
# Iteration 274, loss = 0.14300342
# Iteration 275, loss = 0.14263450
# Iteration 276, loss = 0.14229092
# Iteration 277, loss = 0.14194089
# Iteration 278, loss = 0.14157796
# Iteration 279, loss = 0.14122350
# Iteration 280, loss = 0.14088333
# Iteration 281, loss = 0.14058495
# Iteration 282, loss = 0.14020302
# Iteration 283, loss = 0.13988487
# Iteration 284, loss = 0.13954150
# Iteration 285, loss = 0.13923555
# Iteration 286, loss = 0.13890315
# Iteration 287, loss = 0.13855505
# Iteration 288, loss = 0.13823328
# Iteration 289, loss = 0.13792157
# Iteration 290, loss = 0.13759017
# Iteration 291, loss = 0.13726062
# Iteration 292, loss = 0.13695430
# Iteration 293, loss = 0.13666056
# Iteration 294, loss = 0.13633135
# Iteration 295, loss = 0.13602778
# Iteration 296, loss = 0.13572657
# Iteration 297, loss = 0.13543511
# Iteration 298, loss = 0.13514043
# Iteration 299, loss = 0.13484706
# Iteration 300, loss = 0.13451910
# Iteration 301, loss = 0.13424850
# Iteration 302, loss = 0.13394994
# Iteration 303, loss = 0.13365602
# Iteration 304, loss = 0.13336094
# Iteration 305, loss = 0.13310735
# Iteration 306, loss = 0.13281000
# Iteration 307, loss = 0.13252878
# Iteration 308, loss = 0.13226634
# Iteration 309, loss = 0.13200392
# Iteration 310, loss = 0.13171435
# Iteration 311, loss = 0.13145418
# Iteration 312, loss = 0.13117257
# Iteration 313, loss = 0.13090069
# Iteration 314, loss = 0.13063635
# Iteration 315, loss = 0.13038037
# Iteration 316, loss = 0.13014035
# Iteration 317, loss = 0.12988123
# Iteration 318, loss = 0.12962252
# Iteration 319, loss = 0.12935574
# Iteration 320, loss = 0.12910407
# Iteration 321, loss = 0.12884969
# Iteration 322, loss = 0.12860290
# Iteration 323, loss = 0.12835617
# Iteration 324, loss = 0.12809819
# Iteration 325, loss = 0.12786999
# Iteration 326, loss = 0.12761345
# Iteration 327, loss = 0.12737812
# Iteration 328, loss = 0.12712908
# Iteration 329, loss = 0.12689902
# Iteration 330, loss = 0.12666594
# Iteration 331, loss = 0.12642867
# Iteration 332, loss = 0.12619500
# Iteration 333, loss = 0.12595843
# Iteration 334, loss = 0.12571143
# Iteration 335, loss = 0.12548868
# Iteration 336, loss = 0.12526763
# Iteration 337, loss = 0.12504220
# Iteration 338, loss = 0.12487229
# Iteration 339, loss = 0.12463226
# Iteration 340, loss = 0.12440029
# Iteration 341, loss = 0.12419117
# Iteration 342, loss = 0.12393815
# Iteration 343, loss = 0.12373205
# Iteration 344, loss = 0.12348957
# Iteration 345, loss = 0.12329876
# Iteration 346, loss = 0.12309709
# Iteration 347, loss = 0.12288277
# Iteration 348, loss = 0.12264919
# Iteration 349, loss = 0.12246809
# Iteration 350, loss = 0.12227275
# Iteration 351, loss = 0.12205878
# Iteration 352, loss = 0.12183071
# Iteration 353, loss = 0.12164558
# Iteration 354, loss = 0.12144427
# Iteration 355, loss = 0.12124477
# Iteration 356, loss = 0.12103258
# Iteration 357, loss = 0.12084921
# Iteration 358, loss = 0.12063151
# Iteration 359, loss = 0.12042198
# Iteration 360, loss = 0.12023546
# Iteration 361, loss = 0.12003286
# Iteration 362, loss = 0.11986458
# Iteration 363, loss = 0.11967146
# Iteration 364, loss = 0.11946414
# Iteration 365, loss = 0.11930354
# Iteration 366, loss = 0.11909932
# Iteration 367, loss = 0.11891600
# Iteration 368, loss = 0.11871588
# Iteration 369, loss = 0.11854489
# Iteration 370, loss = 0.11835309
# Iteration 371, loss = 0.11817820
# Iteration 372, loss = 0.11798897
# Iteration 373, loss = 0.11779626
# Iteration 374, loss = 0.11763301
# Iteration 375, loss = 0.11745846
# Iteration 376, loss = 0.11727397
# Iteration 377, loss = 0.11707712
# Iteration 378, loss = 0.11691354
# Iteration 379, loss = 0.11672445
# Iteration 380, loss = 0.11656974
# Iteration 381, loss = 0.11636947
# Iteration 382, loss = 0.11619859
# Iteration 383, loss = 0.11604504
# Iteration 384, loss = 0.11586277
# Iteration 385, loss = 0.11569023
# Iteration 386, loss = 0.11551433
# Iteration 387, loss = 0.11531922
# Iteration 388, loss = 0.11515458
# Iteration 389, loss = 0.11500015
# Iteration 390, loss = 0.11481724
# Iteration 391, loss = 0.11465139
# Iteration 392, loss = 0.11451276
# Iteration 393, loss = 0.11430456
# Iteration 394, loss = 0.11417550
# Iteration 395, loss = 0.11398781
# Iteration 396, loss = 0.11381930
# Iteration 397, loss = 0.11365955
# Iteration 398, loss = 0.11348568
# Iteration 399, loss = 0.11332136
# Iteration 400, loss = 0.11316407
# Iteration 401, loss = 0.11301404
# Iteration 402, loss = 0.11286484
# Iteration 403, loss = 0.11269765
# Iteration 404, loss = 0.11254009
# Iteration 405, loss = 0.11237830
# Iteration 406, loss = 0.11223540
# Iteration 407, loss = 0.11207041
# Iteration 408, loss = 0.11192037
# Iteration 409, loss = 0.11178099
# Iteration 410, loss = 0.11163735
# Iteration 411, loss = 0.11145969
# Iteration 412, loss = 0.11131498
# Iteration 413, loss = 0.11115511
# Iteration 414, loss = 0.11101195
# Iteration 415, loss = 0.11087290
# Iteration 416, loss = 0.11072573
# Iteration 417, loss = 0.11057802
# Iteration 418, loss = 0.11042568
# Iteration 419, loss = 0.11029407
# Iteration 420, loss = 0.11016208
# Iteration 421, loss = 0.11001350
# Iteration 422, loss = 0.10988152
# Iteration 423, loss = 0.10971430
# Iteration 424, loss = 0.10958477
# Iteration 425, loss = 0.10943302
# Iteration 426, loss = 0.10934147
# Iteration 427, loss = 0.10917043
# Iteration 428, loss = 0.10901242
# Iteration 429, loss = 0.10886880
# Iteration 430, loss = 0.10875418
# Iteration 431, loss = 0.10863016
# Iteration 432, loss = 0.10847018
# Iteration 433, loss = 0.10833398
# Iteration 434, loss = 0.10820848
# Iteration 435, loss = 0.10807653
# Iteration 436, loss = 0.10795859
# Iteration 437, loss = 0.10779952
# Iteration 438, loss = 0.10768293
# Iteration 439, loss = 0.10753396
# Iteration 440, loss = 0.10740278
# Iteration 441, loss = 0.10728348
# Iteration 442, loss = 0.10714908
# Iteration 443, loss = 0.10702403
# Iteration 444, loss = 0.10688055
# Iteration 445, loss = 0.10676345
# Iteration 446, loss = 0.10664627
# Iteration 447, loss = 0.10650126
# Iteration 448, loss = 0.10640228
# Iteration 449, loss = 0.10624712
# Iteration 450, loss = 0.10611735
# Iteration 451, loss = 0.10599464
# Iteration 452, loss = 0.10585265
# Iteration 453, loss = 0.10572219
# Iteration 454, loss = 0.10562177
# Iteration 455, loss = 0.10548941
# Iteration 456, loss = 0.10537219
# Iteration 457, loss = 0.10532338
# Iteration 458, loss = 0.10513436
# Iteration 459, loss = 0.10502550
# Iteration 460, loss = 0.10488510
# Iteration 461, loss = 0.10477135
# Iteration 462, loss = 0.10466165
# Iteration 463, loss = 0.10453152
# Iteration 464, loss = 0.10441329
# Iteration 465, loss = 0.10429044
# Iteration 466, loss = 0.10420190
# Iteration 467, loss = 0.10408194
# Iteration 468, loss = 0.10394908
# Iteration 469, loss = 0.10383046
# Iteration 470, loss = 0.10374130
# Iteration 471, loss = 0.10358595
# Iteration 472, loss = 0.10350753
# Iteration 473, loss = 0.10338335
# Iteration 474, loss = 0.10328158
# Iteration 475, loss = 0.10315137
# Iteration 476, loss = 0.10304847
# Iteration 477, loss = 0.10293138
# Iteration 478, loss = 0.10282335
# Iteration 479, loss = 0.10270532
# Iteration 480, loss = 0.10261839
# Iteration 481, loss = 0.10248254
# Iteration 482, loss = 0.10239042
# Iteration 483, loss = 0.10227725
# Iteration 484, loss = 0.10215287
# Iteration 485, loss = 0.10205391
# Iteration 486, loss = 0.10194619
# Iteration 487, loss = 0.10182862
# Iteration 488, loss = 0.10172255
# Iteration 489, loss = 0.10162776
# Iteration 490, loss = 0.10153241
# Iteration 491, loss = 0.10142894
# Iteration 492, loss = 0.10131859
# Iteration 493, loss = 0.10119205
# Iteration 494, loss = 0.10112584
# Iteration 495, loss = 0.10101796
# Iteration 496, loss = 0.10089312
# Iteration 497, loss = 0.10077849
# Iteration 498, loss = 0.10068601
# Iteration 499, loss = 0.10058671
# Iteration 500, loss = 0.10048177
# Iteration 501, loss = 0.10039845
# Iteration 502, loss = 0.10028519
# Iteration 503, loss = 0.10016184
# Iteration 504, loss = 0.10008735
# Iteration 505, loss = 0.09997176
# Iteration 506, loss = 0.09987981
# Iteration 507, loss = 0.09980642
# Iteration 508, loss = 0.09971141
# Iteration 509, loss = 0.09960527
# Iteration 510, loss = 0.09947817
# Iteration 511, loss = 0.09937844
# Iteration 512, loss = 0.09930124
# Iteration 513, loss = 0.09918889
# Iteration 514, loss = 0.09910141
# Iteration 515, loss = 0.09901947
# Iteration 516, loss = 0.09891998
# Iteration 517, loss = 0.09880712
# Iteration 518, loss = 0.09872066
# Iteration 519, loss = 0.09862510
# Iteration 520, loss = 0.09855518
# Iteration 521, loss = 0.09846588
# Iteration 522, loss = 0.09834467
# Iteration 523, loss = 0.09825442
# Iteration 524, loss = 0.09816274
# Iteration 525, loss = 0.09809339
# Iteration 526, loss = 0.09797342
# Iteration 527, loss = 0.09790861
# Iteration 528, loss = 0.09778306
# Iteration 529, loss = 0.09769879
# Iteration 530, loss = 0.09761773
# Iteration 531, loss = 0.09751378
# Iteration 532, loss = 0.09743095
# Iteration 533, loss = 0.09733718
# Iteration 534, loss = 0.09726265
# Iteration 535, loss = 0.09719498
# Iteration 536, loss = 0.09708206
# Iteration 537, loss = 0.09698929
# Iteration 538, loss = 0.09690572
# Iteration 539, loss = 0.09681315
# Iteration 540, loss = 0.09672816
# Iteration 541, loss = 0.09664749
# Iteration 542, loss = 0.09659526
# Iteration 543, loss = 0.09645763
# Iteration 544, loss = 0.09639212
# Iteration 545, loss = 0.09629340
# Iteration 546, loss = 0.09620694
# Iteration 547, loss = 0.09612326
# Iteration 548, loss = 0.09605679
# Iteration 549, loss = 0.09596779
# Iteration 550, loss = 0.09589309
# Iteration 551, loss = 0.09580925
# Iteration 552, loss = 0.09570626
# Iteration 553, loss = 0.09565920
# Iteration 554, loss = 0.09552904
# Iteration 555, loss = 0.09546701
# Iteration 556, loss = 0.09538054
# Iteration 557, loss = 0.09529508
# Iteration 558, loss = 0.09520459
# Iteration 559, loss = 0.09512213
# Iteration 560, loss = 0.09503107
# Iteration 561, loss = 0.09495930
# Iteration 562, loss = 0.09486942
# Iteration 563, loss = 0.09479359
# Iteration 564, loss = 0.09474246
# Iteration 565, loss = 0.09463183
# Iteration 566, loss = 0.09456035
# Iteration 567, loss = 0.09449374
# Iteration 568, loss = 0.09442346
# Iteration 569, loss = 0.09432544
# Iteration 570, loss = 0.09424541
# Iteration 571, loss = 0.09417857
# Iteration 572, loss = 0.09408008
# Iteration 573, loss = 0.09401019
# Iteration 574, loss = 0.09392792
# Iteration 575, loss = 0.09385954
# Iteration 576, loss = 0.09377153
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Iteration 1, loss = 0.64700853
# Iteration 2, loss = 0.64103063
# Iteration 3, loss = 0.63530203
# Iteration 4, loss = 0.62961695
# Iteration 5, loss = 0.62405730
# Iteration 6, loss = 0.61863194
# Iteration 7, loss = 0.61333496
# Iteration 8, loss = 0.60796297
# Iteration 9, loss = 0.60279445
# Iteration 10, loss = 0.59765778
# Iteration 11, loss = 0.59257258
# Iteration 12, loss = 0.58765278
# Iteration 13, loss = 0.58269801
# Iteration 14, loss = 0.57785471
# Iteration 15, loss = 0.57308925
# Iteration 16, loss = 0.56822427
# Iteration 17, loss = 0.56356337
# Iteration 18, loss = 0.55895613
# Iteration 19, loss = 0.55434608
# Iteration 20, loss = 0.54982879
# Iteration 21, loss = 0.54536452
# Iteration 22, loss = 0.54107768
# Iteration 23, loss = 0.53649695
# Iteration 24, loss = 0.53218405
# Iteration 25, loss = 0.52789691
# Iteration 26, loss = 0.52365438
# Iteration 27, loss = 0.51946463
# Iteration 28, loss = 0.51536647
# Iteration 29, loss = 0.51122218
# Iteration 30, loss = 0.50711228
# Iteration 31, loss = 0.50306477
# Iteration 32, loss = 0.49904940
# Iteration 33, loss = 0.49502726
# Iteration 34, loss = 0.49107223
# Iteration 35, loss = 0.48715639
# Iteration 36, loss = 0.48326104
# Iteration 37, loss = 0.47936276
# Iteration 38, loss = 0.47552830
# Iteration 39, loss = 0.47172359
# Iteration 40, loss = 0.46788696
# Iteration 41, loss = 0.46415413
# Iteration 42, loss = 0.46046644
# Iteration 43, loss = 0.45677225
# Iteration 44, loss = 0.45307001
# Iteration 45, loss = 0.44939360
# Iteration 46, loss = 0.44580638
# Iteration 47, loss = 0.44223534
# Iteration 48, loss = 0.43868748
# Iteration 49, loss = 0.43516129
# Iteration 50, loss = 0.43177761
# Iteration 51, loss = 0.42834205
# Iteration 52, loss = 0.42498673
# Iteration 53, loss = 0.42166004
# Iteration 54, loss = 0.41833269
# Iteration 55, loss = 0.41500299
# Iteration 56, loss = 0.41173969
# Iteration 57, loss = 0.40852280
# Iteration 58, loss = 0.40532904
# Iteration 59, loss = 0.40214681
# Iteration 60, loss = 0.39897654
# Iteration 61, loss = 0.39585717
# Iteration 62, loss = 0.39274859
# Iteration 63, loss = 0.38971006
# Iteration 64, loss = 0.38670122
# Iteration 65, loss = 0.38371743
# Iteration 66, loss = 0.38081775
# Iteration 67, loss = 0.37785242
# Iteration 68, loss = 0.37493446
# Iteration 69, loss = 0.37209165
# Iteration 70, loss = 0.36924035
# Iteration 71, loss = 0.36644723
# Iteration 72, loss = 0.36368703
# Iteration 73, loss = 0.36096141
# Iteration 74, loss = 0.35817331
# Iteration 75, loss = 0.35547159
# Iteration 76, loss = 0.35283068
# Iteration 77, loss = 0.35015652
# Iteration 78, loss = 0.34756625
# Iteration 79, loss = 0.34499449
# Iteration 80, loss = 0.34247612
# Iteration 81, loss = 0.33997429
# Iteration 82, loss = 0.33744590
# Iteration 83, loss = 0.33495105
# Iteration 84, loss = 0.33252849
# Iteration 85, loss = 0.33010981
# Iteration 86, loss = 0.32769359
# Iteration 87, loss = 0.32532680
# Iteration 88, loss = 0.32297750
# Iteration 89, loss = 0.32064949
# Iteration 90, loss = 0.31835989
# Iteration 91, loss = 0.31607921
# Iteration 92, loss = 0.31385816
# Iteration 93, loss = 0.31167036
# Iteration 94, loss = 0.30948455
# Iteration 95, loss = 0.30731268
# Iteration 96, loss = 0.30514588
# Iteration 97, loss = 0.30307342
# Iteration 98, loss = 0.30098723
# Iteration 99, loss = 0.29889727
# Iteration 100, loss = 0.29693694
# Iteration 101, loss = 0.29481815
# Iteration 102, loss = 0.29285575
# Iteration 103, loss = 0.29089898
# Iteration 104, loss = 0.28893256
# Iteration 105, loss = 0.28698678
# Iteration 106, loss = 0.28512997
# Iteration 107, loss = 0.28323243
# Iteration 108, loss = 0.28140332
# Iteration 109, loss = 0.27957100
# Iteration 110, loss = 0.27770994
# Iteration 111, loss = 0.27594797
# Iteration 112, loss = 0.27414644
# Iteration 113, loss = 0.27241279
# Iteration 114, loss = 0.27065095
# Iteration 115, loss = 0.26898918
# Iteration 116, loss = 0.26730107
# Iteration 117, loss = 0.26562795
# Iteration 118, loss = 0.26398765
# Iteration 119, loss = 0.26236917
# Iteration 120, loss = 0.26072367
# Iteration 121, loss = 0.25915685
# Iteration 122, loss = 0.25758936
# Iteration 123, loss = 0.25601982
# Iteration 124, loss = 0.25447254
# Iteration 125, loss = 0.25293512
# Iteration 126, loss = 0.25150301
# Iteration 127, loss = 0.24995739
# Iteration 128, loss = 0.24848304
# Iteration 129, loss = 0.24705108
# Iteration 130, loss = 0.24560903
# Iteration 131, loss = 0.24419065
# Iteration 132, loss = 0.24279375
# Iteration 133, loss = 0.24141070
# Iteration 134, loss = 0.24004323
# Iteration 135, loss = 0.23872843
# Iteration 136, loss = 0.23734208
# Iteration 137, loss = 0.23603565
# Iteration 138, loss = 0.23475004
# Iteration 139, loss = 0.23343443
# Iteration 140, loss = 0.23215203
# Iteration 141, loss = 0.23089561
# Iteration 142, loss = 0.22966501
# Iteration 143, loss = 0.22842691
# Iteration 144, loss = 0.22722185
# Iteration 145, loss = 0.22600723
# Iteration 146, loss = 0.22483335
# Iteration 147, loss = 0.22368537
# Iteration 148, loss = 0.22249474
# Iteration 149, loss = 0.22139355
# Iteration 150, loss = 0.22025283
# Iteration 151, loss = 0.21912171
# Iteration 152, loss = 0.21804377
# Iteration 153, loss = 0.21695734
# Iteration 154, loss = 0.21590085
# Iteration 155, loss = 0.21482886
# Iteration 156, loss = 0.21380164
# Iteration 157, loss = 0.21277768
# Iteration 158, loss = 0.21173447
# Iteration 159, loss = 0.21070660
# Iteration 160, loss = 0.20969936
# Iteration 161, loss = 0.20871042
# Iteration 162, loss = 0.20773823
# Iteration 163, loss = 0.20676377
# Iteration 164, loss = 0.20579838
# Iteration 165, loss = 0.20483721
# Iteration 166, loss = 0.20391196
# Iteration 167, loss = 0.20300864
# Iteration 168, loss = 0.20203395
# Iteration 169, loss = 0.20114386
# Iteration 170, loss = 0.20025511
# Iteration 171, loss = 0.19934369
# Iteration 172, loss = 0.19846975
# Iteration 173, loss = 0.19760993
# Iteration 174, loss = 0.19673329
# Iteration 175, loss = 0.19588341
# Iteration 176, loss = 0.19503859
# Iteration 177, loss = 0.19420387
# Iteration 178, loss = 0.19336895
# Iteration 179, loss = 0.19256136
# Iteration 180, loss = 0.19173703
# Iteration 181, loss = 0.19092159
# Iteration 182, loss = 0.19014792
# Iteration 183, loss = 0.18937561
# Iteration 184, loss = 0.18858327
# Iteration 185, loss = 0.18783055
# Iteration 186, loss = 0.18707412
# Iteration 187, loss = 0.18630245
# Iteration 188, loss = 0.18558786
# Iteration 189, loss = 0.18484622
# Iteration 190, loss = 0.18411626
# Iteration 191, loss = 0.18338767
# Iteration 192, loss = 0.18268313
# Iteration 193, loss = 0.18200563
# Iteration 194, loss = 0.18130605
# Iteration 195, loss = 0.18061127
# Iteration 196, loss = 0.17991846
# Iteration 197, loss = 0.17922212
# Iteration 198, loss = 0.17857545
# Iteration 199, loss = 0.17791328
# Iteration 200, loss = 0.17725810
# Iteration 201, loss = 0.17659284
# Iteration 202, loss = 0.17595656
# Iteration 203, loss = 0.17530795
# Iteration 204, loss = 0.17468535
# Iteration 205, loss = 0.17408616
# Iteration 206, loss = 0.17346057
# Iteration 207, loss = 0.17285476
# Iteration 208, loss = 0.17223189
# Iteration 209, loss = 0.17164420
# Iteration 210, loss = 0.17103744
# Iteration 211, loss = 0.17046502
# Iteration 212, loss = 0.16989514
# Iteration 213, loss = 0.16933237
# Iteration 214, loss = 0.16873451
# Iteration 215, loss = 0.16817056
# Iteration 216, loss = 0.16761567
# Iteration 217, loss = 0.16705836
# Iteration 218, loss = 0.16649200
# Iteration 219, loss = 0.16594659
# Iteration 220, loss = 0.16541363
# Iteration 221, loss = 0.16486563
# Iteration 222, loss = 0.16433041
# Iteration 223, loss = 0.16378929
# Iteration 224, loss = 0.16329989
# Iteration 225, loss = 0.16275134
# Iteration 226, loss = 0.16222985
# Iteration 227, loss = 0.16170093
# Iteration 228, loss = 0.16120339
# Iteration 229, loss = 0.16069815
# Iteration 230, loss = 0.16018517
# Iteration 231, loss = 0.15969196
# Iteration 232, loss = 0.15918875
# Iteration 233, loss = 0.15871160
# Iteration 234, loss = 0.15825664
# Iteration 235, loss = 0.15777128
# Iteration 236, loss = 0.15733627
# Iteration 237, loss = 0.15680799
# Iteration 238, loss = 0.15635361
# Iteration 239, loss = 0.15588482
# Iteration 240, loss = 0.15542169
# Iteration 241, loss = 0.15497486
# Iteration 242, loss = 0.15450745
# Iteration 243, loss = 0.15410640
# Iteration 244, loss = 0.15361170
# Iteration 245, loss = 0.15318385
# Iteration 246, loss = 0.15274218
# Iteration 247, loss = 0.15232709
# Iteration 248, loss = 0.15187854
# Iteration 249, loss = 0.15145458
# Iteration 250, loss = 0.15103699
# Iteration 251, loss = 0.15059845
# Iteration 252, loss = 0.15019497
# Iteration 253, loss = 0.14979843
# Iteration 254, loss = 0.14937019
# Iteration 255, loss = 0.14896300
# Iteration 256, loss = 0.14853662
# Iteration 257, loss = 0.14816199
# Iteration 258, loss = 0.14777126
# Iteration 259, loss = 0.14735249
# Iteration 260, loss = 0.14696249
# Iteration 261, loss = 0.14656673
# Iteration 262, loss = 0.14617192
# Iteration 263, loss = 0.14581073
# Iteration 264, loss = 0.14543000
# Iteration 265, loss = 0.14505526
# Iteration 266, loss = 0.14469225
# Iteration 267, loss = 0.14429943
# Iteration 268, loss = 0.14393988
# Iteration 269, loss = 0.14357432
# Iteration 270, loss = 0.14323193
# Iteration 271, loss = 0.14284836
# Iteration 272, loss = 0.14249305
# Iteration 273, loss = 0.14213640
# Iteration 274, loss = 0.14179220
# Iteration 275, loss = 0.14146235
# Iteration 276, loss = 0.14110433
# Iteration 277, loss = 0.14078912
# Iteration 278, loss = 0.14041872
# Iteration 279, loss = 0.14012698
# Iteration 280, loss = 0.13976664
# Iteration 281, loss = 0.13944236
# Iteration 282, loss = 0.13913752
# Iteration 283, loss = 0.13876188
# Iteration 284, loss = 0.13847010
# Iteration 285, loss = 0.13811872
# Iteration 286, loss = 0.13782573
# Iteration 287, loss = 0.13746902
# Iteration 288, loss = 0.13717081
# Iteration 289, loss = 0.13684317
# Iteration 290, loss = 0.13655733
# ...
# Iteration 78, loss = 0.35069877
# Iteration 79, loss = 0.34821124
# Iteration 80, loss = 0.34562798
# Iteration 81, loss = 0.34307961
# Iteration 82, loss = 0.34060780
# Iteration 83, loss = 0.33818181
# Iteration 84, loss = 0.33579616
# Iteration 85, loss = 0.33340939
# Iteration 86, loss = 0.33104394
# Iteration 87, loss = 0.32863327
# Iteration 88, loss = 0.32633700
# Iteration 89, loss = 0.32402626
# Iteration 90, loss = 0.32169365
# Iteration 91, loss = 0.31949352
# Iteration 92, loss = 0.31720695
# Iteration 93, loss = 0.31503757
# Iteration 94, loss = 0.31284537
# Iteration 95, loss = 0.31070023
# Iteration 96, loss = 0.30853724
# Iteration 97, loss = 0.30643097
# Iteration 98, loss = 0.30433725
# Iteration 99, loss = 0.30228462
# Iteration 100, loss = 0.30026745
# Iteration 101, loss = 0.29826229
# Iteration 102, loss = 0.29616024
# Iteration 103, loss = 0.29418089
# Iteration 104, loss = 0.29220682
# Iteration 105, loss = 0.29025588
# Iteration 106, loss = 0.28831696
# Iteration 107, loss = 0.28639152
# Iteration 108, loss = 0.28450967
# Iteration 109, loss = 0.28261417
# Iteration 110, loss = 0.28077247
# Iteration 111, loss = 0.27896012
# Iteration 112, loss = 0.27716574
# Iteration 113, loss = 0.27540699
# Iteration 114, loss = 0.27364748
# Iteration 115, loss = 0.27190980
# Iteration 116, loss = 0.27019060
# Iteration 117, loss = 0.26851183
# Iteration 118, loss = 0.26683689
# Iteration 119, loss = 0.26516201
# Iteration 120, loss = 0.26353125
# Iteration 121, loss = 0.26191508
# Iteration 122, loss = 0.26031268
# Iteration 123, loss = 0.25874067
# Iteration 124, loss = 0.25716233
# Iteration 125, loss = 0.25560767
# Iteration 126, loss = 0.25410866
# Iteration 127, loss = 0.25259527
# Iteration 128, loss = 0.25109339
# Iteration 129, loss = 0.24961758
# Iteration 130, loss = 0.24817930
# Iteration 131, loss = 0.24674057
# Iteration 132, loss = 0.24532611
# Iteration 133, loss = 0.24392169
# Iteration 134, loss = 0.24255629
# Iteration 135, loss = 0.24119181
# Iteration 136, loss = 0.23985099
# Iteration 137, loss = 0.23847923
# Iteration 138, loss = 0.23714398
# Iteration 139, loss = 0.23582677
# Iteration 140, loss = 0.23453727
# Iteration 141, loss = 0.23326902
# Iteration 142, loss = 0.23199878
# Iteration 143, loss = 0.23075466
# Iteration 144, loss = 0.22953516
# Iteration 145, loss = 0.22832286
# Iteration 146, loss = 0.22710671
# Iteration 147, loss = 0.22594031
# Iteration 148, loss = 0.22471582
# Iteration 149, loss = 0.22359203
# Iteration 150, loss = 0.22243956
# Iteration 151, loss = 0.22132172
# Iteration 152, loss = 0.22018969
# Iteration 153, loss = 0.21909223
# Iteration 154, loss = 0.21799782
# Iteration 155, loss = 0.21688574
# Iteration 156, loss = 0.21584586
# Iteration 157, loss = 0.21482391
# Iteration 158, loss = 0.21373926
# Iteration 159, loss = 0.21271889
# Iteration 160, loss = 0.21167808
# Iteration 161, loss = 0.21069909
# Iteration 162, loss = 0.20966592
# Iteration 163, loss = 0.20866341
# Iteration 164, loss = 0.20770674
# Iteration 165, loss = 0.20671839
# Iteration 166, loss = 0.20575590
# Iteration 167, loss = 0.20482091
# Iteration 168, loss = 0.20392530
# Iteration 169, loss = 0.20297060
# Iteration 170, loss = 0.20203631
# Iteration 171, loss = 0.20112636
# Iteration 172, loss = 0.20022688
# Iteration 173, loss = 0.19934182
# Iteration 174, loss = 0.19846680
# Iteration 175, loss = 0.19758748
# Iteration 176, loss = 0.19670540
# Iteration 177, loss = 0.19583689
# Iteration 178, loss = 0.19498888
# Iteration 179, loss = 0.19414642
# Iteration 180, loss = 0.19332750
# Iteration 181, loss = 0.19250413
# Iteration 182, loss = 0.19170883
# Iteration 183, loss = 0.19088460
# Iteration 184, loss = 0.19007933
# Iteration 185, loss = 0.18929592
# Iteration 186, loss = 0.18852012
# Iteration 187, loss = 0.18775462
# Iteration 188, loss = 0.18699362
# Iteration 189, loss = 0.18621546
# Iteration 190, loss = 0.18548548
# Iteration 191, loss = 0.18469916
# Iteration 192, loss = 0.18399926
# Iteration 193, loss = 0.18324219
# Iteration 194, loss = 0.18255976
# Iteration 195, loss = 0.18180361
# Iteration 196, loss = 0.18111252
# Iteration 197, loss = 0.18043039
# Iteration 198, loss = 0.17975361
# Iteration 199, loss = 0.17902585
# Iteration 200, loss = 0.17835975
# Iteration 201, loss = 0.17771247
# Iteration 202, loss = 0.17700985
# Iteration 203, loss = 0.17636120
# Iteration 204, loss = 0.17571718
# Iteration 205, loss = 0.17506487
# Iteration 206, loss = 0.17443423
# Iteration 207, loss = 0.17380271
# Iteration 208, loss = 0.17316389
# Iteration 209, loss = 0.17254198
# Iteration 210, loss = 0.17195909
# Iteration 211, loss = 0.17132888
# Iteration 212, loss = 0.17072705
# Iteration 213, loss = 0.17013873
# Iteration 214, loss = 0.16953433
# Iteration 215, loss = 0.16897867
# Iteration 216, loss = 0.16840487
# Iteration 217, loss = 0.16780653
# Iteration 218, loss = 0.16725364
# Iteration 219, loss = 0.16666900
# Iteration 220, loss = 0.16611027
# Iteration 221, loss = 0.16553738
# Iteration 222, loss = 0.16500946
# Iteration 223, loss = 0.16446762
# Iteration 224, loss = 0.16389890
# Iteration 225, loss = 0.16337554
# Iteration 226, loss = 0.16286035
# Iteration 227, loss = 0.16230581
# Iteration 228, loss = 0.16179964
# Iteration 229, loss = 0.16129473
# Iteration 230, loss = 0.16080279
# Iteration 231, loss = 0.16025887
# Iteration 232, loss = 0.15975469
# Iteration 233, loss = 0.15928084
# Iteration 234, loss = 0.15878241
# Iteration 235, loss = 0.15827828
# Iteration 236, loss = 0.15777419
# Iteration 237, loss = 0.15732809
# Iteration 238, loss = 0.15684454
# Iteration 239, loss = 0.15635642
# Iteration 240, loss = 0.15589474
# Iteration 241, loss = 0.15540671
# Iteration 242, loss = 0.15494730
# Iteration 243, loss = 0.15450522
# Iteration 244, loss = 0.15402882
# Iteration 245, loss = 0.15357172
# Iteration 246, loss = 0.15313320
# Iteration 247, loss = 0.15267203
# Iteration 248, loss = 0.15222713
# Iteration 249, loss = 0.15180207
# Iteration 250, loss = 0.15136672
# Iteration 251, loss = 0.15093234
# Iteration 252, loss = 0.15049164
# Iteration 253, loss = 0.15006795
# Iteration 254, loss = 0.14965050
# Iteration 255, loss = 0.14924577
# Iteration 256, loss = 0.14880257
# Iteration 257, loss = 0.14838923
# Iteration 258, loss = 0.14798714
# Iteration 259, loss = 0.14759140
# Iteration 260, loss = 0.14720197
# Iteration 261, loss = 0.14677192
# Iteration 262, loss = 0.14638184
# Iteration 263, loss = 0.14598256
# Iteration 264, loss = 0.14558708
# Iteration 265, loss = 0.14520845
# Iteration 266, loss = 0.14482284
# Iteration 267, loss = 0.14445237
# Iteration 268, loss = 0.14407556
# Iteration 269, loss = 0.14369654
# Iteration 270, loss = 0.14333056
# Iteration 271, loss = 0.14292824
# Iteration 272, loss = 0.14257181
# Iteration 273, loss = 0.14218221
# Iteration 274, loss = 0.14182666
# Iteration 275, loss = 0.14146449
# Iteration 276, loss = 0.14110529
# Iteration 277, loss = 0.14075703
# Iteration 278, loss = 0.14039248
# Iteration 279, loss = 0.14003958
# Iteration 280, loss = 0.13968940
# Iteration 281, loss = 0.13935184
# Iteration 282, loss = 0.13900416
# Iteration 283, loss = 0.13868960
# Iteration 284, loss = 0.13832791
# Iteration 285, loss = 0.13801584
# Iteration 286, loss = 0.13766627
# Iteration 287, loss = 0.13734688
# Iteration 288, loss = 0.13703578
# Iteration 289, loss = 0.13669374
# Iteration 290, loss = 0.13637669
# Iteration 291, loss = 0.13605119
# Iteration 292, loss = 0.13574534
# Iteration 293, loss = 0.13541909
# Iteration 294, loss = 0.13510520
# Iteration 295, loss = 0.13479651
# Iteration 296, loss = 0.13447501
# Iteration 297, loss = 0.13415662
# Iteration 298, loss = 0.13387831
# Iteration 299, loss = 0.13355618
# Iteration 300, loss = 0.13327437
# Iteration 301, loss = 0.13297412
# Iteration 302, loss = 0.13268231
# Iteration 303, loss = 0.13237707
# Iteration 304, loss = 0.13207985
# Iteration 305, loss = 0.13179993
# Iteration 306, loss = 0.13152277
# Iteration 307, loss = 0.13122751
# Iteration 308, loss = 0.13092260
# Iteration 309, loss = 0.13063875
# Iteration 310, loss = 0.13036948
# Iteration 311, loss = 0.13008896
# Iteration 312, loss = 0.12981079
# Iteration 313, loss = 0.12952327
# Iteration 314, loss = 0.12925643
# Iteration 315, loss = 0.12899332
# Iteration 316, loss = 0.12870278
# Iteration 317, loss = 0.12844894
# Iteration 318, loss = 0.12816936
# Iteration 319, loss = 0.12790156
# Iteration 320, loss = 0.12763729
# Iteration 321, loss = 0.12737638
# Iteration 322, loss = 0.12710676
# Iteration 323, loss = 0.12684058
# Iteration 324, loss = 0.12659675
# Iteration 325, loss = 0.12634607
# Iteration 326, loss = 0.12607636
# Iteration 327, loss = 0.12581491
# Iteration 328, loss = 0.12557940
# Iteration 329, loss = 0.12531628
# Iteration 330, loss = 0.12509316
# Iteration 331, loss = 0.12479826
# Iteration 332, loss = 0.12456331
# Iteration 333, loss = 0.12431831
# Iteration 334, loss = 0.12409530
# Iteration 335, loss = 0.12383542
# Iteration 336, loss = 0.12358721
# Iteration 337, loss = 0.12336342
# Iteration 338, loss = 0.12310656
# Iteration 339, loss = 0.12286851
# Iteration 340, loss = 0.12264744
# Iteration 341, loss = 0.12242569
# Iteration 342, loss = 0.12217598
# Iteration 343, loss = 0.12195036
# Iteration 344, loss = 0.12171002
# Iteration 345, loss = 0.12148618
# Iteration 346, loss = 0.12124682
# Iteration 347, loss = 0.12102212
# Iteration 348, loss = 0.12079700
# Iteration 349, loss = 0.12059430
# Iteration 350, loss = 0.12037691
# Iteration 351, loss = 0.12014459
# Iteration 352, loss = 0.11992849
# Iteration 353, loss = 0.11970895
# Iteration 354, loss = 0.11949430
# Iteration 355, loss = 0.11928751
# Iteration 356, loss = 0.11908164
# Iteration 357, loss = 0.11888331
# Iteration 358, loss = 0.11865936
# Iteration 359, loss = 0.11845279
# Iteration 360, loss = 0.11825162
# Iteration 361, loss = 0.11803621
# Iteration 362, loss = 0.11781952
# Iteration 363, loss = 0.11762581
# Iteration 364, loss = 0.11741758
# Iteration 365, loss = 0.11724312
# Iteration 366, loss = 0.11703468
# Iteration 367, loss = 0.11683890
# Iteration 368, loss = 0.11664153
# Iteration 369, loss = 0.11644310
# Iteration 370, loss = 0.11623329
# Iteration 371, loss = 0.11604698
# Iteration 372, loss = 0.11585455
# Iteration 373, loss = 0.11566642
# Iteration 374, loss = 0.11548942
# Iteration 375, loss = 0.11528515
# Iteration 376, loss = 0.11508705
# Iteration 377, loss = 0.11492468
# Iteration 378, loss = 0.11473700
# Iteration 379, loss = 0.11453559
# Iteration 380, loss = 0.11435114
# Iteration 381, loss = 0.11416738
# Iteration 382, loss = 0.11398579
# Iteration 383, loss = 0.11380500
# Iteration 384, loss = 0.11362338
# Iteration 385, loss = 0.11346959
# Iteration 386, loss = 0.11326304
# Iteration 387, loss = 0.11308079
# Iteration 388, loss = 0.11292438
# Iteration 389, loss = 0.11271261
# Iteration 390, loss = 0.11254479
# Iteration 391, loss = 0.11237385
# Iteration 392, loss = 0.11220101
# Iteration 393, loss = 0.11202669
# Iteration 394, loss = 0.11187197
# Iteration 395, loss = 0.11167447
# Iteration 396, loss = 0.11152892
# Iteration 397, loss = 0.11134065
# Iteration 398, loss = 0.11118147
# Iteration 399, loss = 0.11101425
# Iteration 400, loss = 0.11083932
# Iteration 401, loss = 0.11066280
# Iteration 402, loss = 0.11049812
# Iteration 403, loss = 0.11032901
# Iteration 404, loss = 0.11017244
# Iteration 405, loss = 0.11000574
# Iteration 406, loss = 0.10985317
# Iteration 407, loss = 0.10969561
# Iteration 408, loss = 0.10954355
# Iteration 409, loss = 0.10937409
# Iteration 410, loss = 0.10920208
# Iteration 411, loss = 0.10906994
# Iteration 412, loss = 0.10891092
# Iteration 413, loss = 0.10872557
# Iteration 414, loss = 0.10858143
# Iteration 415, loss = 0.10843434
# Iteration 416, loss = 0.10828043
# Iteration 417, loss = 0.10813460
# Iteration 418, loss = 0.10796550
# Iteration 419, loss = 0.10781302
# Iteration 420, loss = 0.10766431
# Iteration 421, loss = 0.10750845
# Iteration 422, loss = 0.10736087
# Iteration 423, loss = 0.10721546
# Iteration 424, loss = 0.10706264
# Iteration 425, loss = 0.10691081
# Iteration 426, loss = 0.10677594
# Iteration 427, loss = 0.10661492
# Iteration 428, loss = 0.10649597
# Iteration 429, loss = 0.10634314
# Iteration 430, loss = 0.10618822
# Iteration 431, loss = 0.10604842
# Iteration 432, loss = 0.10589146
# Iteration 433, loss = 0.10576043
# Iteration 434, loss = 0.10563050
# Iteration 435, loss = 0.10549121
# Iteration 436, loss = 0.10534486
# Iteration 437, loss = 0.10521050
# Iteration 438, loss = 0.10508986
# Iteration 439, loss = 0.10492306
# Iteration 440, loss = 0.10479038
# Iteration 441, loss = 0.10465382
# Iteration 442, loss = 0.10451858
# Iteration 443, loss = 0.10438657
# Iteration 444, loss = 0.10427274
# Iteration 445, loss = 0.10411370
# Iteration 446, loss = 0.10398288
# Iteration 447, loss = 0.10385277
# Iteration 448, loss = 0.10371154
# Iteration 449, loss = 0.10358277
# Iteration 450, loss = 0.10345684
# Iteration 451, loss = 0.10332692
# Iteration 452, loss = 0.10320989
# Iteration 453, loss = 0.10306709
# Iteration 454, loss = 0.10293671
# Iteration 455, loss = 0.10284599
# Iteration 456, loss = 0.10267822
# Iteration 457, loss = 0.10256165
# Iteration 458, loss = 0.10243480
# Iteration 459, loss = 0.10232448
# Iteration 460, loss = 0.10218706
# Iteration 461, loss = 0.10207323
# Iteration 462, loss = 0.10192500
# Iteration 463, loss = 0.10182904
# Iteration 464, loss = 0.10169863
# Iteration 465, loss = 0.10155960
# Iteration 466, loss = 0.10144876
# Iteration 467, loss = 0.10131616
# Iteration 468, loss = 0.10122552
# Iteration 469, loss = 0.10107836
# Iteration 470, loss = 0.10097458
# Iteration 471, loss = 0.10084351
# Iteration 472, loss = 0.10074709
# Iteration 473, loss = 0.10061174
# Iteration 474, loss = 0.10048685
# Iteration 475, loss = 0.10039219
# Iteration 476, loss = 0.10026252
# Iteration 477, loss = 0.10015259
# Iteration 478, loss = 0.10003709
# Iteration 479, loss = 0.09992255
# Iteration 480, loss = 0.09982088
# Iteration 481, loss = 0.09969788
# Iteration 482, loss = 0.09956269
# Iteration 483, loss = 0.09947340
# Iteration 484, loss = 0.09934364
# Iteration 485, loss = 0.09926489
# Iteration 486, loss = 0.09912167
# Iteration 487, loss = 0.09901307
# Iteration 488, loss = 0.09892218
# Iteration 489, loss = 0.09879141
# Iteration 490, loss = 0.09868918
# Iteration 491, loss = 0.09857780
# Iteration 492, loss = 0.09845874
# Iteration 493, loss = 0.09836149
# Iteration 494, loss = 0.09825009
# Iteration 495, loss = 0.09814419
# Iteration 496, loss = 0.09803907
# Iteration 497, loss = 0.09794352
# Iteration 498, loss = 0.09783604
# Iteration 499, loss = 0.09772191
# Iteration 500, loss = 0.09763305
# Iteration 501, loss = 0.09752174
# Iteration 502, loss = 0.09741714
# Iteration 503, loss = 0.09729882
# Iteration 504, loss = 0.09721749
# Iteration 505, loss = 0.09709244
# Iteration 506, loss = 0.09699590
# Iteration 507, loss = 0.09689327
# Iteration 508, loss = 0.09679583
# Iteration 509, loss = 0.09669549
# Iteration 510, loss = 0.09657856
# Iteration 511, loss = 0.09650294
# Iteration 512, loss = 0.09640115
# Iteration 513, loss = 0.09629986
# Iteration 514, loss = 0.09619934
# Iteration 515, loss = 0.09609965
# Iteration 516, loss = 0.09598539
# Iteration 517, loss = 0.09590024
# Iteration 518, loss = 0.09581295
# Iteration 519, loss = 0.09571166
# Iteration 520, loss = 0.09560113
# Iteration 521, loss = 0.09551392
# Iteration 522, loss = 0.09540965
# Iteration 523, loss = 0.09531260
# Iteration 524, loss = 0.09522026
# Iteration 525, loss = 0.09514320
# Iteration 526, loss = 0.09502604
# Iteration 527, loss = 0.09494616
# Iteration 528, loss = 0.09483510
# Iteration 529, loss = 0.09475272
# Iteration 530, loss = 0.09466551
# Iteration 531, loss = 0.09456426
# Iteration 532, loss = 0.09447239
# Iteration 533, loss = 0.09438545
# Iteration 534, loss = 0.09428624
# Iteration 535, loss = 0.09419198
# Iteration 536, loss = 0.09411993
# Iteration 537, loss = 0.09400928
# Iteration 538, loss = 0.09392078
# Iteration 539, loss = 0.09382586
# Iteration 540, loss = 0.09373548
# Iteration 541, loss = 0.09365738
# Iteration 542, loss = 0.09355671
# Iteration 543, loss = 0.09347578
# Iteration 544, loss = 0.09339280
# Iteration 545, loss = 0.09329599
# Iteration 546, loss = 0.09321185
# Iteration 547, loss = 0.09313268
# Iteration 548, loss = 0.09303072
# Iteration 549, loss = 0.09294576
# Iteration 550, loss = 0.09285313
# Iteration 551, loss = 0.09277344
# Iteration 552, loss = 0.09268660
# Iteration 553, loss = 0.09260511
# Iteration 554, loss = 0.09252777
# Iteration 555, loss = 0.09243686
# Iteration 556, loss = 0.09236031
# Iteration 557, loss = 0.09226732
# Iteration 558, loss = 0.09218900
# Iteration 559, loss = 0.09211349
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.972     0.995     0.984       212
#    Malignant      0.995     0.972     0.983       212
#
#     accuracy                          0.983       424
#    macro avg      0.984     0.983     0.983       424
# weighted avg      0.984     0.983     0.983       424

# %%
originalclass = []
predictedclass = []
  
# Cross validate
clf_mlp_sgd =  Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=10)),('scaler2', StandardScaler()),
                ('mlp',MLPClassifier(solver='sgd',alpha=0.1, batch_size=99,
                               hidden_layer_sizes=(20,),learning_rate='constant',
                               learning_rate_init=0.01, max_iter=1000,momentum=0.2,
                               random_state=13, verbose=0))])

score = cross_val_score(clf_mlp_sgd, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.972     0.995     0.984       212
#    Malignant      0.995     0.972     0.983       212
#
#     accuracy                          0.983       424
#    macro avg      0.984     0.983     0.983       424
# weighted avg      0.984     0.983     0.983       424

# %% [markdown]
# 3. Solver : LBFGS

# %%
# http://yann.lecun.com/exdb/publis/pdf/lecun-98b.pdf
# https://www.cs.cornell.edu/courses/cs4780/2018fa/lectures/lecturenote20.html
# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw
# https://datascience.stackexchange.com/questions/36049/how-to-adjust-the-hyperparameters-of-mlp-classifier-to-get-more-perfect-performa
param_grid = {
    'mlp__hidden_layer_sizes' : [(20,)],  #[(20,),(100,),(20,4),(10,10,)]
    'mlp__activation' : ['relu'],
    'mlp__solver' : ['lbfgs'],
    'mlp__alpha' : [1], #10.0 ** -np.arange(1, 7) , np.linspace(0.1,3,20) , 1
    'mlp__max_iter' : np.arange(300,500,10) , # np.arange(100,300,10) , [100,200,500,1000]
}

search_lbfgs = RandomizedSearchCV(clf_mlp, param_distributions=param_grid, n_jobs=-1,cv=search_cv,verbose=1,scoring='f1_macro',n_iter=1000)

originalclass = []
predictedclass = []
  
# Nested Cross validation
score = cross_val_score(search_lbfgs, x_new, y, scoring=make_scorer(classification_report_with_accuracy_score),cv=cv)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits

# %%
print(classification_report(originalclass, predictedclass, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#       Benign      0.968     0.986     0.977       212
#    Malignant      0.986     0.967     0.976       212
#
#     accuracy                          0.976       424
#    macro avg      0.977     0.976     0.976       424
# weighted avg      0.977     0.976     0.976       424

# %% [markdown]
# <a id='16'></a>
# ## 16) Summary

# %% [markdown]
# * Below are the tables of the specific feature selection method.
# * The performance of the algorithms is in descending order.
# * All the results are the average values of a 10-fold cross validation.
# * The columns contain the accuracy and the average values of precision, recall and f1 score.
# * It is observed that the number of samples of Βenign and Μalignant cancer are equal (212 respectively), so the weighted average and the macro average are equal.

# %% [markdown]
# <table style="text-align:center">
#     <tr>
#         <th colspan="6"> PCA : Default algorithms</th>
#     </tr>
#     <tr>
#         <th></th>
#         <th>precision </th>
#         <th>recall</th>
#         <th>f1 score</th>
#         <th>accuracy</th>
#         <th>Execution Time<br>
#         (seconds)</th>
#     </tr>
#     <tr>
#         <th>MLP</th>
#         <td>0.981</td>
#         <td>0.981</td>
#         <td>0.981</td>
#         <td>0.981</td>
#         <td>3.700</td>
#     </tr>
#     <tr>
#         <th>SVC</th>
#         <td>0.981</td>
#         <td>0.981</td>
#         <td>0.981</td>
#         <td>0.981</td>
#         <td>0.093</td>
#     </tr>
#     <tr>
#         <th>LGBM</th>
#         <td>0.974</td>
#         <td>0.974</td>
#         <td>0.974</td>
#         <td>0.974</td>
#         <td>0.284</td>
#     </tr>
#     <tr>
#         <th>KNN</th>
#         <td>0.965</td>
#         <td>0.965</td>
#         <td>0.965</td>
#         <td>0.965</td>
#         <td>0.100</td>
#     </tr>
#     <tr>
#         <th>Ridge</th>
#         <td>0.964</td>
#         <td>0.962</td>
#         <td>0.962</td>
#         <td>0.962</td>
#         <td>0.100</td>
#     </tr>
#     <tr>
#         <th>LDA</th>
#         <td>0.964</td>
#         <td>0.962</td>
#         <td>0.962</td>
#         <td>0.962</td>
#         <td>0.089</td>
#     </tr>
#      <tr>
#         <th>XGBoost</th>
#         <td>0.962</td>
#         <td>0.962</td>
#         <td>0.962</td>
#         <td>0.962</td>
#         <td>0.585</td>
#     </tr>
#     <tr>
#         <th>QDA</th>
#         <td>0.960</td>
#         <td>0.960</td>
#         <td>0.960</td>
#         <td>0.960</td>
#         <td>0.085</td>
#     </tr>
#     <tr>
#         <th>SGD</th>
#         <td>0.960</td>
#         <td>0.960</td>
#         <td>0.960</td>
#         <td>0.960</td>
#         <td>0.088</td>
#     </tr>
#     <tr>
#         <th>AdaBoost</th>
#         <td>0.960</td>
#         <td>0.960</td>
#         <td>0.960</td>
#         <td>0.960</td>
#         <td>0.803</td>
#     </tr>
#     <tr>
#         <th>Random Forest</th>
#         <td>0.955</td>
#         <td>0.955</td>
#         <td>0.955</td>
#         <td>0.955</td>
#         <td>1.253</td>
#     </tr>
#     <tr>
#         <th>GNB</th>
#         <td>0.935</td>
#         <td>0.934</td>
#         <td>0.934</td>
#         <td>0.934</td>
#         <td>0.111</td>
#     </tr>
#     <tr>
#         <th>Decision Tree</th>
#         <td>0.934</td>
#         <td>0.934</td>
#         <td>0.934</td>
#         <td>0.934</td>
#         <td>0.954</td>
#     </tr>
#
# </table>

# %% [markdown]
# <table style="text-align:center">
#     <tr>
#         <th colspan="6"> PCA : Tuned algorithms</th>
#     </tr>
#     <tr>
#         <th></th>
#         <th>precision </th>
#         <th>recall</th>
#         <th>f1 score</th>
#         <th>accuracy</th>
#         <th>Execution Time<br>
#         (seconds)</th>
#     </tr>
#     <tr>
#         <th>MLP</th>
#         <td>0.984</td>
#         <td>0.983</td>
#         <td>0.983</td>
#         <td>0.983</td>
#         <td>trial and error</td>
#     </tr>
#     <tr>
#         <th>SVC</th>
#         <td>0.981</td>
#         <td>0.981</td>
#         <td>0.981</td>
#         <td>0.981</td>
#         <td>9.945</td>
#     </tr>
#     <tr>
#         <th>KNN</th>
#         <td>0.979</td>
#         <td>0.979</td>
#         <td>0.979</td>
#         <td>0.979</td>
#         <td>87.843</td>
#     </tr>
#     <tr>
#         <th>SGD</th>
#         <td>0.974</td>
#         <td>0.974</td>
#         <td>0.974</td>
#         <td>0.974</td>
#         <td>4.023</td>
#     </tr>
#     <tr>
#         <th>QDA</th>
#         <td>0.972</td>
#         <td>0.972</td>
#         <td>0.972</td>
#         <td>0.972</td>
#         <td>27.984</td>
#     </tr>
#     <tr>
#         <th>LGBM</th>
#         <td>0.967</td>
#         <td>0.967</td>
#         <td>0.967</td>
#         <td>0.967</td>
#         <td>90.937</td>
#     </tr>
#     <tr>
#         <th>LDA</th>
#         <td>0.964</td>
#         <td>0.962</td>
#         <td>0.962</td>
#         <td>0.962</td>
#         <td>6.809</td>
#     </tr>
#     <tr>
#         <th>Ridge</th>
#         <td>0.964</td>
#         <td>0.962</td>
#         <td>0.962</td>
#         <td>0.962</td>
#         <td>32.047</td>
#     </tr>
#     <tr>
#         <th>XGBoost</th>
#         <td>0.955</td>
#         <td>0.955</td>
#         <td>0.955</td>
#         <td>0.955</td>
#         <td>217.937</td>
#     </tr>
#     <tr>
#         <th>AdaBoost</th>
#         <td>0.953</td>
#         <td>0.953</td>
#         <td>0.953</td>
#         <td>0.953</td>
#         <td>41.335</td>
#     </tr>
#     <tr>
#         <th>Random Forest</th>
#         <td>0.948</td>
#         <td>0.948</td>
#         <td>0.948</td>
#         <td>0.948</td>
#         <td>148.473</td>
#     </tr>
#     <tr>
#         <th>GNB</th>
#         <td>0.937</td>
#         <td>0.936</td>
#         <td>0.936</td>
#         <td>0.936</td>
#         <td>9.095</td>
#     </tr>
#     <tr>
#         <th>Decision Tree</th>
#         <td>0.929</td>
#         <td>0.929</td>
#         <td>0.929</td>
#         <td>0.929</td>
#         <td>51.518</td>
#     </tr>
#
# </table>

# %% [markdown]
# - As it is seen, some models perform better with default parameters. This can happen for various reasons such as:
#     - Unlucky selection of hyperparameters from random search
#     - Hyperparameters selected cause overfitting
#     - Smaller training sample in the inner loop due to nested cross-validation

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# - Sources for nested cross validation :
#     1. [Cross-Validation and Hyperparameter Search in scikit-learn - A Complete Guide](<https://dev.to/balapriya/cross-validation-and-hyperparameter-search-in-scikit-learn-a-complete-guide-5ed8>)
#     2. [Nested Cross Validation for Algorithm Selection](<https://vitalflux.com/python-nested-cross-validation-algorithm-selection/>)
#     3. [Nested Cross-Validation for Machine Learning with Python](<https://machinelearningmastery.com/nested-cross-validation-for-machine-learning-with-python/>)
#     4. [Nested cross validation for model selection](<https://stats.stackexchange.com/questions/65128/nested-cross-validation-for-model-selection/65158#65158>)
#     5. [scikit-learn GridSearchCV with multiple repetitions](<https://stackoverflow.com/questions/42228735/scikit-learn-gridsearchcv-with-multiple-repetitions/42230764#42230764>)
#     6. [Model selection done right: A gentle introduction to nested cross-validation](<https://ploomber.io/blog/nested-cv/>)
#     7. [How to obtain optimal hyperparameters after nested cross validation?](<https://stats.stackexchange.com/questions/254612/how-to-obtain-optimal-hyperparameters-after-nested-cross-validation>)
#     8. [Cross-validation for parameter tuning, model selection, and feature selection](<https://github.com/justmarkham/scikit-learn-videos/blob/master/07_cross_validation.ipynb>)
# - Sources for Hyper Parameter-Optimization :
#     1. [Random Search for Hyper-Parameter Optimization](<https://www.jmlr.org/papers/volume13/bergstra12a/bergstra12a.pdf>)
#     2. [Hyperparameter tuning for machine learning models](<https://www.jeremyjordan.me/hyperparameter-tuning/>)
# - Sources for code :
#     - All sources are in comments at each code part
